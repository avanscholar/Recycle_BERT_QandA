# %% [markdown]
# ## Importing Libraries

# %%
#!pip install elsapy
#!pip install xmltodict

# %%
#Elsevier Libraries
from elsapy.elsclient import ElsClient
from elsapy.elsprofile import ElsAuthor, ElsAffil
from elsapy.elsdoc import FullDoc, AbsDoc
from elsapy.elssearch import ElsSearch

#Libraries for URL access
import json
import csv
import pprint
import requests
import xmltodict
import urllib3
import pandas as pd
import numpy as np

#Import warnings library
import warnings
warnings.filterwarnings("ignore")

# %%
#xml.etree.ElementTree — The ElementTree XML API
import xml.etree.ElementTree as ET

# %%
info_list = [] #Creating an empty list to store the  info
#Rerunning this will delete the data that will be stored further
#Run only once

# %%
#Create a num array of 0 to 5900 spaces 100 apart per page. Each page of Search returns 100 entries until 6000 is reached
num = np.linspace(0,6000, 60, dtype = int)
print(num)
#Maximum of 6000 searches are returned on calling the ElsSearch API
# Out:
# [   0  101  203  305  406  508  610  711  813  915 1016 1118 1220 1322
#  1423 1525 1627 1728 1830 1932 2033 2135 2237 2338 2440 2542 2644 2745
#  2847 2949 3050 3152 3254 3355 3457 3559 3661 3762 3864 3966 4067 4169
#  4271 4372 4474 4576 4677 4779 4881 4983 5084 5186 5288 5389 5491 5593
#  5694 5796 5898 6000]

# %%
len(num)
# Out:
# 60

# %% [markdown]
# ## Accessing the Links - API Extraction

# %%
#config = {'apikey': '22d18e0c4fdc59bb8898844056b2be57'}
config = {
    "apikey": "2dc442325fc67f2f275ec3157ef8df65",
 "insttoken": "6beb1f6c29d85f50029bf11c8de94d1b"
    }

client = ElsClient(config['apikey'])
client.inst_token = config['insttoken']

# %%
def XML_DOI(link):
    
    #defining a header's dictionary to pass through requests
    headers_dict = {"X-ELS-APIKey": "2dc442325fc67f2f275ec3157ef8df65", "X-ELS-Insttoken": "6beb1f6c29d85f50029bf11c8de94d1b", "Accept": "application/xml"}
    
    #x takes response of the HTTP request, passes link
    x = requests.get(link, headers=headers_dict)
    
    #Save it as XML file
    with open("doi.xml", 'wb') as f:
        f.write(x.content)

# %% [raw]
# def XML_DOI(link):
#
#     #defining a header's dictionary to pass through requests
#     headers_dict = {"X-ELS-APIKey": "2dc442325fc67f2f275ec3157ef8df65", "X-ELS-Insttoken": "6beb1f6c29d85f50029bf11c8de94d1b", "Accept": "application/xml"}
#
#     #x takes response of the HTTP request, passes link
#     x = requests.get(link, headers=headers_dict)
#
#     #Save it as XML file
#     with open("doi.xml", 'wb') as f:
#         f.write(x.content)
#     return x.content

# %%
link_list = []

#Loop to iterate over all papers
#UPI query can take many arguments.
#start, count, query are a few as name suggests
for i in range(0, 60):
    
    start = "https://api.elsevier.com/content/search/sciencedirect?" 
    count = "start=" + str(num[i]) + "&count=100"
    query = "&query=preparation+of+alcohol"
    endapi = "&apiKey=2dc442325fc67f2f275ec3157ef8df65&insttoken=6beb1f6c29d85f50029bf11c8de94d1b"
    
    link = start + count + query  + endapi 
    #print(link)
    link_list.append(link)
#subscription = "&subscribed=true"

# %%
#len(link_list), link_list
link_list[4]
# Out:
# 'https://api.elsevier.com/content/search/sciencedirect?start=406&count=100&query=preparation+of+alcohol&apiKey=2dc442325fc67f2f275ec3157ef8df65&insttoken=6beb1f6c29d85f50029bf11c8de94d1b'

# %%
#XML_DOI(link_list[1])
#link_list[4]

# %% [markdown]
# ## XML Parsing

# %%
link = link_list[2]
link
# Out:
# 'https://api.elsevier.com/content/search/sciencedirect?start=203&count=100&query=preparation+of+alcohol&apiKey=2dc442325fc67f2f275ec3157ef8df65&insttoken=6beb1f6c29d85f50029bf11c8de94d1b'

# %%
# Call the XML_DOI function
for j in range(0, 60):
    xmlfile = XML_DOI(link_list[j])
    #print(j)
    #print(xmlfile)
    #Read the data
    #<?xml version="1.0" encoding="UTF-8"?>
    tree = ET.parse("doi.xml")
    root = tree.getroot()
    for entry in root.findall('{http://www.w3.org/2005/Atom}entry'):
    
        info_dict = {} #This will create a dictionary where we will store information about the searches
    
        '''
        CHECK CODE
        url = entry.find('{http://prismstandard.org/namespaces/basic/2.0/}url').text
        title = entry.find('{http://purl.org/dc/elements/1.1/}title').text
        pub_name = entry.find('{http://prismstandard.org/namespaces/basic/2.0/}publicationName').text
        doi = entry.find('{http://prismstandard.org/namespaces/basic/2.0/}doi').text
        #description = entry.find('{http://purl.org/dc/elements/1.1/}description').text
        print(url, title, pub_name, doi)
        print('\n')
        
        '''
    
        info_dict['URL'] = entry.find('{http://prismstandard.org/namespaces/basic/2.0/}url').text
        info_dict['Title'] = entry.find('{http://purl.org/dc/elements/1.1/}title').text
        info_dict['Pub_Name'] = entry.find('{http://prismstandard.org/namespaces/basic/2.0/}publicationName').text
        doi = entry.find('{http://prismstandard.org/namespaces/basic/2.0/}doi')
        info_dict['Year'] = entry.find('{http://prismstandard.org/namespaces/basic/2.0/}coverDate').text
        if doi is None:
            info_dict['DOI'] = None
        else:
            info_dict['DOI'] = doi.text
    
        info_list.append(info_dict)
    
    #print(info_list)

# %%
type(info_list), len(info_list)
# info_list
# Out:
# (list, 5900)

# %%
info_list[0]['Pub_Name'], info_list[0]['Year'], info_list[0]['Title']
# Out:
# ('Fuel Processing Technology',
#  '2023-03-31',
#  'A novel integrated process for selective preparation of jet-range fuels from low carbon alcohols and ABE')

# %%
len(info_list)
# Out:
# 5900

# %%
DOI =  []
Title = []
Pub_name = []
year = []

for i in range(len(info_list)):
    DOI.append(info_list[i]['DOI'])
    Title.append(info_list[i]['Title'])
    Pub_name.append(info_list[i]['Pub_Name'])
    year.append(info_list[i]['Year'])

# %%
df =  pd.DataFrame()
df['Title'] =  Title
df['Pub_name'] = Pub_name
df['DOI'] = DOI
df['Year'] = year

df.head()
# Out:
#                                                Title  \
# 0  A novel integrated process for selective prepa...
# 1  Iron nanoparticles in isopropyl alcohol: Prepa...
# 2  Comparing surgeons’ skin tolerance and accepta...
# 3  Surfactant-assisted preparation of Mo-Co-K sul...
# 4  Preparation of nanocellulose-polyvinyl alcohol...
#
#                                 Pub_name                            DOI  \
# 0             Fuel Processing Technology   10.1016/j.fuproc.2022.107603
# 1           Journal of Molecular Liquids   10.1016/j.molliq.2022.120743
# 2  American Journal of Infection Control     10.1016/j.ajic.2022.01.028
# 3  Chemical Engineering Journal Advances     10.1016/j.ceja.2022.100256
# 4          Industrial Crops and Products  10.1016/j.indcrop.2021.114371
#
#          Year
# 0  2023-03-31
# 1  2022-12-15
# 2  2022-10-31
# 3  2022-05-15
# 4  2022-02-28

# %%
#Create string1 and string2 to join doi with institoken to make a single URL
string1 = "https://api.elsevier.com/content/article/doi/" 
string2 = "?apiKey=2dc442325fc67f2f275ec3157ef8df65&insttoken=6beb1f6c29d85f50029bf11c8de94d1b"

#Access every DOI in the previous file and append the new URL to another column
df['Link'] = df['DOI'].apply(lambda x: string1 + str(x) + string2)

df.head()
# Out:
#                                                Title  \
# 0  A novel integrated process for selective prepa...
# 1  Iron nanoparticles in isopropyl alcohol: Prepa...
# 2  Comparing surgeons’ skin tolerance and accepta...
# 3  Surfactant-assisted preparation of Mo-Co-K sul...
# 4  Preparation of nanocellulose-polyvinyl alcohol...
#
#                                 Pub_name                            DOI  \
# 0             Fuel Processing Technology   10.1016/j.fuproc.2022.107603
# 1           Journal of Molecular Liquids   10.1016/j.molliq.2022.120743
# 2  American Journal of Infection Control     10.1016/j.ajic.2022.01.028
# 3  Chemical Engineering Journal Advances     10.1016/j.ceja.2022.100256
# 4          Industrial Crops and Products  10.1016/j.indcrop.2021.114371
#
#          Year                                               Link
# 0  2023-03-31  https://api.elsevier.com/content/article/doi/1...
# 1  2022-12-15  https://api.elsevier.com/content/article/doi/1...
# 2  2022-10-31  https://api.elsevier.com/content/article/doi/1...
# 3  2022-05-15  https://api.elsevier.com/content/article/doi/1...
# 4  2022-02-28  https://api.elsevier.com/content/article/doi/1...

# %%
df['Title'][133]
# Out:
# 'Deoxydehydration of glycerol to allyl alcohol catalysed by ceria-supported rhenium oxide'

# %%
# %%time
list_abstract = []
list_doi= []
list_title = []
list_date = []
list_journal = []

## ScienceDirect (full-text) document example using DOI
#for i in range(len(data)):
from pprint import pprint
doi= df['DOI']
for i in range(df.shape[0]):
    pprint(doi[i])
    doi_doc = FullDoc(doi = doi[i])
    if doi_doc.read(client):

        #pprint(dir(doi_doc))
        #pprint(doi_doc._data)
        abstract = doi_doc._data['coredata']['dc:description']
        title = doi_doc.title
        date = doi_doc._data['coredata']['prism:coverDisplayDate']
        journal = doi_doc._data['coredata']['prism:publicationName']
        #pprint(abstract)
        print(i, 'done')
        #dict_abstract['DOI'] = doi[i]
        #dict_abstract['Abstract'] = abstract
        list_abstract.append(abstract)
        list_doi.append(doi[i])
        list_title.append(title)
        list_date.append(date)
        list_journal.append(journal)
        #doi_doc.write()
    
    else:
        pprint('Operation failed')
        #dict_abstract['DOI'] = doi[i]
        #dict_abstract['Abstract'] = 'NAN'
        list_abstract.append('0')
        list_doi.append('1')
        list_title.append('2')
        list_date.append('3')
        list_journal.append('4')
# Out:
# '10.1016/j.fuproc.2022.107603'
# 0 done
# '10.1016/j.molliq.2022.120743'
# 1 done
# '10.1016/j.ajic.2022.01.028'
# 2 done
# '10.1016/j.ceja.2022.100256'
# 3 done
# '10.1016/j.indcrop.2021.114371'
# 4 done
# '10.1016/j.jiec.2022.09.011'
# 5 done
# '10.1016/j.foodchem.2022.133085'
# 6 done
# '10.1016/j.ijbiomac.2022.12.302'
# 7 done
# '10.1016/j.seppur.2023.123226'
# 8 done
# '10.1016/j.procbio.2022.08.025'
# 9 done
# '10.1016/j.ijbiomac.2022.11.114'
# 10 done
# '10.1016/B978-0-12-819727-1.00027-3'
# 11 done
# '10.1016/j.polymer.2022.125607'
# 12 done
# '10.1016/j.ijadhadh.2021.102958'
# 13 done
# '10.1016/j.polymertesting.2023.107936'
# 14 done
# '10.1016/j.renene.2022.04.100'
# 15 done
# '10.1016/j.carbpol.2022.120382'
# 16 done
# '10.1016/j.ijbiomac.2022.10.119'
# 17 done
# '10.1016/j.cdc.2022.100869'
# 18 done
# '10.1016/j.artd.2022.02.024'
# 19 done
# '10.1016/j.jelechem.2022.116539'
# 20 done
# '10.1016/j.matpr.2022.06.500'
# 21 done
# '10.1016/j.mssp.2022.106499'
# 22 done
# '10.1016/S1872-5813(21)60179-2'
# 23 done
# '10.1016/j.polymer.2022.125036'
# 24 done
# '10.1016/j.ijbiomac.2022.06.157'
# 25 done
# '10.1016/j.oret.2020.04.006'
# 26 done
# '10.1016/j.reactfunctpolym.2022.105187'
# 27 done
# '10.1016/j.tetlet.2019.151017'
# 28 done
# '10.1016/j.matchemphys.2022.126169'
# 29 done
# '10.1016/j.indcrop.2022.116171'
# 30 done
# '10.1016/j.matpr.2021.10.432'
# 31 done
# '10.1016/j.ijbiomac.2021.07.136'
# 32 done
# '10.1016/j.ijbiomac.2021.09.015'
# 33 done
# '10.1016/j.fuproc.2022.107600'
# 34 done
# '10.1016/j.mseb.2022.115922'
# 35 done
# '10.1016/j.mcat.2020.110789'
# 36 done
# '10.1016/j.jcis.2022.08.119'
# 37 done
# '10.1016/j.tetlet.2021.153455'
# 38 done
# '10.1016/j.colcom.2021.100377'
# 39 done
# '10.1016/j.mcat.2020.111120'
# 40 done
# '10.1016/j.jsps.2021.06.002'
# 41 done
# '10.1016/j.cmi.2019.06.016'
# 42 done
# '10.1016/j.applthermaleng.2022.118143'
# 43 done
# '10.1016/j.jenvman.2021.114044'
# 44 done
# '10.1016/j.mtchem.2022.101340'
# 45 done
# '10.1016/j.ijhydene.2022.11.116'
# 46 done
# '10.1016/j.drugalcdep.2022.109755'
# 47 done
# '10.1016/j.carbpol.2022.119318'
# 48 done
# '10.1016/j.jddst.2021.103053'
# 49 done
# '10.1016/j.alcohol.2022.12.002'
# 50 done
# '10.1016/S1872-2067(22)64174-3'
# 51 done
# '10.1016/j.jcat.2019.12.012'
# 52 done
# '10.1016/j.mcat.2022.112764'
# 53 done
# '10.1016/j.carpta.2022.100273'
# 54 done
# '10.1016/j.colsurfa.2021.126270'
# 55 done
# '10.1016/j.est.2020.101600'
# 56 done
# '10.1016/j.apcata.2022.118721'
# 57 done
# '10.1016/j.jimed.2022.03.009'
# 58 done
# '10.1016/j.ijbiomac.2021.07.127'
# 59 done
# '10.1016/j.addbeh.2022.107571'
# 60 done
# '10.1016/j.solmat.2022.111796'
# 61 done
# '10.1016/j.jff.2019.103776'
# 62 done
# '10.1016/j.ijbiomac.2022.05.017'
# 63 done
# '10.1016/j.ajic.2021.10.031'
# 64 done
# '10.1016/j.porgcoat.2022.106937'
# 65 done
# '10.1016/j.gresc.2021.07.003'
# 66 done
# '10.1016/j.apcata.2020.117868'
# 67 done
# '10.1016/j.mseb.2021.115500'
# 68 done
# '10.1016/j.ijhydene.2020.09.112'
# 69 done
# '10.1016/j.arabjc.2022.104140'
# 70 done
# '10.1016/j.bioadv.2023.213290'
# 71 done
# '10.1016/j.eurpolymj.2021.110619'
# 72 done
# '10.1016/j.matpr.2022.02.034'
# 73 done
# '10.1016/S1872-5813(21)60111-1'
# 74 done
# '10.1016/j.foodchem.2019.125933'
# 75 done
# '10.1016/S1872-5813(19)30023-4'
# 76 done
# '10.1016/j.carbon.2021.06.075'
# 77 done
# '10.1016/j.reactfunctpolym.2021.105089'
# 78 done
# '10.1016/j.tchem.2022.100031'
# 79 done
# '10.1016/j.eurpolymj.2020.109571'
# 80 done
# '10.1016/j.sleep.2022.12.022'
# 81 done
# '10.1016/j.renene.2022.08.125'
# 82 done
# '10.1016/j.clay.2020.105761'
# 83 done
# '10.1016/j.indcrop.2022.115723'
# 84 done
# '10.1016/j.snb.2022.132450'
# 85 done
# '10.1016/j.carbpol.2021.118850'
# 86 done
# '10.1016/j.eurpolymj.2022.111675'
# 87 done
# '10.1016/j.apcata.2023.119036'
# 88 done
# '10.1016/j.jmrt.2022.07.176'
# 89 done
# '10.1016/j.redox.2022.102577'
# 90 done
# '10.1016/j.diamond.2022.109635'
# 91 done
# '10.1016/j.vaccine.2020.12.082'
# 92 done
# '10.1016/j.fuel.2022.127011'
# 93 done
# '10.1016/j.polymertesting.2021.107057'
# 94 done
# '10.1016/j.microc.2022.107507'
# 95 done
# '10.1016/j.matchemphys.2020.123193'
# 96 done
# '10.1016/j.ejogrb.2019.10.035'
# 97 done
# '10.1016/j.matchemphys.2019.04.053'
# 98 done
# '10.1016/j.procbio.2022.10.014'
# 99 done
# '10.1016/j.matchemphys.2020.122991'
# 100 done
# '10.1016/j.carbpol.2023.120548'
# 101 done
# '10.1016/j.carbpol.2020.116670'
# 102 done
# '10.1016/j.drugalcdep.2022.109671'
# 103 done
# '10.1016/j.colsurfa.2020.125743'
# 104 done
# '10.1016/j.addbeh.2022.107395'
# 105 done
# '10.1016/j.apsusc.2022.156233'
# 106 done
# '10.1016/j.jtice.2019.06.013'
# 107 done
# '10.1016/j.tetlet.2022.154332'
# 108 done
# '10.1016/j.indcrop.2019.01.034'
# 109 done
# '10.1016/j.fuel.2021.120394'
# 110 done
# '10.1016/j.srhc.2021.100622'
# 111 done
# '10.1016/j.matpr.2021.11.377'
# 112 done
# '10.1016/j.ajic.2022.09.020'
# 113 done
# '10.1016/j.ijbiomac.2020.02.174'
# 114 done
# '10.1016/j.chroma.2018.12.048'
# 115 done
# '10.1016/j.colsurfa.2022.128572'
# 116 done
# '10.1016/j.drugalcdep.2022.109673'
# 117 done
# '10.1016/j.cej.2020.128282'
# 118 done
# '10.1016/B978-0-323-89936-9.00020-5'
# 119 done
# '10.1016/j.cattod.2022.05.039'
# 120 done
# '10.1016/j.alcohol.2022.09.001'
# 121 done
# '10.1016/j.healthpol.2022.11.012'
# 122 done
# '10.1016/j.fuel.2022.125873'
# 123 done
# '10.1016/j.jfoodeng.2022.111334'
# 124 done
# '10.1016/j.lfs.2022.121102'
# 125 done
# '10.1016/j.supflu.2022.105815'
# 126 done
# '10.1016/j.colcom.2019.100222'
# 127 done
# '10.1016/j.mcat.2019.110533'
# 128 done
# '10.1016/j.jad.2022.12.069'
# 129 done
# '10.1016/j.mcat.2022.112772'
# 130 done
# '10.1016/j.ijpharm.2019.03.008'
# 131 done
# '10.1016/j.foodcont.2021.108331'
# 132 done
# '10.1016/j.mcat.2022.112856'
# 133 done
# '10.1016/j.soard.2022.10.025'
# 134 done
# '10.1016/j.carbpol.2021.117875'
# 135 done
# '10.1016/j.memsci.2022.120541'
# 136 done
# '10.1016/j.jallcom.2019.05.209'
# 137 done
# '10.1016/j.ypmed.2022.107381'
# 138 done
# '10.1016/j.pnpbp.2022.110699'
# 139 done
# '10.1016/j.matpr.2020.07.101'
# 140 done
# '10.1016/j.molliq.2022.120537'
# 141 done
# '10.1016/j.polymer.2022.124674'
# 142 done
# '10.1016/j.jssc.2019.120991'
# 143 done
# '10.1016/j.cclet.2020.01.012'
# 144 done
# '10.1016/j.mcat.2021.111639'
# 145 done
# '10.1016/j.molstruc.2019.126895'
# 146 done
# '10.1016/j.matchemphys.2021.125218'
# 147 done
# '10.1016/j.colegn.2022.11.003'
# 148 done
# '10.1016/j.jddst.2021.102484'
# 149 done
# '10.1016/j.reactfunctpolym.2022.105461'
# 150 done
# '10.1016/j.jhep.2022.11.013'
# 151 done
# '10.1016/j.micromeso.2022.112407'
# 152 done
# '10.1016/j.vibspec.2022.103493'
# 153 done
# '10.1016/j.expneurol.2023.114318'
# 154 done
# '10.1016/j.apsusc.2022.155616'
# 155 done
# '10.1016/j.addbeh.2022.107536'
# 156 done
# '10.1016/S1872-2040(18)61105-3'
# 157 done
# '10.1016/j.ajic.2022.07.020'
# 158 done
# '10.1016/j.jfoodeng.2022.111360'
# 159 done
# '10.1016/j.electacta.2022.141736'
# 160 done
# '10.1016/j.ijbiomac.2022.10.252'
# 161 done
# '10.1016/j.ijhydene.2022.12.274'
# 162 done
# '10.1016/j.chb.2021.106773'
# 163 done
# '10.1016/j.ijbiomac.2020.06.105'
# 164 done
# '10.1016/j.fuel.2022.126749'
# 165 done
# '10.1016/j.coco.2022.101359'
# 166 done
# '10.1016/j.jcou.2019.03.007'
# 167 done
# '10.1016/j.applthermaleng.2020.114943'
# 168 done
# '10.1016/j.fuel.2022.126928'
# 169 done
# '10.1016/j.ijhydene.2018.07.021'
# 170 done
# '10.1016/j.tetlet.2022.154062'
# 171 done
# '10.1016/j.puhe.2022.07.006'
# 172 done
# '10.1016/j.drugpo.2022.103936'
# 173 done
# '10.1016/j.fuel.2022.127121'
# 174 done
# '10.1016/j.semarthrit.2022.152146'
# 175 done
# '10.1016/j.fuel.2022.127264'
# 176 done
# '10.1016/j.drugalcdep.2022.109533'
# 177 done
# '10.1016/j.colsurfb.2022.113025'
# 178 done
# '10.1016/j.ijbiomac.2019.07.205'
# 179 done
# '10.1016/j.diamond.2022.109642'
# 180 done
# '10.1016/j.mcat.2022.112883'
# 181 done
# '10.1016/j.addicn.2022.100041'
# 182 done
# '10.1016/j.teac.2022.e00164'
# 183 done
# '10.1016/j.forsciint.2022.111438'
# 184 done
# '10.1016/j.matpr.2022.02.629'
# 185 done
# '10.1016/j.matpr.2022.07.255'
# 186 done
# '10.1016/j.livres.2022.11.006'
# 187 done
# '10.1016/j.fuel.2022.126222'
# 188 done
# '10.1016/j.ijpharm.2020.120172'
# 189 done
# '10.1016/j.fpsl.2022.100904'
# 190 done
# '10.1016/j.ijhydene.2022.05.083'
# 191 done
# '10.1016/j.psep.2022.06.014'
# 192 done
# '10.1016/j.reactfunctpolym.2021.104916'
# 193 done
# '10.1016/j.jechem.2022.10.038'
# 194 done
# '10.1016/j.foodchem.2022.135051'
# 195 done
# '10.1016/j.cdc.2019.100245'
# 196 done
# '10.1016/j.addbeh.2023.107619'
# 197 done
# '10.1016/j.revpalbo.2013.11.004'
# 198 done
# '10.1016/j.carbpol.2019.115784'
# 199 done
# '10.1016/j.jaap.2022.105749'
# 200 done
# '10.1016/j.micromeso.2020.110211'
# 201 done
# '10.1016/j.indcrop.2019.111729'
# 202 done
# '10.1016/j.jscs.2022.101578'
# 203 done
# '10.1016/j.apcatb.2022.122048'
# 204 done
# '10.1016/j.snb.2023.133292'
# 205 done
# '10.1016/j.apsusc.2022.155438'
# 206 done
# '10.1016/j.fuproc.2019.05.003'
# 207 done
# '10.1016/j.bbr.2022.114087'
# 208 done
# '10.1016/j.biopsycho.2015.12.012'
# 209 done
# '10.1016/j.cct.2022.106976'
# 210 done
# '10.1016/j.tet.2022.133226'
# 211 done
# '10.1016/j.seppur.2022.120769'
# 212 done
# '10.1016/j.alcohol.2022.08.008'
# 213 done
# '10.1016/j.fuel.2022.126137'
# 214 done
# '10.1016/j.apsusc.2022.155308'
# 215 done
# '10.1016/j.foodres.2019.108604'
# 216 done
# '10.1016/j.tet.2021.132379'
# 217 done
# '10.1016/j.jmst.2022.08.009'
# 218 done
# '10.1016/j.jtice.2021.06.046'
# 219 done
# '10.1016/j.jpowsour.2022.232468'
# 220 done
# '10.1016/j.molstruc.2022.133267'
# 221 done
# '10.1016/j.desal.2022.116242'
# 222 done
# '10.1016/j.ceramint.2022.10.249'
# 223 done
# '10.1016/j.ejim.2022.08.013'
# 224 done
# '10.1016/j.molstruc.2022.134584'
# 225 done
# '10.1016/j.neulet.2022.136813'
# 226 done
# '10.1016/j.fuel.2022.126439'
# 227 done
# '10.1016/j.tetlet.2016.07.056'
# 228 done
# '10.1016/j.ijbiomac.2019.09.132'
# 229 done
# '10.1016/j.energy.2022.124972'
# 230 done
# '10.1016/j.apcata.2016.05.029'
# 231 done
# '10.1016/j.burns.2022.04.005'
# 232 done
# '10.1016/j.tetlet.2015.12.109'
# 233 done
# '10.1016/j.mseb.2022.116251'
# 234 done
# '10.1016/j.jcat.2022.12.002'
# 235 done
# '10.1016/j.molliq.2018.12.049'
# 236 done
# '10.1016/j.carbpol.2022.120231'
# 237 done
# '10.1016/j.carbpol.2020.117485'
# 238 done
# '10.1016/j.microc.2022.107854'
# 239 done
# '10.1016/j.drugalcdep.2022.109466'
# 240 done
# '10.1016/j.reprotox.2022.05.017'
# 241 done
# '10.1016/j.apsusc.2022.155296'
# 242 done
# '10.1016/j.mcat.2022.112596'
# 243 done
# '10.1016/j.jcat.2022.11.032'
# 244 done
# '10.1016/j.metabol.2022.155334'
# 245 done
# '10.1016/j.chempr.2022.08.016'
# 246 done
# '10.1016/S2468-1253(21)00191-6'
# 247 done
# '10.1016/j.ijbiomac.2022.08.052'
# 248 done
# '10.1016/j.jclepro.2022.135048'
# 249 done
# '10.1016/j.fuel.2022.125083'
# 250 done
# '10.1016/j.paid.2022.111877'
# 251 done
# '10.1016/B978-0-12-820472-6.00170-5'
# 252 done
# '10.1016/j.ijpharm.2022.121908'
# 253 done
# '10.1016/j.apsusc.2019.144754'
# 254 done
# '10.1016/j.ultrasmedbio.2022.01.007'
# 255 done
# '10.1016/j.matchemphys.2022.126817'
# 256 done
# '10.1016/j.arabjc.2023.104564'
# 257 done
# '10.1016/j.nicl.2021.102738'
# 258 done
# '10.1016/j.tetlet.2022.153839'
# 259 done
# '10.1016/j.mcat.2022.112735'
# 260 done
# '10.1016/j.cclet.2020.04.042'
# 261 done
# '10.1016/j.jff.2019.103563'
# 262 done
# '10.1016/j.bej.2022.108406'
# 263 done
# '10.1016/j.ijbiomac.2019.12.073'
# 264 done
# '10.1016/j.envint.2022.107559'
# 265 done
# '10.1016/j.jpba.2022.114694'
# 266 done
# '10.1016/j.colsurfa.2022.129580'
# 267 done
# '10.1016/j.drugalcdep.2021.109068'
# 268 done
# '10.1016/j.addbeh.2022.107487'
# 269 done
# '10.1016/j.catcom.2022.106513'
# 270 done
# '10.1016/j.jallcom.2022.166994'
# 271 done
# '10.1016/j.eurpolymj.2023.111822'
# 272 done
# '10.1016/j.crci.2015.06.019'
# 273 done
# '10.1016/j.biopha.2022.113508'
# 274 done
# '10.1016/j.molstruc.2022.134282'
# 275 done
# '10.1016/j.mcat.2021.112092'
# 276 done
# '10.1016/j.fuel.2022.125222'
# 277 done
# '10.1016/j.celrep.2022.110937'
# 278 done
# '10.1016/j.jinorgbio.2022.112095'
# 279 done
# '10.1016/j.molstruc.2022.134249'
# 280 done
# '10.1016/j.arabjc.2022.103865'
# 281 done
# '10.1016/j.apcata.2022.118660'
# 282 done
# '10.1016/j.ijbiomac.2020.03.077'
# 283 done
# '10.1016/j.tet.2022.133114'
# 284 done
# '10.1016/j.vaa.2020.11.006'
# 285 done
# '10.1016/j.ssmmh.2022.100073'
# 286 done
# '10.1016/j.procbio.2016.11.007'
# 287 done
# '10.1016/j.pbb.2022.173482'
# 288 done
# '10.1016/j.energy.2022.123806'
# 289 done
# '10.1016/j.dialog.2022.100040'
# 290 done
# '10.1016/j.molliq.2022.120231'
# 291 done
# '10.1016/j.apsusc.2022.155364'
# 292 done
# '10.1016/j.jddst.2022.103888'
# 293 done
# '10.1016/j.jcou.2018.04.018'
# 294 done
# '10.1016/j.drugalcdep.2022.109697'
# 295 done
# '10.1016/j.ces.2022.117920'
# 296 done
# '10.1016/j.jmrt.2018.12.023'
# 297 done
# '10.1016/j.seppur.2019.115746'
# 298 done
# '10.1016/j.abrep.2022.100471'
# 299 done
# '10.1016/j.jcou.2018.04.018'
# 300 done
# '10.1016/j.jasc.2022.07.001'
# 301 done
# '10.1016/j.dadr.2022.100124'
# 302 done
# '10.1016/j.ijbiomac.2020.02.176'
# 303 done
# '10.1016/j.solener.2022.01.069'
# 304 done
# '10.1016/j.ijhydene.2020.04.134'
# 305 done
# '10.1016/j.jscs.2022.101487'
# 306 done
# '10.1016/j.ijhydene.2022.04.242'
# 307 done
# '10.1016/j.jcou.2022.102322'
# 308 done
# '10.1016/j.jmgm.2022.108358'
# 309 done
# '10.1016/j.seppur.2022.121004'
# 310 done
# '10.1016/j.cpcardiol.2022.101395'
# 311 done
# '10.1016/j.cattod.2022.05.021'
# 312 done
# '10.1016/j.jcat.2022.09.012'
# 313 done
# '10.1016/j.cattod.2022.08.001'
# 314 done
# '10.1016/j.fuel.2022.124507'
# 315 done
# '10.1016/j.apcata.2022.118783'
# 316 done
# '10.1016/j.tetlet.2014.01.144'
# 317 done
# '10.1016/j.procbio.2022.11.008'
# 318 done
# '10.1016/j.mcat.2022.112454'
# 319 done
# '10.1016/j.msec.2021.111889'
# 320 done
# '10.1016/j.drugalcdep.2022.109462'
# 321 done
# '10.1016/j.tet.2010.11.079'
# 322 done
# '10.1016/j.apsusc.2022.155549'
# 323 done
# '10.1016/j.jcat.2022.08.010'
# 324 done
# '10.1016/j.jff.2022.105142'
# 325 done
# '10.1016/j.drugalcdep.2022.109515'
# 326 done
# '10.1016/j.molliq.2022.121129'
# 327 done
# '10.1016/j.csite.2022.101826'
# 328 done
# '10.1016/j.mcat.2022.112674'
# 329 done
# '10.1016/j.cattod.2022.07.009'
# 330 done
# '10.1016/j.apsusc.2022.154997'
# 331 done
# '10.1016/j.gresc.2022.12.002'
# 332 done
# '10.1016/j.ecoenv.2020.110935'
# 333 done
# '10.1016/j.carbpol.2021.118697'
# 334 done
# '10.1016/j.apenergy.2022.119843'
# 335 done
# '10.1016/j.matchemphys.2019.122552'
# 336 done
# '10.1016/j.colsurfb.2022.112882'
# 337 done
# '10.1016/j.fochx.2022.100401'
# 338 done
# '10.1016/j.fshw.2022.04.016'
# 339 done
# '10.1016/j.polymdegradstab.2022.110133'
# 340 done
# '10.1016/j.eurpolymj.2019.05.049'
# 341 done
# '10.1016/j.mcat.2022.112372'
# 342 done
# '10.1016/j.biopsych.2022.01.002'
# 343 done
# '10.1016/j.jfluchem.2013.07.016'
# 344 done
# '10.1016/j.apsadv.2021.100099'
# 345 done
# '10.1016/j.fuel.2022.125700'
# 346 done
# '10.1016/j.cej.2022.139328'
# 347 done
# '10.1016/j.tetlet.2013.02.079'
# 348 done
# '10.1016/j.neuropharm.2022.109384'
# 349 done
# '10.1016/j.carbpol.2022.119602'
# 350 done
# '10.1016/j.molcatb.2009.04.017'
# 351 done
# '10.1016/j.drugalcdep.2021.109134'
# 352 done
# '10.1016/j.apsusc.2021.151978'
# 353 done
# '10.1016/j.bios.2022.114319'
# 354 done
# '10.1016/j.solidstatesciences.2022.106905'
# 355 done
# '10.1016/j.optmat.2022.113227'
# 356 done
# '10.1016/j.matlet.2022.133506'
# 357 done
# '10.1016/j.tetlet.2014.08.078'
# 358 done
# '10.1016/j.jcat.2022.11.014'
# 359 done
# '10.1016/j.eclinm.2022.101460'
# 360 done
# '10.1016/j.tetlet.2011.06.111'
# 361 done
# '10.1016/j.alcohol.2022.07.003'
# 362 done
# '10.1016/j.jddst.2020.102227'
# 363 done
# '10.1016/j.mcat.2022.112891'
# 364 done
# '10.1016/j.reactfunctpolym.2017.02.008'
# 365 done
# '10.1016/j.drugalcdep.2021.109253'
# 366 done
# '10.1016/j.apsusc.2022.154563'
# 367 done
# '10.1016/B978-0-323-91001-9.00021-9'
# 368 done
# '10.1016/j.polymertesting.2019.106315'
# 369 done
# '10.1016/j.jechem.2022.06.012'
# 370 done
# '10.1016/j.drugalcdep.2022.109597'
# 371 done
# '10.1016/j.intimp.2022.109250'
# 372 done
# '10.1016/j.ijbiomac.2022.04.067'
# 373 done
# '10.1016/j.jpcs.2022.110883'
# 374 done
# '10.1016/j.chroma.2019.02.004'
# 375 done
# '10.1016/j.dib.2022.107873'
# 376 done
# '10.1016/j.biortech.2017.09.111'
# 377 done
# '10.1016/j.jff.2022.105062'
# 378 done
# '10.1016/j.supflu.2014.02.011'
# 379 done
# '10.1016/j.abb.2020.108677'
# 380 done
# '10.1016/j.procbio.2017.03.019'
# 381 done
# '10.1016/j.bbadis.2022.166483'
# 382 done
# '10.1016/S1875-5364(22)60181-X'
# 383 done
# '10.1016/j.materresbull.2021.111632'
# 384 done
# '10.1016/j.carbpol.2021.117679'
# 385 done
# '10.1016/j.cclet.2015.01.009'
# 386 done
# '10.1016/j.fuproc.2022.107507'
# 387 done
# '10.1016/j.mcat.2022.112712'
# 388 done
# '10.1016/S1872-2067(21)63989-X'
# 389 done
# '10.1016/j.apcatb.2022.121393'
# 390 done
# '10.1016/j.molstruc.2020.128767'
# 391 done
# '10.1016/j.abrep.2022.100434'
# 392 done
# '10.1016/j.jhazmat.2018.07.108'
# 393 done
# '10.1016/j.alcohol.2022.02.005'
# 394 done
# '10.1016/j.chemosphere.2022.137457'
# 395 done
# '10.1016/j.addbeh.2021.107106'
# 396 done
# '10.1016/j.ica.2022.120830'
# 397 done
# '10.1016/j.lwt.2019.03.036'
# 398 done
# '10.1016/j.cattod.2021.10.013'
# 399 done
# '10.1016/j.cattod.2021.10.013'
# 400 done
# '10.1016/j.jiec.2022.12.002'
# 401 done
# '10.1016/j.ijhydene.2018.11.051'
# 402 done
# '10.1016/j.colsurfa.2022.128998'
# 403 done
# '10.1016/j.pnpbp.2022.110570'
# 404 done
# '10.1016/j.mcat.2018.06.009'
# 405 done
# '10.1016/j.mcat.2022.112403'
# 406 done
# '10.1016/j.appet.2021.105225'
# 407 done
# '10.1016/S1872-5813(21)60015-X'
# 408 done
# '10.1016/j.jddst.2022.103715'
# 409 done
# '10.1016/j.tetlet.2008.11.111'
# 410 done
# '10.1016/j.bonr.2021.101144'
# 411 done
# '10.1016/j.mcat.2022.112909'
# 412 done
# '10.1016/j.solidstatesciences.2017.08.022'
# 413 done
# '10.1016/j.tetlet.2021.153604'
# 414 done
# '10.1016/j.microc.2022.107738'
# 415 done
# '10.1016/j.tet.2022.133094'
# 416 done
# '10.1016/j.enmm.2020.100364'
# 417 done
# '10.1053/j.gastro.2022.06.071'
# 418 done
# '10.1016/j.addbeh.2022.107367'
# 419 done
# '10.1016/j.jceh.2022.04.010'
# 420 done
# '10.1016/j.micromeso.2022.112121'
# 421 done
# '10.1016/j.memsci.2022.120777'
# 422 done
# '10.1016/j.fbio.2022.101794'
# 423 done
# '10.1016/j.jct.2022.106930'
# 424 done
# '10.1071/HI12006'
# 425 done
# '10.1016/j.tet.2021.132213'
# 426 done
# '10.1016/j.carbon.2022.12.028'
# 427 done
# '10.1016/j.ypmed.2022.107139'
# 428 done
# '10.1016/j.mcat.2022.112558'
# 429 done
# '10.1016/j.chemphys.2022.111596'
# 430 done
# '10.1016/j.addbeh.2022.107417'
# 431 done
# '10.1016/j.neuropharm.2022.109376'
# 432 done
# '10.1016/j.cej.2022.134545'
# 433 done
# '10.1016/j.tetlet.2014.12.092'
# 434 done
# '10.1016/j.jechem.2022.05.021'
# 435 done
# '10.1016/j.reactfunctpolym.2020.104635'
# 436 done
# '10.1016/j.chroma.2013.03.052'
# 437 done
# '10.1016/j.catcom.2023.106606'
# 438 done
# '10.1016/j.cep.2022.109038'
# 439 done
# '10.1016/j.tet.2022.132993'
# 440 done
# '10.1016/j.renene.2022.06.088'
# 441 done
# '10.1016/j.polymer.2019.121581'
# 442 done
# '10.1016/j.steroids.2014.06.011'
# 443 done
# '10.1016/j.nano.2018.08.003'
# 444 done
# '10.1016/j.mcat.2022.112874'
# 445 done
# '10.1016/j.mtcomm.2022.105153'
# 446 done
# '10.1016/j.physbeh.2021.113688'
# 447 done
# '10.1016/j.mcat.2022.112456'
# 448 done
# '10.1016/j.ica.2022.121034'
# 449 done
# '10.1016/j.apcatb.2021.120195'
# 450 done
# '10.1016/j.fuel.2022.126308'
# 451 done
# '10.1016/j.ijbiomac.2021.09.113'
# 452 done
# '10.1016/j.fbp.2021.07.008'
# 453 done
# '10.1016/j.crci.2016.03.004'
# 454 done
# '10.1016/j.rcpeng.2020.06.003'
# 455 done
# '10.1016/j.rser.2021.111211'
# 456 done
# '10.1016/j.jenvman.2022.116130'
# 457 done
# '10.1016/S1872-5813(16)30009-3'
# 458 done
# '10.1016/j.jcis.2022.10.087'
# 459 done
# '10.1016/j.colsurfa.2022.130313'
# 460 done
# '10.1016/j.polymer.2020.122885'
# 461 done
# '10.1016/j.apcata.2012.07.005'
# 462 done
# '10.1016/j.seppur.2021.119969'
# 463 done
# '10.1016/j.orgel.2022.106653'
# 464 done
# '10.1016/j.jceh.2022.03.003'
# 465 done
# '10.1016/j.apsusc.2021.151370'
# 466 done
# '10.1016/j.phymed.2022.154113'
# 467 done
# '10.1016/j.forc.2022.100404'
# 468 done
# '10.1016/j.yrtph.2016.12.010'
# 469 done
# '10.1016/j.tetlet.2013.06.047'
# 470 done
# '10.1016/j.addbeh.2022.107278'
# 471 done
# '10.1016/j.tetlet.2009.06.136'
# 472 done
# '10.1016/j.carbpol.2021.118816'
# 473 done
# '10.1016/j.tetasy.2010.04.025'
# 474 done
# '10.1016/j.jbc.2022.102445'
# 475 done
# '10.1016/j.jcat.2023.01.015'
# 476 done
# '10.1016/j.mcat.2020.111311'
# 477 done
# '10.1016/j.apcata.2009.07.014'
# 478 done
# '10.1016/j.cclet.2012.07.010'
# 479 done
# '10.1016/j.fpsl.2022.100848'
# 480 done
# '10.1016/j.jddst.2020.101530'
# 481 done
# '10.1016/j.apsusc.2021.151506'
# 482 done
# '10.1016/j.electacta.2022.139998'
# 483 done
# '10.1016/j.mcat.2022.112458'
# 484 done
# '10.1016/j.jsat.2022.108825'
# 485 done
# '10.1016/j.ijhydene.2020.08.050'
# 486 done
# '10.1016/j.apcata.2022.118574'
# 487 done
# '10.1016/j.apcatb.2022.121904'
# 488 done
# '10.1016/j.drugalcdep.2022.109572'
# 489 done
# '10.1016/j.neuropharm.2021.108937'
# 490 done
# '10.1016/j.isci.2022.105119'
# 491 done
# '10.1016/j.cclet.2022.04.077'
# 492 done
# '10.1016/j.ijbiomac.2022.09.083'
# 493 done
# '10.1016/j.psep.2022.04.022'
# 494 done
# '10.1016/j.jcis.2022.01.024'
# 495 done
# '10.1016/j.ijbiomac.2022.08.061'
# 496 done
# '10.1016/j.ijbiomac.2020.08.115'
# 497 done
# '10.1016/j.arabjc.2022.104074'
# 498 done
# '10.1016/j.jece.2021.106431'
# 499 done
# '10.1016/j.apcata.2022.118527'
# 500 done
# '10.1016/j.cej.2022.136578'
# 501 done
# '10.1016/j.tet.2014.05.014'
# 502 done
# '10.1016/j.abb.2022.109236'
# 503 done
# '10.1016/j.diamond.2023.109697'
# 504 done
# '10.1016/j.micromeso.2020.110706'
# 505 done
# '10.1016/j.midw.2022.103335'
# 506 done
# '10.1016/j.applthermaleng.2022.119031'
# 507 done
# '10.1016/j.jtemb.2022.126922'
# 508 done
# '10.1016/j.ijbiomac.2019.03.015'
# 509 done
# '10.1016/j.jallcom.2022.166645'
# 510 done
# '10.1016/j.catcom.2022.106423'
# 511 done
# '10.1016/j.cjche.2022.07.022'
# 512 done
# '10.1016/j.jpowsour.2022.232128'
# 513 done
# '10.1016/j.heliyon.2022.e11348'
# 514 done
# '10.1016/j.polymer.2021.123660'
# 515 done
# '10.1016/j.apcata.2022.118816'
# 516 done
# '10.1016/j.apcatb.2022.121271'
# 517 done
# '10.1016/j.mtcomm.2020.101489'
# 518 done
# '10.1016/j.jcou.2022.101914'
# 519 done
# '10.1016/j.ijso.2016.02.002'
# 520 done
# '10.1016/j.brainres.2022.147901'
# 521 done
# '10.1016/j.apsusc.2018.12.067'
# 522 done
# '10.1016/j.cogsc.2021.100548'
# 523 done
# '10.1016/j.jddst.2022.103781'
# 524 done
# '10.1016/j.micres.2022.127021'
# 525 done
# '10.1016/j.cyto.2022.155901'
# 526 done
# '10.1016/j.fuel.2021.122780'
# 527 done
# '10.1016/j.apcatb.2022.121583'
# 528 done
# '10.1016/j.jhin.2018.10.004'
# 529 done
# '10.1016/j.mencom.2022.07.026'
# 530 done
# '10.1016/j.jics.2021.100304'
# 531 done
# '10.1016/j.molcata.2012.11.004'
# 532 done
# '10.1016/j.inoche.2022.109513'
# 533 done
# '10.1016/j.jcou.2021.101744'
# 534 done
# '10.1016/j.jcis.2022.06.105'
# 535 done
# '10.1016/j.rcpeng.2020.11.004'
# 536 done
# '10.1016/j.solidstatesciences.2022.107026'
# 537 done
# '10.1016/j.ces.2022.117627'
# 538 done
# '10.1016/j.tetlet.2021.153370'
# 539 done
# '10.1016/j.matpr.2016.04.135'
# 540 done
# '10.1016/j.jssc.2022.123628'
# 541 done
# '10.1016/j.jhin.2017.10.021'
# 542 done
# '10.1016/j.appet.2021.105173'
# 543 done
# '10.1016/j.jece.2018.06.049'
# 544 done
# '10.1016/j.ajic.2015.03.034'
# 545 done
# '10.1016/j.exppara.2022.108399'
# 546 done
# '10.1016/j.apcatb.2022.122301'
# 547 done
# '10.1016/j.janxdis.2022.102615'
# 548 done
# '10.1016/j.jcat.2021.12.024'
# 549 done
# '10.1016/j.fluid.2021.112949'
# 550 done
# '10.1016/j.foodchem.2021.131943'
# 551 done
# '10.1016/j.drugpo.2022.103810'
# 552 done
# '10.1016/j.fuel.2022.125055'
# 553 done
# '10.1016/j.fuproc.2022.107378'
# 554 done
# '10.1016/j.molliq.2022.120937'
# 555 done
# '10.1016/j.apsusc.2022.153851'
# 556 done
# '10.1016/j.est.2022.105761'
# 557 done
# '10.1016/j.foodres.2022.111971'
# 558 done
# '10.1016/j.psep.2022.02.027'
# 559 done
# '10.1016/S1473-3099(20)30738-6'
# 560 done
# '10.1016/j.ijbiomac.2020.08.095'
# 561 done
# '10.1016/j.molstruc.2022.133163'
# 562 done
# '10.1016/j.ijbiomac.2022.12.169'
# 563 done
# '10.1016/j.jeurceramsoc.2011.02.001'
# 564 done
# '10.1016/j.apcatb.2022.121665'
# 565 done
# '10.1016/j.jece.2022.107382'
# 566 done
# '10.1016/j.jece.2021.106416'
# 567 done
# '10.1016/j.ijbiomac.2022.09.139'
# 568 done
# '10.1016/j.apcata.2021.118158'
# 569 done
# '10.1016/j.foodres.2022.111283'
# 570 done
# '10.1016/j.tetlet.2022.153838'
# 571 done
# '10.1016/j.cej.2022.139526'
# 572 done
# '10.1016/j.ssmqr.2022.100080'
# 573 done
# '10.1016/j.tetlet.2022.154129'
# 574 done
# '10.1016/j.drugalcdep.2022.109440'
# 575 done
# '10.1016/j.cmet.2021.12.024'
# 576 done
# '10.1016/j.drugalcdep.2022.109444'
# 577 done
# '10.1016/j.forsciint.2021.111147'
# 578 done
# '10.1016/j.cjche.2022.07.001'
# 579 done
# '10.1016/j.ceramint.2020.07.204'
# 580 done
# '10.1016/j.apcata.2014.06.023'
# 581 done
# '10.1016/j.chroma.2009.09.049'
# 582 done
# '10.1016/j.apsusc.2018.07.045'
# 583 done
# '10.1016/j.fuel.2022.124898'
# 584 done
# '10.1016/j.bcp.2022.115224'
# 585 done
# '10.1016/j.jceh.2022.01.010'
# 586 done
# '10.1016/j.ijpharm.2022.122114'
# 587 done
# '10.1016/j.apsusc.2021.151846'
# 588 done
# '10.1016/j.tetlet.2008.11.019'
# 589 done
# '10.1016/j.ijbiomac.2022.11.323'
# 590 done
# '10.1016/j.ijbiomac.2022.06.150'
# 591 done
# '10.1016/j.jceh.2022.06.012'
# 592 done
# '10.1016/j.catcom.2022.106540'
# 593 done
# '10.1016/j.egyr.2022.05.239'
# 594 done
# '10.1016/j.jceh.2022.12.006'
# 595 done
# '10.1016/j.drugalcdep.2021.109178'
# 596 done
# '10.1016/j.psychres.2021.113915'
# 597 done
# '10.1016/j.cpnec.2020.100022'
# 598 done
# '10.1016/j.foodchem.2023.135459'
# 599 done
# '10.1016/j.electacta.2012.02.094'
# 600 done
# '10.1016/j.addbeh.2021.106969'
# 601 done
# '10.1016/j.jmmm.2020.166953'
# 602 done
# '10.1016/j.jsat.2021.108693'
# 603 done
# '10.1016/j.tetasy.2008.05.018'
# 604 done
# '10.1016/j.neuropharm.2021.108564'
# 605 done
# '10.1016/j.inoche.2021.108842'
# 606 done
# '10.1016/j.jmrt.2019.09.074'
# 607 done
# '10.1016/j.fuel.2022.124134'
# 608 done
# '10.1016/j.jmmm.2010.06.025'
# 609 done
# '10.1016/j.conbuildmat.2022.129879'
# 610 done
# '10.1016/j.compositesb.2014.09.020'
# 611 done
# '10.1016/j.cjca.2022.04.009'
# 612 done
# '10.1016/j.carbpol.2017.10.014'
# 613 done
# '10.1016/j.addbeh.2021.106946'
# 614 done
# '10.1016/j.fuel.2022.124265'
# 615 done
# '10.1016/j.mcat.2022.112167'
# 616 done
# '10.1016/j.matdes.2021.110186'
# 617 done
# '10.1016/j.jcis.2020.02.053'
# 618 done
# '10.1016/j.carbpol.2022.120085'
# 619 done
# '10.1016/j.snb.2011.03.014'
# 620 done
# '10.1016/j.indcrop.2022.115203'
# 621 done
# '10.1016/j.molcatb.2009.08.006'
# 622 done
# '10.1016/j.fuel.2010.04.014'
# 623 done
# '10.1016/j.neubiorev.2021.06.009'
# 624 done
# '10.1016/j.micromeso.2022.112140'
# 625 done
# '10.1016/j.seppur.2021.119112'
# 626 done
# '10.1016/j.bpc.2020.106459'
# 627 done
# '10.1016/j.ijbiomac.2022.07.220'
# 628 done
# '10.1016/j.microc.2021.106688'
# 629 done
# '10.1016/j.cej.2022.135885'
# 630 done
# '10.1016/j.fuel.2022.125786'
# 631 done
# '10.1016/j.nutos.2022.02.004'
# 632 done
# '10.1016/j.tetlet.2021.153428'
# 633 done
# '10.1016/j.chemosphere.2021.133444'
# 634 done
# '10.1016/j.poly.2022.115869'
# 635 done
# '10.1016/j.jcrysgro.2022.126514'
# 636 done
# '10.1016/j.chemosphere.2021.131587'
# 637 done
# '10.1016/j.matchemphys.2022.126752'
# 638 done
# '10.1016/j.chempr.2022.02.021'
# 639 done
# '10.1016/j.idh.2017.09.023'
# 640 done
# '10.1016/j.cej.2022.135635'
# 641 done
# '10.1016/j.porgcoat.2013.07.005'
# 642 done
# '10.1016/j.chroma.2022.463009'
# 643 done
# '10.1016/j.apcatb.2022.121437'
# 644 done
# '10.1016/j.apcatb.2006.10.026'
# 645 done
# '10.1016/j.jtice.2021.09.020'
# 646 done
# '10.1016/j.seppur.2022.122050'
# 647 done
# '10.1016/j.alcohol.2022.07.001'
# 648 done
# '10.1016/j.vacuum.2021.110767'
# 649 done
# '10.1016/j.foodres.2022.111095'
# 650 done
# '10.1016/j.trsl.2021.10.008'
# 651 done
# '10.1016/j.fuproc.2017.08.012'
# 652 done
# '10.1016/j.drugalcdep.2022.109276'
# 653 done
# '10.1016/j.ijpharm.2008.04.035'
# 654 done
# '10.1016/j.clay.2022.106510'
# 655 done
# '10.1016/j.ijbiomac.2018.07.073'
# 656 done
# '10.1016/j.jallcom.2022.164626'
# 657 done
# '10.1016/j.fuel.2021.122121'
# 658 done
# '10.1016/j.addbeh.2021.107219'
# 659 done
# '10.1016/j.jcat.2013.01.020'
# 660 done
# '10.1016/j.jcat.2022.02.018'
# 661 done
# '10.1016/j.catcom.2020.105946'
# 662 done
# '10.1016/j.tetlet.2007.12.121'
# 663 done
# '10.1016/j.jpsychores.2022.111137'
# 664 done
# '10.1016/j.jcis.2023.01.027'
# 665 done
# '10.1016/j.fuel.2022.124441'
# 666 done
# '10.1016/j.cca.2021.11.013'
# 667 done
# '10.1016/j.jmrt.2022.07.133'
# 668 done
# '10.1016/j.ijhydene.2022.09.100'
# 669 done
# '10.1016/j.jece.2022.107814'
# 670 done
# '10.1016/j.optmat.2022.112981'
# 671 done
# '10.1016/j.chemosphere.2021.131558'
# 672 done
# '10.1016/j.foodres.2022.112278'
# 673 done
# '10.1016/j.gresc.2021.11.006'
# 674 done
# '10.1016/j.chroma.2018.04.045'
# 675 done
# '10.1016/j.cej.2021.132681'
# 676 done
# '10.1016/j.drugalcdep.2021.109248'
# 677 done
# '10.1016/j.bmc.2008.11.023'
# 678 done
# '10.1016/j.jfluchem.2008.09.014'
# 679 done
# '10.1016/j.apcatb.2022.121575'
# 680 done
# '10.1016/j.est.2021.103918'
# 681 done
# '10.1016/j.seppur.2014.03.018'
# 682 done
# '10.1016/j.jechem.2022.02.033'
# 683 done
# '10.1016/j.jiec.2022.03.002'
# 684 done
# '10.1016/j.ijbiomac.2022.06.094'
# 685 done
# '10.1016/j.matchemphys.2022.126650'
# 686 done
# '10.1016/j.molliq.2022.119064'
# 687 done
# '10.1016/j.neuropharm.2020.108337'
# 688 done
# '10.1016/j.jphotochem.2022.114020'
# 689 done
# '10.1016/j.catcom.2012.08.027'
# 690 done
# '10.1016/j.apcata.2022.118502'
# 691 done
# '10.1016/j.eurpolymj.2022.111750'
# 692 done
# '10.1016/j.aap.2021.106455'
# 693 done
# '10.1016/j.bioadv.2022.213069'
# 694 done
# '10.1016/j.cattod.2021.12.011'
# 695 done
# '10.1016/j.poly.2021.115581'
# 696 done
# '10.1016/j.drugpo.2021.103530'
# 697 done
# '10.1016/j.jcou.2022.102085'
# 698 done
# '10.1016/j.mimet.2021.106402'
# 699 done
# '10.1016/j.isci.2022.104010'
# 700 done
# '10.1016/j.cattod.2022.05.038'
# 701 done
# '10.1016/j.jcis.2005.09.067'
# 702 done
# '10.1016/j.mseb.2014.01.011'
# 703 done
# '10.1016/j.eurpolymj.2018.01.005'
# 704 done
# '10.1016/j.foodres.2022.111763'
# 705 done
# '10.1016/j.memsci.2022.121185'
# 706 done
# '10.1016/j.tetasy.2011.11.019'
# 707 done
# '10.1016/j.jcat.2017.10.006'
# 708 done
# '10.1016/j.chempr.2021.10.023'
# 709 done
# '10.1016/j.neulet.2021.136092'
# 710 done
# '10.1016/j.euf.2022.02.005'
# 711 done
# '10.1016/j.drugalcdep.2021.108942'
# 712 done
# '10.1016/j.drugalcdep.2021.109082'
# 713 done
# '10.1016/j.ces.2022.118120'
# 714 done
# '10.1016/j.tetlet.2019.02.045'
# 715 done
# '10.1016/j.fpsl.2022.100914'
# 716 done
# '10.1016/j.indcrop.2022.116074'
# 717 done
# '10.1016/j.alcohol.2021.08.004'
# 718 done
# '10.1016/j.tetasy.2008.07.012'
# 719 done
# '10.1016/j.drugalcdep.2021.109142'
# 720 done
# '10.1016/j.fct.2021.112759'
# 721 done
# '10.1016/j.drugalcdep.2021.108990'
# 722 done
# '10.1016/j.molliq.2021.118384'
# 723 done
# '10.1016/j.jinorgbio.2022.111784'
# 724 done
# '10.1016/j.jcou.2018.09.005'
# 725 done
# '10.1016/j.addbeh.2021.106836'
# 726 done
# '10.1016/j.bmc.2007.08.045'
# 727 done
# '10.1016/j.catcom.2012.09.027'
# 728 done
# '10.1016/j.jiac.2022.01.023'
# 729 done
# '10.1016/j.scitotenv.2021.145914'
# 730 done
# '10.1016/j.molliq.2021.116064'
# 731 done
# '10.1016/j.mssp.2019.104586'
# 732 done
# '10.1016/j.bmcl.2007.11.065'
# 733 done
# '10.1016/j.ijhydene.2021.11.070'
# 734 done
# '10.1016/j.colsurfa.2022.128559'
# 735 done
# '10.1016/j.mcat.2020.111182'
# 736 done
# '10.1016/j.matdes.2022.110502'
# 737 done
# '10.1016/j.bej.2021.108053'
# 738 done
# '10.1053/j.jfas.2018.08.042'
# 739 done
# '10.1016/j.gee.2022.01.015'
# 740 done
# '10.1016/j.tet.2005.08.114'
# 741 done
# '10.1016/j.gee.2022.03.001'
# 742 done
# '10.1016/j.enconman.2021.114822'
# 743 done
# '10.1016/j.ultsonch.2011.11.007'
# 744 done
# '10.1016/j.electacta.2021.139493'
# 745 done
# '10.1016/j.jiac.2021.02.027'
# 746 done
# '10.1016/j.jfluchem.2015.09.001'
# 747 done
# '10.1016/j.eurpolymj.2023.111826'
# 748 done
# '10.1016/j.mcat.2022.112391'
# 749 done
# '10.1016/j.eurpolymj.2018.07.024'
# 750 done
# '10.1016/j.jtice.2022.104492'
# 751 done
# '10.1016/j.jad.2021.06.043'
# 752 done
# '10.1016/j.physb.2022.414189'
# 753 done
# '10.1016/j.cattod.2022.03.008'
# 754 done
# '10.1016/j.tetlet.2012.03.042'
# 755 done
# '10.1016/j.jacep.2020.11.026'
# 756 done
# '10.1016/j.addbeh.2020.106605'
# 757 done
# '10.1016/j.fuel.2022.126261'
# 758 done
# '10.1016/j.eurpolymj.2021.110974'
# 759 done
# '10.1016/j.biosx.2022.100147'
# 760 done
# '10.1016/j.invent.2021.100474'
# 761 done
# '10.1016/j.combustflame.2021.02.008'
# 762 done
# '10.1016/j.pnpbp.2021.110460'
# 763 done
# '10.1016/j.jad.2022.06.091'
# 764 done
# '10.1016/j.apcatb.2021.120739'
# 765 done
# '10.1016/j.jphotochem.2022.114516'
# 766 done
# '10.1016/j.molliq.2021.116875'
# 767 done
# '10.1016/j.jpba.2021.114426'
# 768 done
# '10.1016/j.foodres.2022.111647'
# 769 done
# '10.1016/S1872-2067(21)63931-1'
# 770 done
# '10.1016/j.memsci.2016.04.007'
# 771 done
# '10.1016/j.brainres.2021.147587'
# 772 done
# '10.1016/j.apsusc.2022.153250'
# 773 done
# '10.1016/j.addbeh.2022.107261'
# 774 done
# '10.1016/j.molliq.2016.09.011'
# 775 done
# '10.1016/j.apsusc.2022.153899'
# 776 done
# '10.1016/j.colsurfa.2021.127520'
# 777 done
# '10.1016/j.matlet.2011.08.047'
# 778 done
# '10.1016/j.fpsl.2022.101013'
# 779 done
# '10.1016/j.mcat.2022.112553'
# 780 done
# '10.1016/j.jcis.2015.11.074'
# 781 done
# '10.1016/j.electacta.2021.139645'
# 782 done
# '10.1016/j.eurpolymj.2008.08.024'
# 783 done
# '10.1016/j.apcatb.2022.121155'
# 784 done
# '10.1016/j.ijhydene.2014.08.055'
# 785 done
# '10.1016/j.jcis.2022.12.101'
# 786 done
# '10.1016/j.drugalcdep.2021.108908'
# 787 done
# '10.1016/j.nbd.2022.105610'
# 788 done
# '10.1016/j.inoche.2020.108081'
# 789 done
# '10.1016/j.cattod.2022.07.007'
# 790 done
# '10.1016/j.alcohol.2021.06.004'
# 791 done
# '10.1016/j.memsci.2022.120954'
# 792 done
# '10.1016/j.molliq.2017.12.032'
# 793 done
# '10.1016/j.poly.2022.115787'
# 794 done
# '10.1016/j.jgar.2018.12.008'
# 795 done
# '10.1016/j.bios.2020.112702'
# 796 done
# '10.1016/j.matchemphys.2015.02.011'
# 797 done
# '10.1016/j.apcatb.2022.121260'
# 798 done
# '10.1016/j.mtcomm.2022.104316'
# 799 done
# '10.1016/j.jorganchem.2021.122043'
# 800 done
# '10.1016/j.rechem.2022.100483'
# 801 done
# '10.1016/j.compscitech.2022.109801'
# 802 done
# '10.1016/j.jaim.2021.02.001'
# 803 done
# '10.1016/j.apcatb.2021.120556'
# 804 done
# '10.1016/j.mtsust.2021.100102'
# 805 done
# '10.1016/j.matchemphys.2016.05.002'
# 806 done
# '10.1016/S1003-6326(08)60061-8'
# 807 done
# '10.1016/j.electacta.2018.02.043'
# 808 done
# '10.1016/j.indcrop.2014.04.023'
# 809 done
# '10.1016/j.poly.2020.114979'
# 810 done
# '10.1016/j.jnoncrysol.2012.06.012'
# 811 done
# '10.1016/j.matdes.2018.07.054'
# 812 done
# '10.1016/j.matchemphys.2012.04.065'
# 813 done
# '10.1016/j.amjsurg.2020.12.026'
# 814 done
# '10.1016/j.addbeh.2021.106967'
# 815 done
# '10.1016/j.jpcs.2021.110527'
# 816 done
# '10.1016/j.energy.2022.126166'
# 817 done
# '10.1016/j.matchemphys.2020.124152'
# 818 done
# '10.1016/j.joei.2021.06.002'
# 819 done
# '10.1016/j.seppur.2007.05.019'
# 820 done
# '10.1016/j.psychres.2021.114068'
# 821 done
# '10.1016/j.matdes.2017.07.052'
# 822 done
# '10.1016/j.microc.2021.106578'
# 823 done
# '10.1016/j.biortech.2021.126296'
# 824 done
# '10.1016/j.bmcl.2021.128270'
# 825 done
# '10.1016/j.jcat.2021.05.028'
# 826 done
# '10.1016/j.fluid.2021.113363'
# 827 done
# '10.1016/j.drugalcdep.2021.109117'
# 828 done
# '10.1016/j.drugalcdep.2021.109007'
# 829 done
# '10.1016/j.carres.2012.08.009'
# 830 done
# '10.1016/j.desal.2014.09.024'
# 831 done
# '10.1016/j.molcata.2012.05.021'
# 832 done
# '10.1016/j.elecom.2021.106939'
# 833 done
# '10.1016/j.lwt.2020.110805'
# 834 done
# '10.1016/j.drugpo.2021.103547'
# 835 done
# '10.1016/j.jct.2022.106945'
# 836 done
# '10.1016/j.micromeso.2021.111514'
# 837 done
# '10.1016/j.amepre.2020.08.009'
# 838 done
# '10.1016/j.colsurfa.2009.03.057'
# 839 done
# '10.1016/j.mcat.2021.111932'
# 840 done
# '10.1016/j.cscm.2022.e01466'
# 841 done
# '10.1016/j.carbpol.2011.01.049'
# 842 done
# '10.1016/j.carbpol.2009.09.029'
# 843 done
# '10.1016/j.neuro.2022.03.009'
# 844 done
# '10.1016/j.cca.2021.05.024'
# 845 done
# '10.1016/j.jcis.2021.11.039'
# 846 done
# '10.1016/j.matchemphys.2010.01.045'
# 847 done
# '10.1016/j.cej.2021.133211'
# 848 done
# '10.1016/j.jcat.2022.02.007'
# 849 done
# '10.1016/j.polymertesting.2022.107786'
# 850 done
# '10.1016/j.ces.2021.116847'
# 851 done
# '10.1016/j.molliq.2018.10.087'
# 852 done
# '10.1016/j.invent.2022.100517'
# 853 done
# '10.1016/j.memsci.2016.02.060'
# 854 done
# '10.1016/j.indcrop.2022.115319'
# 855 done
# '10.1016/j.jviromet.2021.114292'
# 856 done
# '10.1016/j.polymdegradstab.2009.11.017'
# 857 done
# '10.1016/j.crci.2013.07.008'
# 858 done
# '10.1016/j.fuel.2022.123975'
# 859 done
# '10.1016/j.fbio.2023.102397'
# 860 done
# '10.1016/j.seppur.2022.122547'
# 861 done
# '10.1016/j.apcata.2022.118640'
# 862 done
# '10.1016/j.addbeh.2021.107083'
# 863 done
# '10.1016/j.jchromb.2018.11.014'
# 864 done
# '10.1016/j.indcrop.2021.114012'
# 865 done
# '10.1016/j.powtec.2022.117685'
# 866 done
# '10.1016/j.colsurfa.2020.126048'
# 867 done
# '10.1016/j.apcata.2022.118537'
# 868 done
# '10.1016/j.ceramint.2006.08.003'
# 869 done
# '10.1016/j.synthmet.2022.117122'
# 870 done
# '10.1016/j.jcat.2022.04.023'
# 871 done
# '10.1016/j.drugalcdep.2020.108304'
# 872 done
# '10.1016/j.solmat.2022.112076'
# 873 done
# '10.1016/j.brainresbull.2022.02.017'
# 874 done
# '10.1016/j.drugalcdep.2021.108753'
# 875 done
# '10.1016/j.apcatb.2021.121031'
# 876 done
# '10.1016/j.neuropharm.2021.108713'
# 877 done
# '10.1016/j.gee.2020.11.019'
# 878 done
# '10.1016/j.tetlet.2006.11.128'
# 879 done
# '10.1016/j.jhepr.2021.100325'
# 880 done
# '10.1016/j.alcohol.2020.10.003'
# 881 done
# '10.1016/j.polymer.2017.01.051'
# 882 done
# '10.1016/j.tet.2008.09.098'
# 883 done
# '10.1016/j.jcat.2022.07.025'
# 884 done
# '10.1016/j.carbpol.2018.01.061'
# 885 done
# '10.1016/j.memsci.2007.12.029'
# 886 done
# '10.1016/j.matlet.2006.08.047'
# 887 done
# '10.1016/j.mjafi.2020.01.002'
# 888 done
# '10.1016/j.tet.2006.03.030'
# 889 done
# '10.1016/j.alcohol.2021.10.003'
# 890 done
# '10.1016/j.carbpol.2022.119729'
# 891 done
# '10.1016/j.jcat.2022.02.023'
# 892 done
# '10.1016/j.ccc.2021.03.009'
# 893 done
# '10.1016/j.jscai.2022.100396'
# 894 done
# '10.1016/j.ultsonch.2006.09.009'
# 895 done
# '10.1016/j.porgcoat.2022.106951'
# 896 done
# '10.1016/j.apcatb.2021.121028'
# 897 done
# '10.1016/j.jpba.2022.114615'
# 898 done
# '10.1016/j.polymer.2022.125129'
# 899 done
# '10.1016/j.polymer.2022.125048'
# 900 done
# '10.1016/j.reactfunctpolym.2022.105212'
# 901 done
# '10.1016/j.steroids.2021.108917'
# 902 done
# '10.1016/j.carbpol.2018.03.015'
# 903 done
# '10.1016/j.ultsonch.2006.09.009'
# 904 done
# '10.1016/j.jcat.2022.10.001'
# 905 done
# '10.1016/j.cej.2009.10.063'
# 906 done
# '10.1016/j.drugalcdep.2021.108813'
# 907 done
# '10.1016/j.mcat.2022.112135'
# 908 done
# '10.1016/j.drugalcdep.2021.108975'
# 909 done
# '10.1016/j.jorganchem.2021.122025'
# 910 done
# '10.1016/j.mssp.2010.10.018'
# 911 done
# '10.1016/j.scib.2022.11.024'
# 912 done
# '10.1016/j.cbi.2022.110039'
# 913 done
# '10.1016/j.mcat.2021.112066'
# 914 done
# '10.1016/j.taap.2022.115923'
# 915 done
# '10.1016/j.jcat.2022.01.010'
# 916 done
# '10.1016/j.drugalcdep.2021.108607'
# 917 done
# '10.1016/j.colsurfb.2018.09.074'
# 918 done
# '10.1016/j.addbeh.2020.106786'
# 919 done
# '10.1016/j.jsat.2022.108831'
# 920 done
# '10.1016/j.micromeso.2022.111949'
# 921 done
# '10.1016/j.neuropharm.2022.109074'
# 922 done
# '10.1016/j.colcom.2022.100608'
# 923 done
# '10.1016/j.molliq.2021.117349'
# 924 done
# '10.1016/j.jmbbm.2022.105427'
# 925 done
# '10.1016/j.solidstatesciences.2020.106284'
# 926 done
# '10.1016/S0957-4166(03)00373-2'
# 927 done
# '10.1016/j.ijbiomac.2014.09.040'
# 928 done
# '10.1016/j.drugalcdep.2021.109088'
# 929 done
# '10.1016/j.drugalcdep.2021.109150'
# 930 done
# '10.1016/j.mcat.2021.111749'
# 931 done
# '10.1016/j.tetlet.2005.01.025'
# 932 done
# '10.1016/j.matlet.2017.07.058'
# 933 done
# '10.1016/j.desal.2009.04.006'
# 934 done
# '10.1016/j.neuropharm.2021.108560'
# 935 done
# '10.1016/S0040-4039(03)01025-6'
# 936 done
# '10.1016/j.solmat.2015.04.014'
# 937 done
# '10.1016/j.ceramint.2020.02.179'
# 938 done
# '10.1016/j.addbeh.2021.106915'
# 939 done
# '10.1016/j.fuel.2019.116042'
# 940 done
# '10.1016/j.intimp.2022.109326'
# 941 done
# '10.1016/j.foodres.2021.110598'
# 942 done
# '10.1016/j.supflu.2022.105696'
# 943 done
# '10.1016/j.jece.2021.106793'
# 944 done
# '10.1016/j.mseb.2022.116222'
# 945 done
# '10.1016/j.jechem.2021.03.033'
# 946 done
# '10.1016/B978-0-12-812709-4.00006-8'
# 947 done
# '10.1016/j.jece.2022.107355'
# 948 done
# '10.1016/j.matlet.2022.133264'
# 949 done
# '10.1016/j.medcle.2015.07.007'
# 950 done
# '10.1016/j.jcat.2019.08.004'
# 951 done
# '10.1016/j.arabjc.2018.01.010'
# 952 done
# '10.1016/j.mtcomm.2022.104834'
# 953 done
# '10.1016/j.jff.2019.01.014'
# 954 done
# '10.1016/j.pmedr.2021.101674'
# 955 done
# '10.1016/j.alcohol.2020.02.164'
# 956 done
# '10.1016/j.afres.2022.100237'
# 957 done
# '10.1016/j.csite.2021.101385'
# 958 done
# '10.1016/j.poly.2022.115728'
# 959 done
# '10.1016/j.tet.2010.08.015'
# 960 done
# '10.1016/j.memsci.2022.120326'
# 961 done
# '10.1016/j.jfca.2022.104558'
# 962 done
# '10.1016/S1872-2067(19)63429-7'
# 963 done
# '10.1016/j.matlet.2016.07.130'
# 964 done
# '10.1016/j.jtice.2017.06.009'
# 965 done
# '10.1016/j.bios.2021.113530'
# 966 done
# '10.1016/j.mcat.2022.112144'
# 967 done
# '10.1016/j.cjche.2022.10.005'
# 968 done
# '10.1016/j.cattod.2021.06.030'
# 969 done
# '10.1016/j.tetasy.2015.04.009'
# 970 done
# '10.1016/j.molliq.2022.120226'
# 971 done
# '10.1016/j.fuel.2021.121321'
# 972 done
# '10.1016/j.xpro.2022.101564'
# 973 done
# '10.1016/S1872-2067(19)63313-9'
# 974 done
# '10.1016/j.alcohol.2021.03.004'
# 975 done
# '10.1016/j.jphotochem.2021.113452'
# 976 done
# '10.1016/j.ceramint.2012.07.062'
# 977 done
# '10.1016/j.micromeso.2021.111235'
# 978 done
# '10.1016/j.polymertesting.2022.107784'
# 979 done
# '10.1016/j.tetlet.2005.08.008'
# 980 done
# '10.1016/j.eatbeh.2020.101409'
# 981 done
# '10.1016/j.eurpolymj.2022.111593'
# 982 done
# '10.1016/j.neulet.2022.136671'
# 983 done
# '10.1016/j.molcata.2004.09.078'
# 984 done
# '10.1016/j.apcata.2006.09.005'
# 985 done
# '10.1016/j.fpsl.2022.100991'
# 986 done
# '10.1016/j.neulet.2021.136014'
# 987 done
# '10.1016/j.ijhydene.2022.04.063'
# 988 done
# '10.1016/j.alcohol.2021.01.008'
# 989 done
# '10.1016/j.molcata.2006.01.024'
# 990 done
# '10.1016/j.matchemphys.2011.07.074'
# 991 done
# '10.1016/j.ijhydene.2016.04.133'
# 992 done
# '10.1016/j.drugalcdep.2020.108204'
# 993 done
# '10.1016/j.conbuildmat.2022.127400'
# 994 done
# '10.1016/j.jfoodeng.2022.111278'
# 995 done
# '10.1016/j.drugalcdep.2020.108481'
# 996 done
# '10.1016/j.ijbiomac.2022.05.119'
# 997 done
# '10.1016/j.addicn.2022.100044'
# 998 done
# '10.1016/j.fuel.2022.124024'
# 999 done
# '10.1016/j.addicn.2022.100044'
# 1000 done
# '10.1016/j.mcat.2021.111898'
# 1001 done
# '10.1016/j.desal.2011.12.003'
# 1002 done
# '10.1016/j.matlet.2017.01.123'
# 1003 done
# '10.1016/j.mcat.2021.111690'
# 1004 done
# '10.1016/j.tet.2022.132732'
# 1005 done
# '10.1016/j.ccr.2021.214257'
# 1006 done
# '10.1016/j.jsat.2021.108565'
# 1007 done
# '10.1016/j.jddst.2022.103298'
# 1008 done
# '10.1016/j.arabjc.2022.103766'
# 1009 done
# '10.1016/j.ijbiomac.2020.08.042'
# 1010 done
# '10.1016/j.foodchem.2022.133021'
# 1011 done
# '10.1016/j.flatc.2021.100248'
# 1012 done
# '10.1016/j.apcata.2020.117965'
# 1013 done
# '10.1016/j.mtcomm.2023.105315'
# 1014 done
# '10.1016/j.matlet.2006.07.078'
# 1015 done
# '10.1016/j.jcat.2021.08.040'
# 1016 done
# '10.1016/j.ajic.2012.04.060'
# 1017 done
# '10.1016/j.jiec.2021.07.039'
# 1018 done
# '10.1016/j.ijbiomac.2023.123187'
# 1019 done
# '10.1016/j.taap.2022.115949'
# 1020 done
# '10.1016/j.jhazmat.2022.130629'
# 1021 done
# '10.1016/j.jece.2021.106097'
# 1022 done
# '10.1016/j.lwt.2020.110031'
# 1023 done
# '10.1016/j.chemphys.2021.111110'
# 1024 done
# '10.1016/j.polymer.2020.122858'
# 1025 done
# '10.1016/j.ijpharm.2022.122383'
# 1026 done
# '10.1016/j.jcou.2021.101551'
# 1027 done
# '10.1016/j.jbiotec.2018.12.003'
# 1028 done
# '10.1016/j.msec.2021.112171'
# 1029 done
# '10.1016/j.molstruc.2021.130691'
# 1030 done
# '10.1016/j.matchemphys.2005.08.072'
# 1031 done
# '10.1016/j.drugpo.2021.103322'
# 1032 done
# '10.1016/j.jorganchem.2018.12.012'
# 1033 done
# '10.1016/j.apsusc.2022.156106'
# 1034 done
# '10.1016/j.jallcom.2008.08.073'
# 1035 done
# '10.1016/j.psep.2022.02.026'
# 1036 done
# '10.1016/j.reactfunctpolym.2021.104975'
# 1037 done
# '10.1016/j.rechem.2021.100150'
# 1038 done
# '10.1016/j.jcat.2022.07.011'
# 1039 done
# '10.1016/j.conbuildmat.2022.128320'
# 1040 done
# '10.1016/j.jmrt.2022.08.130'
# 1041 done
# '10.1016/S0957-4166(03)00454-3'
# 1042 done
# '10.1016/j.catcom.2020.106002'
# 1043 done
# '10.1016/j.jcat.2022.06.016'
# 1044 done
# '10.1016/j.indcrop.2022.115143'
# 1045 done
# '10.1016/j.jece.2021.106092'
# 1046 done
# '10.1016/j.jaubas.2014.01.003'
# 1047 done
# '10.1016/j.tetlet.2006.05.133'
# 1048 done
# '10.1016/j.rechem.2022.100603'
# 1049 done
# '10.1016/j.ijbiomac.2022.03.148'
# 1050 done
# '10.1016/j.memsci.2012.06.051'
# 1051 done
# '10.1016/j.jpcs.2012.12.001'
# 1052 done
# '10.1016/j.mpmed.2020.11.006'
# 1053 done
# '10.1016/j.jsamd.2020.01.002'
# 1054 done
# '10.1016/S0305-4179(00)00020-6'
# 1055 done
# '10.1016/j.lanepe.2021.100172'
# 1056 done
# '10.1016/j.molstruc.2019.03.008'
# 1057 done
# '10.1016/j.jsat.2021.108445'
# 1058 done
# '10.1016/j.mtcomm.2022.103475'
# 1059 done
# '10.1016/j.radphyschem.2022.110338'
# 1060 done
# '10.1016/j.dib.2020.106442'
# 1061 done
# '10.1016/j.colsurfa.2022.128342'
# 1062 done
# '10.1016/j.tet.2010.05.066'
# 1063 done
# '10.1016/j.tet.2017.07.055'
# 1064 done
# '10.1016/j.jfluchem.2020.109629'
# 1065 done
# '10.1016/j.ajic.2012.04.323'
# 1066 done
# '10.1016/j.fm.2020.103713'
# 1067 done
# '10.1016/j.apcata.2021.118424'
# 1068 done
# '10.1016/j.biortech.2022.127875'
# 1069 done
# '10.1016/j.jtice.2021.09.038'
# 1070 done
# '10.1016/j.cherd.2021.12.023'
# 1071 done
# '10.1016/j.wneu.2021.09.007'
# 1072 done
# '10.1016/j.matpr.2020.02.648'
# 1073 done
# '10.1016/j.mtcomm.2022.104413'
# 1074 done
# '10.1016/j.healthplace.2021.102565'
# 1075 done
# '10.1016/j.arabjc.2022.104535'
# 1076 done
# '10.1016/j.foodchem.2022.132629'
# 1077 done
# '10.1016/j.jphotochem.2021.113726'
# 1078 done
# '10.1016/j.ijbiomac.2022.08.025'
# 1079 done
# '10.1016/j.apsusc.2021.151953'
# 1080 done
# '10.1016/j.drugalcdep.2020.107918'
# 1081 done
# '10.1016/j.physbeh.2021.113393'
# 1082 done
# '10.1016/j.desal.2005.07.037'
# 1083 done
# '10.1016/j.fct.2021.112353'
# 1084 done
# '10.1016/j.catcom.2020.106240'
# 1085 done
# '10.1016/j.ijbiomac.2022.12.014'
# 1086 done
# '10.1016/j.surfin.2022.102540'
# 1087 done
# '10.1016/j.cep.2015.03.010'
# 1088 done
# '10.1016/B978-0-12-822425-0.00095-6'
# 1089 done
# '10.1016/j.molliq.2021.116986'
# 1090 done
# '10.1016/j.jcat.2022.04.018'
# 1091 done
# '10.1016/j.renene.2021.05.059'
# 1092 done
# '10.1016/j.molstruc.2022.134164'
# 1093 done
# '10.1016/j.chroma.2006.10.088'
# 1094 done
# '10.1016/j.socscimed.2020.113307'
# 1095 done
# '10.1016/j.apcatb.2021.120619'
# 1096 done
# '10.1016/j.neuropharm.2020.108293'
# 1097 done
# '10.1016/j.reactfunctpolym.2012.04.006'
# 1098 done
# '10.1016/j.ejogrb.2021.01.027'
# 1099 done
# '10.1016/j.jddst.2022.103318'
# 1100 done
# '10.1016/j.ijbiomac.2013.06.050'
# 1101 done
# '10.1016/j.eurpolymj.2010.08.004'
# 1102 done
# '10.1016/j.drugalcdep.2021.109014'
# 1103 done
# '10.1016/j.tetlet.2021.153060'
# 1104 done
# '10.1016/j.materresbull.2010.06.018'
# 1105 done
# '10.1016/j.comptc.2021.113419'
# 1106 done
# '10.1016/j.neuroscience.2020.10.039'
# 1107 done
# '10.1016/j.addbeh.2021.106868'
# 1108 done
# '10.1016/j.neuropharm.2020.108293'
# 1109 done
# '10.1016/j.polymertesting.2022.107903'
# 1110 done
# '10.1016/j.est.2022.106202'
# 1111 done
# '10.1053/j.gastro.2021.05.048'
# 1112 done
# '10.1016/j.ssmqr.2021.100012'
# 1113 done
# '10.1016/j.jiec.2009.09.021'
# 1114 done
# '10.1016/j.matlet.2010.03.012'
# 1115 done
# '10.1016/j.foodhyd.2020.106252'
# 1116 done
# '10.1016/j.drugalcdep.2020.108496'
# 1117 done
# '10.1016/j.cclet.2016.06.037'
# 1118 done
# '10.1016/j.ijhydene.2022.12.055'
# 1119 done
# '10.1016/j.matpr.2020.10.481'
# 1120 done
# '10.1016/j.ntt.2021.106980'
# 1121 done
# '10.1016/j.beproc.2021.104340'
# 1122 done
# '10.1016/j.cplett.2022.139942'
# 1123 done
# '10.1016/j.biotechadv.2021.107787'
# 1124 done
# '10.1016/j.jclepro.2022.133988'
# 1125 done
# '10.1016/j.lwt.2021.111842'
# 1126 done
# '10.1016/j.ijbiomac.2022.11.281'
# 1127 done
# '10.1016/j.arabjc.2010.08.003'
# 1128 done
# '10.1016/j.apcata.2020.117832'
# 1129 done
# '10.1016/j.matchemphys.2022.126652'
# 1130 done
# '10.1016/j.jfoodeng.2022.111399'
# 1131 done
# '10.1016/j.rio.2022.100261'
# 1132 done
# '10.1016/j.materresbull.2019.110661'
# 1133 done
# '10.1016/j.cjche.2021.09.013'
# 1134 done
# '10.1016/j.jep.2021.114593'
# 1135 done
# '10.1016/j.tetlet.2021.153186'
# 1136 done
# '10.1016/j.tetlet.2011.03.033'
# 1137 done
# '10.1016/j.ccr.2021.213967'
# 1138 done
# '10.1016/j.jorganchem.2021.121930'
# 1139 done
# '10.1016/j.scitotenv.2021.149434'
# 1140 done
# '10.1016/j.ijpharm.2022.121459'
# 1141 done
# '10.1016/j.fshw.2021.04.012'
# 1142 done
# '10.1016/j.tetlet.2006.07.033'
# 1143 done
# '10.1016/j.aap.2021.106212'
# 1144 done
# '10.1016/j.matlet.2018.06.032'
# 1145 done
# '10.1016/j.lwt.2022.114407'
# 1146 done
# '10.1016/j.drugalcdep.2021.108586'
# 1147 done
# '10.1016/j.poly.2021.115289'
# 1148 done
# '10.1016/j.jechem.2022.03.016'
# 1149 done
# '10.1016/j.molstruc.2020.129285'
# 1150 done
# '10.1016/j.cej.2020.125768'
# 1151 done
# '10.1016/j.desal.2007.09.038'
# 1152 done
# '10.1016/j.apsusc.2017.03.216'
# 1153 done
# '10.1016/j.lwt.2021.110849'
# 1154 done
# '10.1016/j.drugalcdep.2022.109298'
# 1155 done
# '10.1016/j.ijbiomac.2021.09.189'
# 1156 done
# '10.1016/j.ijhydene.2022.03.192'
# 1157 done
# '10.1016/j.mtphys.2022.100928'
# 1158 done
# '10.1016/j.cej.2022.141176'
# 1159 done
# '10.1016/j.jcis.2020.11.112'
# 1160 done
# '10.1016/j.jallcom.2022.166650'
# 1161 done
# '10.1016/j.colsurfb.2021.112166'
# 1162 done
# '10.1016/j.apcatb.2021.120967'
# 1163 done
# '10.1016/j.carbpol.2022.120055'
# 1164 done
# '10.1016/j.apsusc.2017.11.191'
# 1165 done
# '10.1016/j.drugalcdep.2020.108027'
# 1166 done
# '10.1016/j.neuropharm.2021.108501'
# 1167 done
# '10.1016/j.ica.2021.120488'
# 1168 done
# '10.1016/j.desal.2005.08.023'
# 1169 done
# '10.1016/j.rser.2021.111702'
# 1170 done
# '10.1016/j.neulet.2020.135347'
# 1171 done
# '10.1016/j.vibspec.2022.103339'
# 1172 done
# '10.1016/j.jtice.2021.09.031'
# 1173 done
# '10.1016/j.jtice.2021.04.043'
# 1174 done
# '10.1016/j.yofte.2021.102782'
# 1175 done
# '10.1016/j.porgcoat.2021.106526'
# 1176 done
# '10.1016/j.puhe.2022.01.013'
# 1177 done
# '10.1016/j.jct.2021.106521'
# 1178 done
# '10.1016/j.mtcomm.2021.102502'
# 1179 done
# '10.1016/j.jconrel.2011.09.003'
# 1180 done
# '10.1016/j.compositesa.2015.06.019'
# 1181 done
# '10.1016/S0040-4039(02)01968-8'
# 1182 done
# '10.1016/j.euroneuro.2021.04.015'
# 1183 done
# '10.1016/j.jpsychires.2022.02.040'
# 1184 done
# '10.1016/j.neuroimage.2020.117435'
# 1185 done
# '10.1016/j.porgcoat.2022.107000'
# 1186 done
# '10.1016/j.jwpe.2018.08.012'
# 1187 done
# '10.1016/j.supflu.2021.105271'
# 1188 done
# ...
# 5515 done
# '10.1016/j.chemosphere.2019.03.101'
# 5516 done
# '10.1016/j.matlet.2020.129059'
# 5517 done
# '10.1016/j.ejmech.2011.01.004'
# 5518 done
# '10.1016/j.powtec.2018.12.084'
# 5519 done
# '10.1016/j.electacta.2022.140743'
# 5520 done
# '10.1016/j.aca.2013.09.044'
# 5521 done
# '10.1016/j.apcata.2011.11.017'
# 5522 done
# '10.1016/j.ijbiomac.2019.03.045'
# 5523 done
# '10.1016/j.neuroimage.2010.06.061'
# 5524 done
# '10.1016/j.drugalcdep.2013.01.014'
# 5525 done
# '10.1016/j.tetasy.2015.04.002'
# 5526 done
# '10.1016/j.mtcomm.2022.104617'
# 5527 done
# '10.1016/B978-0-12-405941-2.00010-9'
# 5528 done
# '10.1016/j.drugalcdep.2016.01.023'
# 5529 done
# '10.1016/j.memsci.2008.06.055'
# 5530 done
# '10.1016/j.cdc.2017.03.002'
# 5531 done
# '10.1016/j.tetlet.2009.09.160'
# 5532 done
# '10.1016/B978-0-444-63743-7.00016-0'
# 5533 done
# '10.1016/j.culher.2022.05.002'
# 5534 done
# '10.1016/j.cej.2014.02.029'
# 5535 done
# '10.1016/j.colsurfb.2014.03.010'
# 5536 done
# '10.1016/j.catcom.2012.12.015'
# 5537 done
# '10.1016/j.drugalcdep.2017.01.026'
# 5538 done
# '10.1016/j.addbeh.2014.07.013'
# 5539 done
# '10.1016/j.tet.2015.09.024'
# 5540 done
# '10.1016/B978-0-12-805373-7.00026-8'
# 5541 done
# '10.1016/j.tet.2016.09.013'
# 5542 done
# '10.1016/j.jfluchem.2011.07.016'
# 5543 done
# '10.1016/j.catcom.2009.04.012'
# 5544 done
# '10.1016/j.pnucene.2018.10.018'
# 5545 done
# '10.1016/j.jddst.2022.103748'
# 5546 done
# '10.1016/j.catcom.2009.05.020'
# 5547 done
# '10.1016/j.jad.2010.12.014'
# 5548 done
# '10.1016/j.chroma.2018.10.048'
# 5549 done
# '10.1016/j.jbiotec.2012.03.015'
# 5550 done
# '10.1016/j.neuropharm.2016.11.021'
# 5551 done
# '10.1016/j.bbi.2013.03.009'
# 5552 done
# '10.1016/j.apcatb.2012.10.025'
# 5553 done
# '10.1016/j.bios.2015.02.015'
# 5554 done
# '10.1016/j.addbeh.2009.12.017'
# 5555 done
# '10.1016/j.drugalcdep.2016.06.012'
# 5556 done
# '10.1016/j.jcat.2011.12.021'
# 5557 done
# '10.1016/j.egypro.2014.02.051'
# 5558 done
# '10.1016/j.drugalcdep.2013.01.017'
# 5559 done
# '10.1016/j.tetlet.2014.08.020'
# 5560 done
# '10.1016/j.egypro.2015.07.490'
# 5561 done
# '10.1016/j.drugpo.2012.12.007'
# 5562 done
# '10.1016/j.jsat.2017.04.001'
# 5563 done
# '10.1016/j.chroma.2013.04.072'
# 5564 done
# '10.1016/j.tet.2013.07.076'
# 5565 done
# '10.1016/j.forsciint.2017.03.022'
# 5566 done
# '10.1016/j.jflm.2016.08.007'
# 5567 done
# '10.1016/S1872-2067(14)60101-7'
# 5568 done
# '10.1016/j.tetasy.2016.10.005'
# 5569 done
# '10.1016/j.apcata.2011.02.028'
# 5570 done
# '10.1016/j.jcrc.2008.07.002'
# 5571 done
# '10.1016/j.synthmet.2016.10.002'
# 5572 done
# '10.1016/j.colsurfa.2014.04.023'
# 5573 done
# '10.1016/S0140-6736(09)60744-3'
# 5574 done
# '10.1016/j.exppara.2013.03.034'
# 5575 done
# '10.1016/j.apcata.2012.04.005'
# 5576 done
# '10.1016/j.catcom.2009.01.004'
# 5577 done
# '10.1016/j.catcom.2017.05.018'
# 5578 done
# '10.1016/S1872-5805(17)60121-5'
# 5579 done
# '10.1016/j.nanoen.2015.06.006'
# 5580 done
# '10.1016/j.molcatb.2015.03.010'
# 5581 done
# '10.1016/j.cattod.2008.12.034'
# 5582 done
# '10.1016/j.apsusc.2018.02.004'
# 5583 done
# '10.1016/j.egypro.2015.07.804'
# 5584 done
# '10.1016/j.jcat.2017.08.013'
# 5585 done
# '10.1016/j.ssi.2019.01.024'
# 5586 done
# '10.1016/j.molcatb.2013.06.002'
# 5587 done
# '10.1016/j.envpol.2019.113513'
# 5588 done
# '10.1016/j.tetlet.2017.01.105'
# 5589 done
# '10.1016/j.arabjc.2017.01.017'
# 5590 done
# '10.1016/j.apcata.2012.08.029'
# 5591 done
# '10.1016/j.legalmed.2017.01.011'
# 5592 done
# '10.1016/j.molstruc.2014.01.080'
# 5593 done
# '10.1016/j.apcata.2011.10.038'
# 5594 done
# '10.1016/S1003-9953(11)60324-1'
# 5595 done
# '10.1016/j.tca.2015.11.024'
# 5596 done
# '10.1016/B978-0-12-812284-6.00001-9'
# 5597 done
# '10.1016/B978-0-08-097742-3.00711-4'
# 5598 done
# '10.1016/j.fuel.2015.07.086'
# 5599 done
# '10.1016/S0927-7757(01)01015-9'
# 5600 done
# '10.1016/B978-0-12-813125-1.00040-4'
# 5601 done
# '10.1016/j.jcat.2018.10.002'
# 5602 done
# '10.1016/j.polymertesting.2022.107867'
# 5603 done
# '10.1016/j.msec.2019.110316'
# 5604 done
# '10.1016/j.mtcomm.2018.09.013'
# 5605 done
# '10.1016/j.cej.2015.09.113'
# 5606 done
# '10.1016/S0031-9422(01)00251-5'
# 5607 done
# '10.1016/S0040-4020(03)00071-1'
# 5608 done
# '10.1016/j.expneurol.2016.03.013'
# 5609 done
# '10.1016/j.cej.2020.126212'
# 5610 done
# '10.1016/j.tca.2015.04.027'
# 5611 done
# '10.1016/j.addbeh.2017.08.019'
# 5612 done
# '10.1016/j.memsci.2012.09.017'
# 5613 done
# '10.1016/j.alcohol.2017.08.007'
# 5614 done
# '10.1016/S0091-3057(03)00124-2'
# 5615 done
# '10.1016/j.jcat.2017.12.025'
# 5616 done
# '10.1016/j.bmcl.2014.04.055'
# 5617 done
# '10.1016/j.apsusc.2011.07.128'
# 5618 done
# '10.1016/j.colsurfb.2012.08.031'
# 5619 done
# '10.1016/j.jmbbm.2020.104066'
# 5620 done
# '10.1016/j.molcata.2016.11.027'
# 5621 done
# '10.1016/j.apenergy.2015.08.004'
# 5622 done
# '10.1016/j.apcata.2014.02.020'
# 5623 done
# '10.1016/j.ica.2016.04.051'
# 5624 done
# '10.1016/j.ijbiomac.2022.02.105'
# 5625 done
# '10.1016/j.cattod.2012.01.012'
# 5626 done
# '10.1016/j.biopsych.2012.09.019'
# 5627 done
# '10.1016/j.tetlet.2011.11.108'
# 5628 done
# '10.1016/S1381-1177(02)00159-5'
# 5629 done
# '10.1016/j.tca.2007.10.006'
# 5630 done
# '10.1016/j.crci.2012.08.004'
# 5631 done
# '10.1016/j.optmat.2016.09.011'
# 5632 done
# '10.1016/j.fct.2009.05.014'
# 5633 done
# '10.1016/j.tetasy.2009.11.010'
# 5634 done
# '10.1016/j.jorganchem.2018.02.029'
# 5635 done
# '10.1016/j.tet.2012.02.039'
# 5636 done
# '10.1016/j.matchemphys.2014.09.033'
# 5637 done
# '10.1016/j.tetlet.2014.05.042'
# 5638 done
# '10.1016/j.apcatb.2018.10.027'
# 5639 done
# '10.1016/j.chemosphere.2020.127144'
# 5640 done
# '10.1016/j.crci.2012.03.001'
# 5641 done
# '10.1016/j.renene.2010.02.029'
# 5642 done
# '10.1016/j.ijdevneu.2010.01.004'
# 5643 done
# '10.1016/j.ijbiomac.2020.03.185'
# 5644 done
# '10.1016/j.catcom.2013.04.002'
# 5645 done
# '10.1016/j.catcom.2013.12.031'
# 5646 done
# '10.1016/j.apsusc.2007.08.084'
# 5647 done
# '10.1016/j.jiec.2014.04.010'
# 5648 done
# '10.1016/j.cattod.2012.05.052'
# 5649 done
# '10.1016/j.molcatb.2009.01.001'
# 5650 done
# '10.1016/j.cej.2019.122475'
# 5651 done
# '10.1016/j.ccc.2012.07.004'
# 5652 done
# '10.1016/j.jeurceramsoc.2014.07.002'
# 5653 done
# '10.1016/j.cej.2018.05.035'
# 5654 done
# '10.1016/j.aorn.2017.01.009'
# 5655 done
# '10.1016/j.nanoen.2020.105656'
# 5656 done
# '10.1016/j.micromeso.2015.11.019'
# 5657 done
# '10.1016/j.molliq.2017.09.054'
# 5658 done
# '10.1016/j.electacta.2009.09.044'
# 5659 done
# '10.1016/j.drugalcdep.2011.12.005'
# 5660 done
# '10.1016/S1003-6326(14)63481-6'
# 5661 done
# '10.1016/j.energy.2021.120031'
# 5662 done
# '10.1053/j.jrn.2010.03.003'
# 5663 done
# '10.1016/j.radphyschem.2011.10.028'
# 5664 done
# '10.1016/j.jpba.2022.114635'
# 5665 done
# '10.1016/j.molcata.2015.01.008'
# 5666 done
# '10.1016/S1381-1169(02)00694-5'
# 5667 done
# '10.1016/S0040-4039(00)97235-6'
# 5668 done
# '10.1016/j.fuproc.2011.05.003'
# 5669 done
# '10.1016/j.drugalcdep.2018.10.026'
# 5670 done
# '10.1016/j.tetlet.2009.06.045'
# 5671 done
# '10.1016/j.cca.2008.06.001'
# 5672 done
# '10.1016/j.addbeh.2015.02.001'
# 5673 done
# '10.1016/j.rinp.2021.104223'
# 5674 done
# '10.1016/j.acthis.2018.05.011'
# 5675 done
# '10.1016/B978-0-323-91001-9.00028-1'
# 5676 done
# '10.1016/j.jct.2013.01.019'
# 5677 done
# '10.1016/j.jcat.2018.08.004'
# 5678 done
# '10.1016/j.jtice.2020.09.016'
# 5679 done
# '10.1016/j.jallcom.2017.02.179'
# 5680 done
# '10.1016/j.catcom.2010.02.004'
# 5681 done
# '10.1016/j.brat.2016.05.008'
# 5682 done
# '10.1016/j.phytochem.2008.07.018'
# 5683 done
# '10.1016/j.molcata.2016.03.044'
# 5684 done
# '10.1016/j.jallcom.2020.156430'
# 5685 done
# '10.1016/j.molliq.2010.05.012'
# 5686 done
# '10.1016/j.apcatb.2011.09.003'
# 5687 done
# '10.1016/S2221-1691(12)60080-X'
# 5688 done
# '10.1016/B978-0-444-53717-1.00709-5'
# 5689 done
# '10.1016/j.jsat.2016.12.011'
# 5690 done
# '10.1016/j.snb.2005.07.052'
# 5691 done
# '10.1016/j.tetlet.2011.05.020'
# 5692 done
# '10.1016/j.bbi.2011.01.006'
# 5693 done
# '10.1016/j.carbpol.2020.116315'
# 5694 done
# '10.1016/j.molcata.2016.07.012'
# 5695 done
# '10.1016/j.jcat.2014.03.001'
# 5696 done
# '10.1016/j.tetlet.2010.06.112'
# 5697 done
# '10.1016/j.reactfunctpolym.2019.01.002'
# 5698 done
# '10.1016/j.molcata.2011.01.020'
# 5699 done
# '10.1016/j.tetasy.2017.04.005'
# 5700 done
# '10.1016/j.bioelechem.2013.08.001'
# 5701 done
# '10.1016/j.tetlet.2007.12.061'
# 5702 done
# '10.1016/B978-0-323-91001-9.00028-1'
# 5703 done
# '10.1016/j.apcata.2014.08.023'
# 5704 done
# '10.1016/j.jfluchem.2012.06.002'
# 5705 done
# '10.1016/S1381-1169(02)00694-5'
# 5706 done
# '10.1016/j.neuropharm.2015.10.027'
# 5707 done
# '10.1016/j.alcohol.2011.04.002'
# 5708 done
# '10.1016/j.catcom.2012.05.020'
# 5709 done
# '10.1016/j.fbio.2020.100722'
# 5710 done
# '10.1016/j.radphyschem.2011.10.028'
# 5711 done
# '10.1016/j.molcata.2009.10.026'
# 5712 done
# '10.1016/j.foodcont.2021.107880'
# 5713 done
# '10.1016/j.biortech.2010.04.089'
# 5714 done
# '10.1016/j.fluid.2015.06.002'
# 5715 done
# '10.1016/j.porgcoat.2015.03.021'
# 5716 done
# '10.1016/j.apcata.2015.10.027'
# 5717 done
# '10.1016/j.sna.2020.112263'
# 5718 done
# '10.1016/j.radcr.2017.10.013'
# 5719 done
# '10.1016/j.jddst.2019.101276'
# 5720 done
# '10.1016/j.jhin.2012.12.010'
# 5721 done
# '10.1016/j.carbon.2016.09.010'
# 5722 done
# '10.1016/j.indcrop.2022.115980'
# 5723 done
# '10.1016/j.tetlet.2009.06.045'
# 5724 done
# '10.1016/j.chemgeo.2020.119982'
# 5725 done
# '10.1016/j.compositesa.2019.05.033'
# 5726 done
# '10.1016/j.apcatb.2009.07.007'
# 5727 done
# '10.1016/j.enconman.2017.06.030'
# 5728 done
# '10.1016/j.catcom.2012.04.016'
# 5729 done
# '10.1016/j.ridd.2012.05.026'
# 5730 done
# '10.1016/j.euroneuro.2013.02.006'
# 5731 done
# '10.1016/j.apsusc.2014.06.100'
# 5732 done
# '10.1016/j.ultrasmedbio.2019.04.030'
# 5733 done
# '10.1016/j.fuproc.2009.07.004'
# 5734 done
# '10.1074/jbc.M113.521153'
# 5735 done
# '10.1016/j.ijbiomac.2021.02.141'
# 5736 done
# '10.1016/j.tetlet.2014.01.053'
# 5737 done
# '10.1016/j.drugalcdep.2017.07.023'
# 5738 done
# '10.1016/j.memsci.2020.118355'
# 5739 done
# '10.1016/j.bbi.2011.01.006'
# 5740 done
# '10.1016/j.apcata.2016.02.003'
# 5741 done
# '10.1016/j.catcom.2015.10.028'
# 5742 done
# '10.1016/j.cej.2022.138988'
# 5743 done
# '10.1016/j.drugalcdep.2014.08.015'
# 5744 done
# '10.1016/j.drugalcdep.2013.06.035'
# 5745 done
# '10.1016/j.jclepro.2015.11.051'
# 5746 done
# '10.1016/j.mcat.2017.12.038'
# 5747 done
# '10.1016/j.memsci.2019.03.001'
# 5748 done
# '10.1016/j.apsusc.2015.10.234'
# 5749 done
# '10.1016/j.catcom.2011.05.024'
# 5750 done
# '10.1016/j.drugalcdep.2018.03.010'
# 5751 done
# '10.1016/j.foodchem.2013.10.027'
# 5752 done
# '10.1016/j.jpba.2017.02.006'
# 5753 done
# '10.1016/j.neuroimage.2010.11.062'
# 5754 done
# '10.1016/j.molcata.2011.01.008'
# 5755 done
# '10.1016/j.tetlet.2010.11.137'
# 5756 done
# '10.1016/j.jtice.2019.05.010'
# 5757 done
# '10.1016/j.poly.2009.07.008'
# 5758 done
# '10.1016/j.apcata.2014.06.003'
# 5759 done
# '10.1016/j.crci.2015.10.013'
# 5760 done
# '10.1016/j.catcom.2018.08.025'
# 5761 done
# '10.1016/j.apsusc.2013.04.125'
# 5762 done
# '10.1016/j.cattod.2015.06.014'
# 5763 done
# '10.1016/j.tetlet.2007.09.104'
# 5764 done
# '10.1016/j.apcatb.2013.05.047'
# 5765 done
# '10.1016/S1570-0232(03)00213-7'
# 5766 done
# '10.1016/j.snb.2013.05.055'
# 5767 done
# '10.1016/j.catcom.2014.03.015'
# 5768 done
# '10.1016/j.clnu.2016.05.005'
# 5769 done
# '10.1016/B978-0-12-817941-3.00005-X'
# 5770 done
# '10.1016/j.alcohol.2004.07.002'
# 5771 done
# '10.1016/S0040-4020(01)90583-6'
# 5772 done
# '10.1016/j.ijbiomac.2020.08.051'
# 5773 done
# '10.1016/j.neuron.2010.02.015'
# 5774 done
# '10.1016/j.cbi.2017.04.019'
# 5775 done
# '10.1016/j.drugalcdep.2009.09.007'
# 5776 done
# '10.1016/j.alcohol.2017.01.009'
# 5777 done
# '10.1002/jps.22601'
# 5778 done
# '10.1016/j.arabjc.2020.08.006'
# 5779 done
# '10.1016/j.molliq.2015.10.009'
# 5780 done
# '10.1016/j.catcom.2010.05.002'
# 5781 done
# '10.1016/j.ccr.2022.214868'
# 5782 done
# '10.1016/j.toxlet.2017.09.010'
# 5783 done
# '10.1016/j.apsusc.2016.07.020'
# 5784 done
# '10.1016/j.catcom.2007.05.024'
# 5785 done
# '10.1016/j.jcat.2016.01.012'
# 5786 done
# '10.1016/j.tetlet.2011.06.096'
# 5787 done
# '10.1016/j.tetlet.2011.06.109'
# 5788 done
# '10.1016/j.cgh.2018.11.034'
# 5789 done
# '10.1016/j.apcatb.2017.09.048'
# 5790 done
# '10.1016/j.cattod.2011.09.041'
# 5791 done
# '10.1016/j.ijbiomac.2019.12.060'
# 5792 done
# '10.1016/j.ijbiomac.2020.07.320'
# 5793 done
# '10.1016/j.apcata.2013.09.024'
# 5794 done
# '10.1016/S0957-4166(03)00483-X'
# 5795 done
# '10.1016/j.jmst.2014.12.013'
# 5796 done
# '10.1016/j.tetlet.2014.07.107'
# 5797 done
# '10.1016/j.jcat.2012.01.020'
# 5798 done
# '10.1016/j.sab.2011.09.006'
# 5799 done
# '10.1016/j.ica.2012.05.007'
# 5800 done
# '10.1016/j.electacta.2009.02.003'
# 5801 done
# '10.1016/S0032-3861(03)00062-4'
# 5802 done
# '10.1016/S1381-1177(98)00065-4'
# 5803 done
# '10.1016/j.foodchem.2019.125249'
# 5804 done
# '10.1016/j.apcata.2007.12.013'
# 5805 done
# '10.1016/j.comtox.2016.11.001'
# 5806 done
# '10.1016/j.porgcoat.2019.02.006'
# 5807 done
# '10.1016/j.neulet.2010.03.051'
# 5808 done
# '10.1016/j.tet.2016.06.009'
# 5809 done
# '10.1016/j.talanta.2017.10.035'
# 5810 done
# '10.1016/B978-0-08-097742-3.00829-6'
# 5811 done
# '10.1016/j.ijbiomac.2016.02.035'
# 5812 done
# '10.1016/j.enzmictec.2014.04.001'
# 5813 done
# '10.1016/j.neuroscience.2012.01.006'
# 5814 done
# '10.1016/j.catcom.2014.02.002'
# 5815 done
# '10.1016/j.dental.2011.05.004'
# 5816 done
# '10.1016/j.apradiso.2020.109211'
# 5817 done
# '10.1016/j.carbpol.2021.118175'
# 5818 done
# '10.1016/j.electacta.2020.137208'
# 5819 done
# '10.1016/j.jcat.2011.01.029'
# 5820 done
# '10.1016/j.jpowsour.2018.04.072'
# 5821 done
# '10.1016/j.ecoenv.2008.07.019'
# 5822 done
# '10.1016/j.tet.2013.01.063'
# 5823 done
# '10.1016/j.polymer.2020.123330'
# 5824 done
# '10.1016/j.taap.2009.11.027'
# 5825 done
# '10.1016/j.pep.2013.02.009'
# 5826 done
# '10.1016/j.electacta.2019.134874'
# 5827 done
# '10.1016/j.procbio.2012.01.012'
# 5828 done
# '10.1016/j.alcohol.2007.06.002'
# 5829 done
# '10.1016/j.jcat.2014.07.022'
# 5830 done
# '10.1016/j.tet.2014.04.030'
# 5831 done
# '10.1016/j.lwt.2020.109505'
# 5832 done
# '10.1016/j.jcat.2008.08.010'
# 5833 done
# '10.1016/j.bmcl.2008.05.113'
# 5834 done
# '10.1016/j.tetlet.2012.03.104'
# 5835 done
# '10.1016/S1872-2067(14)60252-7'
# 5836 done
# '10.1016/j.ijbiomac.2020.06.240'
# 5837 done
# '10.1016/B978-0-12-809470-9.00016-3'
# 5838 done
# '10.1016/j.biortech.2010.03.016'
# 5839 done
# '10.1016/j.mcat.2018.03.023'
# 5840 done
# '10.1016/j.ica.2016.05.052'
# 5841 done
# '10.1016/j.promfg.2015.07.098'
# 5842 done
# '10.1016/j.ijbiomac.2020.04.202'
# 5843 done
# '10.1016/j.apcata.2008.11.024'
# 5844 done
# '10.1016/j.cej.2018.11.057'
# 5845 done
# '10.1016/j.jpba.2020.113129'
# 5846 done
# '10.1016/j.jbtep.2011.04.004'
# 5847 done
# '10.1016/j.molcata.2007.05.034'
# 5848 done
# '10.1016/S1872-2067(15)60994-9'
# 5849 done
# '10.1016/j.micromeso.2012.11.025'
# 5850 done
# '10.1016/j.colsurfa.2013.06.014'
# 5851 done
# '10.1016/0195-6701(83)90025-7'
# 5852 done
# '10.1016/j.jssc.2017.04.030'
# 5853 done
# '10.1016/j.tetlet.2009.10.050'
# 5854 done
# '10.1016/j.catcom.2011.11.002'
# 5855 done
# '10.1016/j.ijhydene.2011.03.030'
# 5856 done
# '10.1016/j.jcat.2013.12.002'
# 5857 done
# '10.1016/j.jfoodeng.2020.110230'
# 5858 done
# '10.1016/j.colsurfa.2011.05.052'
# 5859 done
# '10.1016/j.procbio.2018.04.016'
# 5860 done
# '10.1016/j.tetlet.2008.03.132'
# 5861 done
# '10.1016/j.eurpolymj.2020.109913'
# 5862 done
# '10.1016/j.drugalcdep.2016.02.029'
# 5863 done
# '10.1016/S2095-4956(15)60312-6'
# 5864 done
# '10.1016/j.arabjc.2015.12.007'
# 5865 done
# '10.1016/j.tetasy.2011.04.021'
# 5866 done
# '10.1016/j.ecl.2013.05.008'
# 5867 done
# '10.1016/j.colsurfb.2021.111771'
# 5868 done
# '10.1016/j.chroma.2012.04.012'
# 5869 done
# '10.1016/j.jcis.2018.06.072'
# 5870 done
# '10.1016/j.tetlet.2013.01.068'
# 5871 done
# '10.1016/j.burns.2008.11.015'
# 5872 done
# '10.1016/j.ica.2012.12.037'
# 5873 done
# '10.1016/j.addbeh.2014.06.007'
# 5874 done
# '10.1016/j.cattod.2010.03.079'
# 5875 done
# '10.1016/j.ica.2010.01.017'
# 5876 done
# '10.1016/j.eurpolymj.2018.06.009'
# 5877 done
# '10.1016/S1875-5372(14)60027-8'
# 5878 done
# '10.1016/j.biortech.2016.07.052'
# 5879 done
# '10.1016/j.addbeh.2017.11.039'
# 5880 done
# '10.1016/j.molcata.2009.02.039'
# 5881 done
# '10.1016/j.tetlet.2013.10.051'
# 5882 done
# '10.1016/j.chroma.2012.05.026'
# 5883 done
# '10.1016/j.tet.2012.06.063'
# 5884 done
# '10.1016/S1003-9953(10)60145-4'
# 5885 done
# '10.1016/j.biortech.2013.11.015'
# 5886 done
# '10.1016/S2222-1808(11)60002-9'
# 5887 done
# '10.1016/0304-4211(84)90067-1'
# 5888 done
# '10.1016/j.addbeh.2004.03.002'
# 5889 done
# '10.1016/j.tetlet.2011.08.097'
# 5890 done
# '10.1016/j.jcis.2010.09.063'
# 5891 done
# '10.1016/j.fuproc.2010.07.005'
# 5892 done
# '10.1016/j.soard.2015.10.085'
# 5893 done
# '10.1016/j.catcom.2011.08.009'
# 5894 done
# '10.1016/j.snb.2013.11.102'
# 5895 done
# '10.1016/j.jpowsour.2014.11.034'
# 5896 done
# '10.1016/j.jsr.2014.02.004'
# 5897 done
# '10.1016/j.canep.2014.10.009'
# 5898 done
# '10.1016/j.chembiol.2006.11.017'
# 5899 done
# CPU times: user 2min 18s, sys: 5.2 s, total: 2min 23s
# Wall time: 3h 55min 26s

# %%
df_available_abstract = pd.DataFrame()
df_available_abstract['DOI'] = list_doi
df_available_abstract['Title'] = list_title
df_available_abstract['Abstract'] = list_abstract
df_available_abstract['Date'] = list_date
df_available_abstract['Journal'] = list_journal

df_available_abstract.tail(10)
# Out:
#                                  DOI  \
# 5890    10.1016/j.tetlet.2011.08.097
# 5891      10.1016/j.jcis.2010.09.063
# 5892    10.1016/j.fuproc.2010.07.005
# 5893     10.1016/j.soard.2015.10.085
# 5894    10.1016/j.catcom.2011.08.009
# 5895       10.1016/j.snb.2013.11.102
# 5896  10.1016/j.jpowsour.2014.11.034
# 5897       10.1016/j.jsr.2014.02.004
# 5898     10.1016/j.canep.2014.10.009
# 5899  10.1016/j.chembiol.2006.11.017
#
#                                                   Title  \
# 5890  Recyclable silica-supported iodoarene–RuCl3 bi...
# 5891  Effect of anionic surfactant and short-chain a...
# 5892  Evaluation of galvanic corrosion of a Zn alloy...
# 5893  ASMBS position statement on alcohol use before...
# 5894  Recyclable ionic liquid-bridged chiral dimeric...
# 5895  Work function based sensing of alkanes and alc...
# 5896  Direct alcohol fuel cells: Increasing platinum...
# 5897  Acute effects of alcohol on inhibitory control...
# 5898  Regional variation in incidence for smoking an...
# 5899  “Primitive” Membrane from Polyprenyl Phosphate...
#
#                                                Abstract              Date  \
# 5890  Novel, efficient, and recyclable bifunctional ...   26 October 2011
# 5891  Measurements of the advancing contact angles f...   1 February 2011
# 5892  Galvanic corrosion of zamak was evaluated in a...     November 2010
# 5893                                               None     February 2016
# 5894  Novel chiral dimeric salen Mn(III) complexes b...  15 November 2011
# 5895  Metalorganic frameworks (MOFs) are porous crys...     31 March 2014
# 5896  By using sp group metals as modifiers, the cat...   1 February 2015
# 5897  Introduction The public health costs associate...         June 2014
# 5898  The prevalence of life habits may vary substan...     February 2015
# 5899  Polyprenyl phosphates, as well as polyprenyl a...        March 2007
#
#                                        Journal
# 5890                       Tetrahedron Letters
# 5891  Journal of Colloid and Interface Science
# 5892                Fuel Processing Technology
# 5893  Surgery for Obesity and Related Diseases
# 5894                  Catalysis Communications
# 5895         Sensors and Actuators B: Chemical
# 5896                  Journal of Power Sources
# 5897                Journal of Safety Research
# 5898                       Cancer Epidemiology
# 5899                       Chemistry & Biology

# %%
#Save the combined abstracts in another CSV file
df.to_csv(r'/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/data/non_relvnt_rendom.csv', index=False)
