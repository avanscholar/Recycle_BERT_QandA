# %%
#BART1 environment
import nltk
from nltk.tokenize import word_tokenize,sent_tokenize
#Import nltk, download repositary for tokenize
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/user3/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
#Basic libraries
import pandas as pd
import numpy as np
import time

# %%
#data load of pet
df_pet = pd.read_csv(r'/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/data/pet_recycles.csv')
df_pet =  df_pet.drop(['Unnamed: 0'], axis=1)
print('Shape of data frame:', df_pet.shape)
df_pet.head()
# Out:
# Shape of data frame: (5900, 5)
#                                  DOI  \
# 0    10.1016/j.resconrec.2022.106639
# 1  10.1016/j.conbuildmat.2022.127084
# 2       10.1016/j.wasman.2021.09.009
# 3      10.1016/j.jclepro.2022.134083
# 4        10.1016/j.crgsc.2022.100280
#
#                                                Title  \
# 0  Efficient chemical recycling of waste polyethy...
# 1  Recycled Non-Biodegradable polyethylene tereph...
# 2  Hydrolysis of waste polyethylene terephthalate...
# 3  Polyethylene terephthalate (PET) waste plastic...
# 4  Development of composite material from Recycle...
#
#                                             Abstract              Date  \
# 0  We present an efficient chemical recycling/dep...     December 2022
# 1  In this study, the use of recycled non-biodegr...     18 April 2022
# 2  Hydrolysis of polyethylene terephthalate (PET)...     November 2021
# 3  This work investigates the recycling potential...  15 November 2022
# 4  Since 1980, numerous studies have been conduct...              2022
#
#                                              Journal
# 0              Resources, Conservation and Recycling
# 1                Construction and Building Materials
# 2                                   Waste Management
# 3                      Journal of Cleaner Production
# 4  Current Research in Green and Sustainable Chem...

# %%
#data load of ps
df_ps = pd.read_csv(r'/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/data/PS_recycle_methods.csv')
#df_ps =  df_ps.drop(['Unnamed: 0'], axis=1)
print('Shape of data frame:', df_ps.shape)
df_ps.head()
# Out:
# Shape of data frame: (5900, 5)
#                                      DOI  \
# 0             10.1016/j.jobe.2022.105697
# 1           10.1016/j.wasman.2022.07.001
# 2                                      1
# 3             10.1016/j.fuel.2021.121835
# 4  10.1016/j.polymdegradstab.2022.109981
#
#                                                Title  \
# 0  Dissolved recycled expanded polystyrene as par...
# 1  Recycling of polystyrene-based external therma...
# 2                                                  2
# 3  A methodology for recycling waste expanded pol...
# 4  Chemical recycling of waste polystyrene by the...
#
#                                             Abstract            Date  \
# 0  The recovery of Construction and Demolition Wa...   15 April 2023
# 1  The material recycling of complex waste stream...   1 August 2022
# 2                                                  0               3
# 3  While polystyrene polymers see broad usage in ...  1 January 2022
# 4  Chemical recycling by thermo-catalytic pyrolys...       July 2022
#
#                              Journal
# 0    Journal of Building Engineering
# 1                   Waste Management
# 2                                  4
# 3                               Fuel
# 4  Polymer Degradation and Stability

# %%
#data load of pe
df_pe = pd.read_csv(r'/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/data/PE_RECYCLE_METHODS.csv')
df_pe =  df_pe.drop(['Unnamed: 0'], axis=1)
print('Shape of data frame:', df_pe.shape)
df_pe.head()
# Out:
# Shape of data frame: (6000, 5)
#                              DOI  \
# 0   10.1016/j.susmat.2022.e00562
# 1     10.1016/j.jobe.2022.105541
# 2  10.1016/j.polymer.2022.125596
# 3     10.1016/j.fpsl.2022.101020
# 4     10.1016/j.egyr.2022.07.101
#
#                                                Title  \
# 0  Environmental assessment of the recycling proc...
# 1  Sustainable utilization of hybrid recycled pow...
# 2  Simulations mapping the influence of oxygen, e...
# 3  Migration of volatile substances from recycled...
# 4  Effect of compatibilization agents and rice hu...
#
#                                             Abstract             Date  \
# 0  The plastic packaging, and in particular the m...       April 2023
# 1  The effects of hybrid recycled powder (HRP) fr...   1 January 2023
# 2  We present a computational study of the develo...  16 January 2023
# 3  Plastic recycling is the main solution to redu...       March 2023
# 4  The new trend of the circular economy encourag...    November 2022
#
#                                   Journal
# 0  Sustainable Materials and Technologies
# 1         Journal of Building Engineering
# 2                                 Polymer
# 3           Food Packaging and Shelf Life
# 4                          Energy Reports

# %%
#data load of pp
df_pp = pd.read_csv(r'/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/data/pp_recycle.csv')
#df_pp =  df_pp.drop(['Unnamed: 0'], axis=1)
print('Shape of data frame:', df_pp.shape)
df_pp.head()
# Out:
# Shape of data frame: (5900, 5)
#                                      DOI  \
# 0             10.1016/j.jobe.2022.105697
# 1           10.1016/j.wasman.2022.07.001
# 2             10.1016/j.jece.2022.108332
# 3             10.1016/j.fuel.2021.121835
# 4  10.1016/j.polymdegradstab.2022.109981
#
#                                                Title  \
# 0  Dissolved recycled expanded polystyrene as par...
# 1  Recycling of polystyrene-based external therma...
# 2  Morpho-structural and thermo-mechanical charac...
# 3  A methodology for recycling waste expanded pol...
# 4  Chemical recycling of waste polystyrene by the...
#
#                                             Abstract            Date  \
# 0  The recovery of Construction and Demolition Wa...   15 April 2023
# 1  The material recycling of complex waste stream...   1 August 2022
# 2  In this work, a complete sorting and character...    October 2022
# 3  While polystyrene polymers see broad usage in ...  1 January 2022
# 4  Chemical recycling by thermo-catalytic pyrolys...       July 2022
#
#                                          Journal
# 0                Journal of Building Engineering
# 1                               Waste Management
# 2  Journal of Environmental Chemical Engineering
# 3                                           Fuel
# 4              Polymer Degradation and Stability

# %%
# concatenating df1 and df2 along rows
df_net = pd.concat([df_pe, df_pet,df_pp, df_ps], axis=0).reset_index(drop = True)
print('Net shape of data frame:', df_net.shape)
# Out:
# Net shape of data frame: (23700, 5)

# %%
indddd = []
for i in range(len(df_net)):
    if int(df_net.Date[i][-4:]) in [2023,2022,2021,2020,2019,2018,2017]:
        indddd.append(i)
len(indddd)
# Out:
# 16636

# %%
# indddd

# %%
df_net = df_net.iloc[indddd].reset_index(drop=True)

# %%
#Delete the all entries with nan in abstract column
NO_INDEX = []
for i in range(len(df_net)):
    if type(df_net.Abstract[i]) != float: 
        NO_INDEX.append(i)
#Select some entries        
df_net = df_net.iloc[NO_INDEX].reset_index(drop = True)
print('Shape of data frame before:', df_net.shape)

#Delete the all entries with integer in abstract column
NO_INDEXX = []
for i in range(len(df_net)):
    if df_net.Abstract[i] != '0': 
        NO_INDEXX.append(i)
#Select some entries        
df_net = df_net.iloc[NO_INDEXX].reset_index(drop = True)
print('Shape of data frame after:', df_net.shape)

df_net.head()
# Out:
# Shape of data frame before: (16494, 5)
# Shape of data frame after: (16494, 5)
#                              DOI  \
# 0   10.1016/j.susmat.2022.e00562
# 1     10.1016/j.jobe.2022.105541
# 2  10.1016/j.polymer.2022.125596
# 3     10.1016/j.fpsl.2022.101020
# 4     10.1016/j.egyr.2022.07.101
#
#                                                Title  \
# 0  Environmental assessment of the recycling proc...
# 1  Sustainable utilization of hybrid recycled pow...
# 2  Simulations mapping the influence of oxygen, e...
# 3  Migration of volatile substances from recycled...
# 4  Effect of compatibilization agents and rice hu...
#
#                                             Abstract             Date  \
# 0  The plastic packaging, and in particular the m...       April 2023
# 1  The effects of hybrid recycled powder (HRP) fr...   1 January 2023
# 2  We present a computational study of the develo...  16 January 2023
# 3  Plastic recycling is the main solution to redu...       March 2023
# 4  The new trend of the circular economy encourag...    November 2022
#
#                                   Journal
# 0  Sustainable Materials and Technologies
# 1         Journal of Building Engineering
# 2                                 Polymer
# 3           Food Packaging and Shelf Life
# 4                          Energy Reports

# %%
#Abstract cleaning
def deletespace(text):
    text0 = text.replace("<jats:p>","" )
    text1 =  text0.replace("</jats:p>", '')
    text2 = text1.replace('<jats:title>Abstract</jats:title>\n', '')
    text3 = text2.replace('<p>', "")
    text4 = text3.replace('</p>', "")
    text5 = text4.replace('\n', "")
    
    return text5

# %%
df_net['Abstract'] = df_net['Abstract'].apply(deletespace)

# %%
df_net.head()
# Out:
#                              DOI  \
# 0   10.1016/j.susmat.2022.e00562
# 1     10.1016/j.jobe.2022.105541
# 2  10.1016/j.polymer.2022.125596
# 3     10.1016/j.fpsl.2022.101020
# 4     10.1016/j.egyr.2022.07.101
#
#                                                Title  \
# 0  Environmental assessment of the recycling proc...
# 1  Sustainable utilization of hybrid recycled pow...
# 2  Simulations mapping the influence of oxygen, e...
# 3  Migration of volatile substances from recycled...
# 4  Effect of compatibilization agents and rice hu...
#
#                                             Abstract             Date  \
# 0  The plastic packaging, and in particular the m...       April 2023
# 1  The effects of hybrid recycled powder (HRP) fr...   1 January 2023
# 2  We present a computational study of the develo...  16 January 2023
# 3  Plastic recycling is the main solution to redu...       March 2023
# 4  The new trend of the circular economy encourag...    November 2022
#
#                                   Journal
# 0  Sustainable Materials and Technologies
# 1         Journal of Building Engineering
# 2                                 Polymer
# 3           Food Packaging and Shelf Life
# 4                          Energy Reports

# %%
print("shape of data:", df_net.shape)
# Out:
# shape of data: (16494, 5)

# %%
# df_net = df_net.head(50)

# %% [markdown]
# **Screener for all categories**

# %%
df_har = pd.read_csv("/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/data/harshita/data_full-modified.csv",encoding="ISO-8859-1")
df_har.head(1)
# Out:
#    Unnamed: 0                          DOI  \
# 0           0  10.1533/9781845697662.2.102
#
#                                          Title  \
# 0  5 Pyrolysis for recycling waste composites
#
#                                             Abstract process catalyst  \
# 0                 Pyrolysis is a suitable process...      []       []
#
#                                             reactant  \
# 0  ['recycling polymer composites', 'polymer matr...
#
#                                  Method  \
# 0  ['pyrolysis', 'pyrolysis reactions']
#
#                                              Product
# 0  ['thermal decomposition products', 'monomers',...

# %%
df_pus =  pd.read_excel("/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/data/harshita/data_full.xlsx")
df_pus.head(1)
# Out:
#    Unnamed: 0                          DOI  \
# 0           0  10.1533/9781845697662.2.102
#
#                                          Title  \
# 0  5 Pyrolysis for recycling waste composites
#
#                                             Abstract process catalyst  \
# 0                 Pyrolysis is a suitable process...      []       []
#
#                                             reactant  \
# 0  ['recycling polymer composites', 'polymer matr...
#
#                                               Method  \
# 0  [' thermal', ' thermal decomposition product',...
#
#                                              Product
# 0  [' thermal decomposition product', 'monomers',...

# %%
df_mod = pd.concat([df_har.loc[:10000],df_pus.loc[10001:]], axis= 0).reset_index()
df_mod.head(4)
# Out:
#    index  Unnamed: 0                                DOI  \
# 0      0           0        10.1533/9781845697662.2.102
# 1      1           1         10.1016/j.fuel.2021.120505
# 2      2           2  10.1016/j.conbuildmat.2022.127949
# 3      3           3       10.1016/j.arabjc.2022.104262
#
#                                                Title  \
# 0        5 Pyrolysis for recycling waste composites
# 1  Low-pressure hydrothermal processing of mixed ...
# 2  Cement mortars with ceramic molds shells and p...
# 3  Degradation-fragmentation of marine plastic wa...
#
#                                             Abstract                process  \
# 0                 Pyrolysis is a suitable process...                     []
# 1  The amount of polyolefin waste, which is 63% o...  ['~23 MPa', '~2 MPa']
# 2  Foundry industry produces millions of tons of ...                     []
# 3  This review critically evaluates the plastic a...                     []
#
#   catalyst                                           reactant  \
# 0       []  ['recycling polymer composites', 'polymer matr...
# 1       []  ['polyolefin waste', 'total plastic waste', '5...
# 2       []                                         ['wastes']
# 3       []                                       ['plastics']
#
#                                    Method  \
# 0    ['pyrolysis', 'pyrolysis reactions']
# 1              ['degradation', 'thermal']
# 2                                      []
# 3  ['degradation', 'plastic degradation']
#
#                                              Product
# 0  ['thermal decomposition products', 'monomers',...
# 1  ['degradation products', 'clean oils', 'oils',...
# 2                      ['cement mortars', 'mortars']
# 3                       ['plastic products', 'soil']

# %%
df_mod["Product"][1459] = str(['bioenergy', 'energy'])
# Out:
# /home/user3/.local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_mod =df_mod.dropna().reset_index(drop = True)

# %% [markdown]
# **Create the listss**

# %%
x=df_mod["process"].values
process_ent=[]
List=[]
for i in range(len(df_mod)):
    #print(x[i], i)
    lis = x[i].split('[')
    gis = lis[1].split(']')
    his = gis[0].split("'")
    J=[]
    for k in range(1, len(his)-1):
        if(his[k]!=' '):
            J.append(his[k])
    List.append(J)
    

    
for i in range(0, len(List)):
    for j in range(0, len(List[i])):
        v=List[i][j]
        if(process_ent.count(v)==0):
            process_ent.append(v)

# %%
x=df_mod["catalyst"].values
catalyst_ent=[]
List=[]
for i in range(len(df_mod)):
    lis = x[i].split('[')
    gis = lis[1].split(']')
    his = gis[0].split("'")
    J=[]
    for k in range(1, len(his)-1):
        if(his[k]!=' '):
            J.append(his[k])
    List.append(J)
    
for i in range(0, len(List)):
    for j in range(0, len(List[i])):
        v=List[i][j]
        if(catalyst_ent.count(v)==0):
            catalyst_ent.append(v)

# %%
x=df_mod["Method"].values
method_ent=[]
List=[]
for i in range(len(df_mod)):
    lis = x[i].split('[')
    gis = lis[1].split(']')
    his = gis[0].split("'")
    J=[]
    for k in range(1, len(his)-1):
        if(his[k]!=' '):
            J.append(his[k])
    List.append(J)
    
for i in range(0, len(List)):
    for j in range(0, len(List[i])):
        v=List[i][j]
        if(method_ent.count(v)==0):
            method_ent.append(v)

# %%
x=df_mod["Product"].values
product_ent=[]
List=[]
for i in range(len(df_mod)):
    #print(x[i],i)
    lis = x[i].split('[')
    gis = lis[1].split(']')
    his = gis[0].split("'")
    J=[]
    for k in range(1, len(his)-1):
        if(his[k]!=' '):
            J.append(his[k])
    List.append(J)
    
for i in range(0, len(List)):
    for j in range(0, len(List[i])):
        v=List[i][j]
        if(product_ent.count(v)==0):
            product_ent.append(v)

# %%
x=df_mod["reactant"].values
reactant_ent=[]
List=[]
for i in range(len(df_mod)):
    lis = x[i].split('[')
    gis = lis[1].split(']')
    his = gis[0].split("'")
    J=[]
    for k in range(1, len(his)-1):
        if(his[k]!=' '):
            J.append(his[k])
    List.append(J)
    
for i in range(0, len(List)):
    for j in range(0, len(List[i])):
        v=List[i][j]
        if(reactant_ent.count(v)==0):
            reactant_ent.append(v)

# %%
# print("Unique entries: ", len(product_ent))
print("Unique entries product: ", len(product_ent))
print("Unique entries method: ", len(method_ent))
print("Unique entries reactant: ", len(reactant_ent))
print("Unique entries catalyst: ", len(catalyst_ent))
# Out:
# Unique entries product:  15244
# Unique entries method:  5673
# Unique entries reactant:  22775
# Unique entries catalyst:  95

# %% [markdown]
# **Extraction of process parameter**

# %%
import spacy
  
# Load English tokenizer, tagger, 
# parser, NER and word vectors
nlp = spacy.load("en_core_web_sm")

from spacy import displacy

# %%
# #Custom dictionary of process parameters
# process = ['temperature', 'pressure', 'weight', 'concentration']

# replacements = {'K': 'kelvin', 'atm': 'pressure',
#                '°C': 'celcius','bar': 'pressure',
#                 'g' : 'gram','Mpa': 'pressure',
#                 'pa' : 'pressure', "MPa": "pressure"}
# #Help in dealing with units of parameters
# replacer = replacements.get

# %%
# list(replacements.keys())

# %%
# def extractprocess(text):
#     sents =  sent_tokenize(text)
#     proc = [] 
#     for sen in sents:
#         for pro in process+list(replacements.keys()):
#             import re
#             if pro in sen:
#                 sentence_word = nltk.word_tokenize(sen)
#                 sentence_list = [replacer(n, n) for n in sentence_word]
#                 sentence_list = " ".join(sentence_list)
#                 doc = nlp(sen)
#                 x = re.findall('[0-9]+', sen)

#                 for num in x:
#                     for j in range(len(sentence_word)):

#                         if num in sentence_word[j]:

#                             for pro in process+list(replacements.keys()):

#                                 if pro in nltk.word_tokenize(sentence_list)[j:j+2]:

#                                     proc.append(" ".join(sentence_word[j:j+2]))
                                    
#     return proc

# %%
# %%time
# df_net['process'] = df_net['Abstract'].apply(extractprocess)

# %%
# #Delete same entries
# def deleteduplicate(lisst):
#     listsss =  []
#     [listsss.append(li) for li in lisst if li not in listsss]
#     return listsss

# %%
# %%time
# df_net['process'] =  df_net['process'].apply(deleteduplicate)  #estimate time 20msec

# %%
# #Stopwords removal
# from gensim.parsing.preprocessing import remove_stopwords
# def deletestopwords(listt):
#     actual_reactant = []
#     for wrd in listt:
#         filtered_sentencee = remove_stopwords(wrd)
#         actual_reactant.append(filtered_sentencee)
#     return actual_reactant

# %%
# df_net['process'] =  df_net['process'].apply(deletestopwords)

# %%
# df_net.head()

# %%
df_net.shape
# Out:
# (16494, 5)

# %%
# indd = []
# for i,cata in enumerate(df_net['process']):
#     if len(cata) != 0:
#         indd.append(i)
        
# len(indd)

# %%
# df_pr = df_net.loc[indd].reset_index(drop = True)

# %%
#df_pr.to_csv('/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/data/harshita/data_pro.csv')

# %% [markdown]
# **Extraction of catalyst entities**

# %%
#Imported chemical entity extraction library
import chemdataextractor
from chemdataextractor import Document

# %%
#All chemical entities of catalyst
df_cat =  pd.read_csv(r'/home/user3/Documents/avan_phd/objective_escape/catalys_entit_final.csv')
df_cat =  df_cat.drop(['Unnamed: 0', 'frequency', 'Unnamed: 3', '7738'], axis= 1)
df_cat.head(2)
# Out:
#   section name
# 0           Cu
# 1           Ni

# %%
#!conda install -c conda-forge spacy

# %%
#The exact catalyst entities
cata = list(df_cat['section name'])
print("Total unique entries of catalyst:",len(cata))
# Out:
# Total unique entries of catalyst: 807

# %%
#Filter all non-catalyst entities
def catalystentities(text):
    name_catalyst =  []
    comp = []
    if ('catalyst' in text.lower()) or ('catalysts' in text.lower()):
        cataa = []
        doc = Document(text)
        ent = doc.cems
        for i in range(len(ent)):
            comp.append(ent[i].text)
            doc = nlp(text)
            for chunk in doc.noun_chunks:
                for wrd in word_tokenize(chunk.text):
                    for cat in comp:
                        if (cat in cata):
                            if cat in wrd:
                                cataa.append(wrd)                            
    else:
        cataa = []
                                
    
    name_catalyst.append(cataa)                           
    return cataa

# %%
# %%time
df_net['catalyst'] =  df_net['Abstract'].apply(catalystentities)    #estimate time 56sec
# Out:
# CPU times: user 12min 38s, sys: 128 ms, total: 12min 38s
# Wall time: 12min 38s

# %%
df_net.head(5)
# Out:
#                              DOI  \
# 0   10.1016/j.susmat.2022.e00562
# 1     10.1016/j.jobe.2022.105541
# 2  10.1016/j.polymer.2022.125596
# 3     10.1016/j.fpsl.2022.101020
# 4     10.1016/j.egyr.2022.07.101
#
#                                                Title  \
# 0  Environmental assessment of the recycling proc...
# 1  Sustainable utilization of hybrid recycled pow...
# 2  Simulations mapping the influence of oxygen, e...
# 3  Migration of volatile substances from recycled...
# 4  Effect of compatibilization agents and rice hu...
#
#                                             Abstract             Date  \
# 0  The plastic packaging, and in particular the m...       April 2023
# 1  The effects of hybrid recycled powder (HRP) fr...   1 January 2023
# 2  We present a computational study of the develo...  16 January 2023
# 3  Plastic recycling is the main solution to redu...       March 2023
# 4  The new trend of the circular economy encourag...    November 2022
#
#                                   Journal catalyst
# 0  Sustainable Materials and Technologies       []
# 1         Journal of Building Engineering       []
# 2                                 Polymer       []
# 3           Food Packaging and Shelf Life       []
# 4                          Energy Reports       []

# %%
#Delete same entries
def deleteduplicate(lisst):
    listsss =  []
    [listsss.append(li) for li in lisst if li not in listsss]
    
    return listsss

# %%
# %%time
df_net['catalyst'] =  df_net['catalyst'].apply(deleteduplicate)  #estimate time 20msec
# Out:
# CPU times: user 33.3 ms, sys: 4 ms, total: 37.3 ms
# Wall time: 36.1 ms

# %%
from gensim.parsing.preprocessing import remove_stopwords
def deletestopwords(listt):
    actual_reactant = []
    for wrd in listt:
        filtered_sentencee = remove_stopwords(wrd)
        actual_reactant.append(filtered_sentencee)
    return actual_reactant

# %%
# %%time
df_net['catalyst'] =  df_net['catalyst'].apply(deletestopwords)  #estimate time 20msec
# Out:
# CPU times: user 14.1 ms, sys: 0 ns, total: 14.1 ms
# Wall time: 13.7 ms

# %%
print("Shape of data",len(df_net))
# Out:
# Shape of data 16494

# %%
df_net
# Out:
#                                       DOI  \
# 0            10.1016/j.susmat.2022.e00562
# 1              10.1016/j.jobe.2022.105541
# 2           10.1016/j.polymer.2022.125596
# 3              10.1016/j.fpsl.2022.101020
# 4              10.1016/j.egyr.2022.07.101
# ...                                   ...
# 16489  10.1016/B978-0-12-821709-2.00001-3
# 16490          10.1016/j.mcat.2022.112480
# 16491        10.1016/j.mtcomm.2020.100982
# 16492       10.1016/j.pnucene.2020.103270
# 16493        10.1016/j.wasman.2019.04.048
#
#                                                    Title  \
# 0      Environmental assessment of the recycling proc...
# 1      Sustainable utilization of hybrid recycled pow...
# 2      Simulations mapping the influence of oxygen, e...
# 3      Migration of volatile substances from recycled...
# 4      Effect of compatibilization agents and rice hu...
# ...                                                  ...
# 16489  Chapter 1 High-performance polymer application...
# 16490  Zinc and magnesium catalysts for the synthesis...
# 16491  Review of catalyst materials in achieving the ...
# 16492  Production of high quality ammonium uranyl car...
# 16493  Separation of polyvinylchloride and acrylonitr...
#
#                                                 Abstract             Date  \
# 0      The plastic packaging, and in particular the m...       April 2023
# 1      The effects of hybrid recycled powder (HRP) fr...   1 January 2023
# 2      We present a computational study of the develo...  16 January 2023
# 3      Plastic recycling is the main solution to redu...       March 2023
# 4      The new trend of the circular economy encourag...    November 2022
# ...                                                  ...              ...
# 16489                 The demand for high-performance...             2021
# 16490  Homoleptic and heteroleptic zinc and magnesium...      August 2022
# 16491  Present study aims to highlight the recent dev...   September 2020
# 16492  The purpose of this study is to investigate pr...       April 2020
# 16493  A combining technology of advanced oxidation b...      15 May 2019
#
#                                                  Journal           catalyst
# 0                 Sustainable Materials and Technologies                 []
# 1                        Journal of Building Engineering                 []
# 2                                                Polymer                 []
# 3                          Food Packaging and Shelf Life                 []
# 4                                         Energy Reports                 []
# ...                                                  ...                ...
# 16489  Nano Tools and Devices for Enhanced Renewable ...                 []
# 16490                                Molecular Catalysis  [zinc, magnesium]
# 16491                     Materials Today Communications                 []
# 16492                         Progress in Nuclear Energy                 []
# 16493                                   Waste Management                 []
#
# [16494 rows x 6 columns]

# %%
indd = []
for i,cata in enumerate(df_net['catalyst']):
    if len(cata) != 0:
        indd.append(i)
        
len(indd)
# Out:
# 1145

# %%
#df_cat = df.loc[indd].reset_index(drop = True)

# %%
#df_cat.to_csv('/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/data/harshita/data_cat_1136.csv')

# %% [markdown]
# **Extraction of Reactant (polymer waste)**

# %%
dff = df_net

# %%
#["polyethylene","waste","plastic", 'PET', 'wastes' ]   #We will try this words
j = 0
def reactantextract(text):
    reactants =  ['poly', 'waste', "wastes", "plastic", "plastics"]
#     print(j,"is done")
    reactant = []
    for sen in sent_tokenize(text):
#         if "poly" in sen:          #Keep it neutral(no biasing)
        doc = nlp(sen)
        for a, chunk in enumerate(doc.noun_chunks):
            for react in reactants:
                if react in reactant_ent:
                    if react in chunk.text:
                        reactant.append(chunk.text)
                    
    return reactant

# %%
# %%time
dff['reactant'] =  dff['Abstract'].apply(reactantextract)
# Out:
# CPU times: user 17min 53s, sys: 120 ms, total: 17min 53s
# Wall time: 17min 53s

# %%
def deleteduplicate(lisst):
    listsss =  []
    [listsss.append(li) for li in lisst if li not in listsss]
    
    return listsss

# %%
# %%time
dff['reactant'] =  dff['reactant'].apply(deleteduplicate) #estimate time 7 sec
# Out:
# CPU times: user 44.1 ms, sys: 5 µs, total: 44.1 ms
# Wall time: 42.8 ms

# %%
dff['reactant'][0]
# Out:
# ['The plastic packaging',
#  'polyamides-polyethylene multilayers packaging films',
#  'the polymers',
#  'polyamides-polyethylene films']

# %%
from gensim.parsing.preprocessing import remove_stopwords
def deletestopwords(listt):
    actual_reactant = []
    for wrd in listt:
        filtered_sentencee = remove_stopwords(wrd)
        actual_reactant.append(filtered_sentencee)
    return actual_reactant

# %%
dff['reactant'] =  dff['reactant'].apply(deletestopwords)

# %%
dff.head(2)
# Out:
#                             DOI  \
# 0  10.1016/j.susmat.2022.e00562
# 1    10.1016/j.jobe.2022.105541
#
#                                                Title  \
# 0  Environmental assessment of the recycling proc...
# 1  Sustainable utilization of hybrid recycled pow...
#
#                                             Abstract            Date  \
# 0  The plastic packaging, and in particular the m...      April 2023
# 1  The effects of hybrid recycled powder (HRP) fr...  1 January 2023
#
#                                   Journal catalyst  \
# 0  Sustainable Materials and Technologies       []
# 1         Journal of Building Engineering       []
#
#                                             reactant
# 0  [The plastic packaging, polyamides-polyethylen...
# 1  [composite concrete brick waste, recycled poly...

# %% [markdown]
# **Methodology entities extraction**

# %%
#Three list of keywords
methods =   ['pyrolysis','conversion',"depolymerization","degradation", "hydrolysis","chemical conversion","reforming",
             "glycolysis","thermal"]

# reactants = ["polyethylene","waste","plastic", 'PET', 'wastes' ]

products = ["ethylene glycol","terephthalic acid", "Terephthalonitrile","BHET","Liquid",
            "monomer", "products", 'added', 'energy', 'CH3CHO']

# %%
def methodextract(text):
    reactant = []
    for sen in sent_tokenize(text):
        for meth in methods:
            if meth in method_ent:
                if meth in sen:
                    doc = nlp(sen)
                    for a, chunk in enumerate(doc.noun_chunks):
                        if meth in chunk.text:
                            reactant.append(chunk.text)
                        else:
                            reactant.append(meth)

    return reactant

# %%
def deleteduplicate(lisst):
    listsss =  []
    [listsss.append(li) for li in lisst if li not in listsss]
    
    return listsss

# %%
dff.shape
# Out:
# (16494, 7)

# %%
# %%time
dff['Method'] =  dff['Abstract'].apply(methodextract)
# Out:
# CPU times: user 1min 41s, sys: 20 ms, total: 1min 41s
# Wall time: 1min 41s

# %%
dff['Method'] = dff['Method'].apply(deleteduplicate)

# %%
dff['Method'] = dff['Method'].apply(deletestopwords)

# %%
indd = []
for i,cata in enumerate(dff['Method']):
    if len(cata) != 0:
        indd.append(i)
        
len(indd)
# Out:
# 6126

# %%
df_meth = dff.loc[indd].reset_index(drop = True)

# %%
df_meth.to_csv('/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/data/harshita/data_meth.csv')

# %% [markdown]
# **Extraction of products**

# %%
"propylene" in "polypropylene"
dff = df_net

# %%
#A list of keywords

products_pet = ["ethylene glycol","terephthalic acid", "Terephthalonitrile","BHET","Liquid",
            "monomer", "product", 'added', 'energy', 'CH3CHO',"mortar"]
products_ps = ["styrene", "monomers", "monomer","other valuable chemcials", "concrete","bitumen","oil","oils", 
               "HIPS membranes",'low-molecular' ]
products_pe = ["high-performance", "PU adhesive", "sand concrete","HAC","hydroxyapatite" ]

products_pp = ["fibers","fibre","food containers"]

#"matrix"

# %%
net_product =  products_pet + products_ps + products_pe + products_pp

# %%
def productextract(text):
    product = []
    for sen in sent_tokenize(text):
        for prod in net_product:
            if prod in product_ent:
                if prod in sen:
                    doc = nlp(sen)
                    for a, chunk in enumerate(doc.noun_chunks):
                        if prod in chunk.text:
                            product.append(chunk.text)
    #                     else:
    #                         product.append(prod)
                        
    return product

# %%
# %%time
dff['Product'] =  dff['Abstract'].apply(productextract)
# Out:
# CPU times: user 6min 44s, sys: 39.6 ms, total: 6min 44s
# Wall time: 6min 44s

# %%
dff['Product'] = dff['Product'].apply(deleteduplicate)

# %%
dff['Product'] = dff['Product'].apply(deletestopwords)

# %%
dff.head(2)
# Out:
#                             DOI  \
# 0  10.1016/j.susmat.2022.e00562
# 1    10.1016/j.jobe.2022.105541
#
#                                                Title  \
# 0  Environmental assessment of the recycling proc...
# 1  Sustainable utilization of hybrid recycled pow...
#
#                                             Abstract            Date  \
# 0  The plastic packaging, and in particular the m...      April 2023
# 1  The effects of hybrid recycled powder (HRP) fr...  1 January 2023
#
#                                   Journal  \
# 0  Sustainable Materials and Technologies
# 1         Journal of Building Engineering
#
#                                              Product
# 0  [monoethylene glycol, final products quality, ...
# 1  [mortar, composite concrete brick waste, The h...

# %%
dff['Product'][33]
# Out:
# []

# %%
indd = []
for i,cata in enumerate(dff['Product']):
    if len(cata) != 0:
        indd.append(i)
        
len(indd)
# Out:
# 9128

# %%
#df_prod = dff.loc[indd].reset_index(drop = True)

# %%
#df_prod.to_csv('/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/data/harshita/data_prod.csv')

# %%
indee = []
for d in dff.index:
    if (len(dff['process'][d]) != 0) and (len(dff['catalyst'][d]) != 0) and (len(dff['reactant'][d]) != 0) and (len(dff['Method'][d]) != 0) and (len(dff['Product'][d]) != 0):
        indee.append(d)
        
len(indee)
# Out:
# 13

# %%
dff_ff.to_csv('/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/data/harshita/data_full_paper.csv')

# %%
dff['process'] = dff['process'].apply(deleteduplicate)
dff['Product'] = dff['Product'].apply(deleteduplicate)
dff['reactant'] = dff['reactant'].apply(deleteduplicate)
dff["Method"] = dff['Method'].apply(deleteduplicate)
dff['catalyst'] = dff['catalyst'].apply(deleteduplicate)

# %% [markdown]
# **1. QnA for catalyst**

# %%
def answers(num, total_text, catalystss):
    listss =  []  #Above list for answer  

    for a in range(len(catalystss)):
    #if len(catalystss) != 0:
        dicttt = {} # One anwser list
        dicttt["text"] = catalystss[a]
        values = total_text.split(catalystss[a])
        b = 0
        for c in values[0]:
            b = b + 1
        dicttt["answer_start"] = b

        listss.append(dicttt)
        
    return listss

# %%
dff = df_net

# %%
indd = []
for i,cata in enumerate(dff['catalyst']):
    if len(cata) != 0:
        indd.append(i)
        
len(indd)
# Out:
# 1145

# %%
import random

# %%
#ext_ind[3004:3100]+indd

# %%
dff_cat = dff.loc[indd].reset_index(drop = True)

# %%
dff_cat.shape
# Out:
# (1145, 6)

# %%
data = dff_cat

# %%
indeeee = []
for i in range(len(data)):
    if int(data.Date[i][-4:]) == 2023:
        if len(data.catalyst[i]) != 0:
            
            indeeee.append(i)
len(indeeee)
# Out:
# 63

# %%
data = data.iloc[indeeee].reset_index(drop=True)
len(data)
# Out:
# 63

# %%
y = []
for i in range(len(data)):
    if len(data['catalyst'][i]) != 0:
        #print(data['catalyst'][i])
        for catt in data['catalyst'][i]:
            y.append(catt)

# %%
from wordcloud import WordCloud

# matplotlib library
import matplotlib.pyplot as plt

# Joining all the processed lines together. Whole PDF
long_string = ''.join([str(i) for i in y])

# WordCloud object
wordcloud = WordCloud(background_color="white", 
                      max_words=100000, 
                      contour_width=5, 
                      contour_color='steelblue',
                      repeat = False,
                      relative_scaling = 0.5,
                      min_font_size=3,
                      max_font_size = 40)
wordcloud.generate(long_string)

# Visualizing
wordcloud.to_image()

plt.imshow(wordcloud) # image show
plt.axis('off') # to off the axis of x and y
plt.savefig('/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/result/catalyst/catalyst_2023.pdf',dpi=2000,bbox_inches='tight')
plt.show()

# %%
#visualization library
import matplotlib.pyplot as plt
from pylab import *
from matplotlib import rc

#Utilize the wordcloud library
from wordcloud import WordCloud

#Import the warning library
import warnings
warnings.filterwarnings("ignore")

# %%
#define the function for get the name of chemical entities and their frequency
def get_chemical_entry_count(column, size):
    catal = []
    #Remove the all punctution
    catalyst_column= pd.Series(column).str.replace('[^\w\s]','')
    for i in range(size):
        cat_list = catalyst_column[i].split(" ")
        for j in range(len(cat_list)):
            #Appending the catalyst
            catal.append(cat_list[j])
            #frequency of existence
            unique, frequency = np.unique(np.array(catal), return_counts = True)
            #Making data frame of uniqueness and frequency
            df_unique_counts = pd.DataFrame({'section name' : unique, 'frequency' : frequency})
            
    return df_unique_counts

#Call the defined function
df_cat_freq = get_chemical_entry_count(y, len(y))

# %%
#Sorting the data frame based on frequency available
sort = df_cat_freq.sort_values("frequency", axis = 0, ascending = False).reset_index(drop = True)
#print(Number of unique chemicals)
print('Number of unique chemicals:', sort.shape[0])
#Shows the first 5 rows
sort.head()
# Out:
# Number of unique chemicals: 63
#   section name  frequency
# 0           Ni          7
# 1           Co          5
# 2         AgMn          4
# 3      CoFe2O4          4
# 4      zeolite          4

# %%
#year 2020
df_list_catalyst = sort

#A zipf line plot is shown
counts = df_list_catalyst.frequency
tokens = df_list_catalyst['section name']

ranks = np.arange(1, len(counts)+1)
indices = argsort(-counts)
frequencies = counts[indices]

# %%
#2017
df_list_catalyst17 = sort

# %%
#2018
df_list_catalyst18 = sort

# %%
#2019
df_list_catalyst19 = sort

# %%
#year 2021
df_list_catalyst1 = sort

# %%
#2022
df_list_catalyst2 = sort

# %%
#2023
df_list_catalyst3 = sort

# %%
#A zipf line plot is shown
counts = df_list_catalyst.frequency
tokens = df_list_catalyst['section name']

ranks = np.arange(1, len(counts)+1)
indices = argsort(-counts)
frequencies = counts[indices]


#A zipf line plot is shown
counts1 = df_list_catalyst1.frequency
tokens1 = df_list_catalyst1['section name']

ranks1 = np.arange(1, len(counts1)+1)
indices1 = argsort(-counts1)
frequencies1 = counts1[indices1]

#A zipf line plot is shown
counts2 = df_list_catalyst2.frequency
tokens2 = df_list_catalyst2['section name']

ranks2 = np.arange(1, len(counts2)+1)
indices2 = argsort(-counts2)
frequencies2 = counts2[indices2]

#A zipf line plot is shown
counts3 = df_list_catalyst3.frequency
tokens3 = df_list_catalyst3['section name']

ranks3 = np.arange(1, len(counts3)+1)
indices3 = argsort(-counts3)
frequencies3 = counts3[indices3]

# %%
#A zipf line plot is shown
counts17 = df_list_catalyst17.frequency
tokens17 = df_list_catalyst17['section name']

ranks17 = np.arange(1, len(counts17)+1)
indices17 = argsort(-counts17)
frequencies17 = counts17[indices17]


#A zipf line plot is shown
counts18 = df_list_catalyst18.frequency
tokens18 = df_list_catalyst18['section name']

ranks18 = np.arange(1, len(counts18)+1)
indices18 = argsort(-counts18)
frequencies18 = counts18[indices18]

#A zipf line plot is shown
counts19 = df_list_catalyst19.frequency
tokens19 = df_list_catalyst19['section name']

ranks19 = np.arange(1, len(counts19)+1)
indices19 = argsort(-counts19)
frequencies19 = counts19[indices19]

# %%
plt.figure(figsize=(10,8))

plt.ylim(1,10**5)
plt.xlim(1,10**3)

loglog(ranks3, frequencies3, marker=".", label = '2023')
loglog(ranks2, frequencies2, marker=".", label = '2022')
loglog(ranks1, frequencies1, marker=".", label = '2021')
loglog(ranks, frequencies, marker=".", label = '2020')



xlabel("Rank of catalyst entity",fontweight='bold', fontsize=16)
ylabel("Absolute frequency of catalyst entity",fontweight='bold', fontsize=16)

plt.rcParams['axes.linewidth'] = 2
rc('font', weight='bold')

plt.tick_params(axis="x", direction="in",width=2)
plt.tick_params(axis="y", direction="in", width=2)

grid(True)
for n in list(logspace(-0.5, log10(len(counts)-2), 25).astype(int)):
    dummy = text(ranks[n], frequencies[n], " " + tokens[indices[n]], 
                 verticalalignment="bottom",
                 horizontalalignment="left", fontweight='bold',
                 fontsize=12, rotation = 'vertical')
    
for n in list(logspace(-0.5, log10(len(counts1)-2), 25).astype(int)):
    dummy1 = text(ranks1[n], frequencies1[n], " " + tokens1[indices1[n]], 
                 verticalalignment="bottom",
                 horizontalalignment="left", fontweight='bold',
                 fontsize=12, rotation = 'vertical')
    
for n in list(logspace(-0.5, log10(len(counts2)-2), 25).astype(int)):
    dummy2 = text(ranks2[n], frequencies2[n], " " + tokens2[indices2[n]], 
                 verticalalignment="bottom",
                 horizontalalignment="left", fontweight='bold',
                 fontsize=12, rotation = 'vertical')
    
for n in list(logspace(-0.5, log10(len(counts3)-2), 25).astype(int)):
    dummy3 = text(ranks3[n], frequencies3[n], " " + tokens3[indices3[n]], 
                 verticalalignment="bottom",
                 horizontalalignment="left", fontweight='bold',
                 fontsize=12, rotation = 'vertical')
#Save the plot
plt.legend()
plt.savefig(r'/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/result/catalyst/zipf_catalyst_text.pdf', dpi=5000)

plt.show()

# %%
plt.figure(figsize=(10,8))

plt.ylim(1,1*10**1)
plt.xlim(0.8,1*10**2)

# loglog(ranks3, frequencies3, marker=".", label = '2023')
# loglog(ranks2, frequencies2, marker=".", label = '2022')
# loglog(ranks1, frequencies1, marker=".", label = '2021')
loglog(ranks, frequencies, marker=".", label = '2023')
# loglog(ranks19, frequencies19, marker=".", label = '2019')
# loglog(ranks18, frequencies18, marker=".", label = '2018')
# loglog(ranks17, frequencies17, marker=".", label = '2017')


xlabel("Rank of catalyst entity",fontweight='bold', fontsize=21)
ylabel("Absolute frequency of catalyst entity",fontweight='bold', fontsize=21)

plt.rcParams['axes.linewidth'] = 2
rc('font', weight='bold')

plt.tick_params(axis="x", direction="in",width=2)
plt.tick_params(axis="y", direction="in", width=2)

grid(True)
for n in list(logspace(-0.5, log10(len(counts)-2), 25).astype(int)):
    dummy = text(ranks[n], frequencies[n], " " + tokens[indices[n]], 
                 verticalalignment="bottom",
                 horizontalalignment="left", fontweight='bold',
                 fontsize=18,rotation ='vertical')
    
    
# for n in list(logspace(-0.5, log10(len(counts17)-2), 25).astype(int)):
#     dummy2 = text(ranks17[n], frequencies17[n], " " + tokens17[indices17[n]], 
#                  verticalalignment="bottom",
#                  horizontalalignment="left", fontweight='bold',
#                  fontsize=18, rotation ='vertical')
#Save the plot
plt.legend()
plt.savefig(r'/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/result/catalyst/zipf_catalyst_text_2023.pdf', dpi=5000)

plt.show()

# %%
dff_cat.head()
# Out:
#                              DOI  \
# 0   10.1016/j.seppur.2021.118821
# 1  10.1016/S1385-8947(00)00347-8
# 2     10.1016/j.fuel.2020.119155
# 3     10.1016/j.jaap.2022.105719
# 4     10.1016/j.jaap.2022.105719
#
#                                                Title  \
# 0  Flexible CuS/TiO2 based composites made with r...
# 1  Chemical recycling of mixture of waste plastic...
# 2  A Cu doped TiO2 catalyst mediated Catalytic Th...
# 3  Catalytic process toward green recycling of po...
# 4  Catalytic process toward green recycling of po...
#
#                                             Abstract process  \
# 0  We report the use of flexible photocatalytic c...      []
# 1  A new reactor system was developed for recover...      []
# 2  Plastic waste has been identified as a potent ...      []
# 3  Municipal solid wastes (MSW) include a conside...      []
# 4  Municipal solid wastes (MSW) include a conside...      []
#
#                                       catalyst  \
# 0  [CuS/TiO2, TiO2, CuST, RBag-CuST, RPS-CuST]
# 1                                     [Ni-REY]
# 2                           [Cu, TiO2, copper]
# 3                   [zeolites, zeolite, Si/Al]
# 4                   [zeolites, zeolite, Si/Al]
#
#                                             reactant  \
# 0               [recycled polystyrene, /polystyrene]
# 1  [waste plastic mixture, plastics, polyolefins,...
# 2  [Plastic waste, plastic, polyolefinic plastic ...
# 3  [Municipal solid wastes, polyvinyl chloride, P...
# 4  [Municipal solid wastes, polyvinyl chloride, P...
#
#                                               Method  \
# 0  [degradation, maximum degradation percentage, ...
# 1              [degradation mechanisms, degradation]
# 2  [conversion, maximum conversion, >85% conversion]
# 3  [pyrolysis, pyrolysis-gas chromatography-mass ...
# 4  [pyrolysis, pyrolysis-gas chromatography-mass ...
#
#                                              Product
# 0  [recycled polystyrene, The production, product...
# 1                                   [heavy oil, oil]
# 2  [hydrocarbon liquid oil, hydrocarbon oil, energy]
# 3  [organic pollutant production, secondary pollu...
# 4  [organic pollutant production, secondary pollu...

# %%
train = []

j =1
for inde,abst in enumerate(dff_cat['Abstract']):
    data1 = {} #This list for a context 
    
    data1["context"] =  abst
    
    dictt_cat = {}   #Dict for catalyst question
    dictt_react = {} #Dict for reactants question
    dictt_metho= {} #Dict for method question
    dictt_prod = {} #Dict for product question
    
    #The data making for the catalyst entries
    comp =  dff_cat['catalyst'][inde]
    if len(comp) != 0:
        listt = []
        #This dict for QnA task
        dictt_cat["id"] = str(j)   # j tells the question number

        boolen_list = [True, False]    # tells the is it possible to answer or not
        dictt_cat["is_impossible"] =  boolen_list[1]

        ques = ["What are the materials used as catalyst?"]   #Question write here
        dictt_cat["question"] = ques[0]

        listttt_cat = answers(inde, abst,comp)
        j = j+1
    elif len(comp) == 0:
        #THis dict for QnA task
        dictt_cat["id"] = str(j)

        boolen_list = [True, False]
        dictt_cat["is_impossible"] =  boolen_list[0]

        ques = ["What are the materials used as catalyst?"] 
        dictt_cat["question"] = ques[0]

        listttt_cat =  []
        #listss.append(answers(sent, s))
        j = j+1
    
    
    dictt_cat["answers"] = listttt_cat
#     dictt_react["answers"] = listttt_react
#     dictt_metho["answers"] = listttt_metho
#     dictt_prod["answers"]  = listttt_prod
    
    lisst= []    #QnA list where question and answer exist
    
    lisst.append(dictt_cat)
#     lisst.append(dictt_react)
#     lisst.append(dictt_metho)
#     lisst.append(dictt_prod)
    
    data1["qas"] = lisst
    
    train.append(data1)

# %%
len(train)
# Out:
# 1138

# %%
train_ = train[:int(0.80*(len(train)))]                       # 80% train
valid_ = train[int(0.80*(len(train))):int(0.90*(len(train)))] #10% valid 
test_  = train[int(0.90*(len(train))):]                       #10% test

# %%
len(train_), len(test_), len(valid_)
# Out:
# (910, 114, 114)

# %%
import json
with open('/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/result/catalyst/cat_train.json', 'w') as F:
    # Use the json dumps method to write the list to disk
    F.write(json.dumps(train_))

# %%
import json
with open('/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/result/catalyst/cat_test.json', 'w') as F:
    # Use the json dumps method to write the list to disk
    F.write(json.dumps(test_))

# %%
import json
with open('/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/result/catalyst/cat_valid.json', 'w') as F:
    # Use the json dumps method to write the list to disk
    F.write(json.dumps(valid_))

# %%
import json
with open('/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/result/catalyst/cat_full.json', 'w') as F:
    # Use the json dumps method to write the list to disk
    F.write(json.dumps(train))

# %% [markdown]
# **2. QnA for reactant**

# %%
def answers(num, total_text, catalystss):
    listss =  []  #Above list for answer  

    for a in range(len(catalystss)):
    #if len(catalystss) != 0:
        dicttt = {} # One anwser list
        dicttt["text"] = catalystss[a]
        values = total_text.split(catalystss[a])
        b = 0
        for c in values[0]:
            b = b + 1
        dicttt["answer_start"] = b

        listss.append(dicttt)
        
    return listss

# %%
indd = []
for i,cata in enumerate(dff['reactant']):
    if len(cata) != 0:
        indd.append(i)
        
len(indd)
# Out:
# 14134

# %%
import random

# %%
#ext_ind[3004:3100]+indd

# %%
dff_react = dff.loc[indd].reset_index(drop = True)

# %%
data = dff_react

# %%
indeeee = []
for i in range(len(data)):
    if int(data.Date[i][-4:]) == 2017:
        if len(data.catalyst[i]) != 0:
            indeeee.append(i)
            
len(indeeee)
# Out:
# 79

# %%
data = data.iloc[indeeee].reset_index(drop=True)
len(data)
# Out:
# 79

# %%
y = []
for i in range(len(data)):
    if len(data['reactant'][i]) != 0:
        #print(data['catalyst'][i])
        for catt in data['reactant'][i]:
            y.append(catt)

# %%
from wordcloud import WordCloud

# matplotlib library
import matplotlib.pyplot as plt

# Joining all the processed lines together. Whole PDF
long_string = ''.join([str(i) for i in y])

# WordCloud object
wordcloud = WordCloud(background_color="white", 
                      max_words=100000, 
                      contour_width=5, 
                      contour_color='steelblue',
                      repeat = False,
                      relative_scaling = 0.5,
                      min_font_size=3,
                      max_font_size = 40)
wordcloud.generate(long_string)

# Visualizing
wordcloud.to_image()

plt.imshow(wordcloud) # image show
plt.axis('off') # to off the axis of x and y
plt.savefig('/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/result/reactant/reactant_2017.pdf',dpi=2000,bbox_inches='tight')
plt.show()

# %%
#visualization library
import matplotlib.pyplot as plt
from pylab import *
from matplotlib import rc

#Utilize the wordcloud library
from wordcloud import WordCloud

#Import the warning library
import warnings
warnings.filterwarnings("ignore")

# %%
#define the function for get the name of chemical entities and their frequency
def get_chemical_entry_count(column, size):
    catal = []
    #Remove the all punctution
    catalyst_column= pd.Series(column).str.replace('[^\w\s]','')
    for i in range(size):
        cat_list = catalyst_column[i].split(" ")
        for j in range(len(cat_list)):
            #Appending the catalyst
            catal.append(cat_list[j])
            #frequency of existence
            unique, frequency = np.unique(np.array(catal), return_counts = True)
            #Making data frame of uniqueness and frequency
            df_unique_counts = pd.DataFrame({'section name' : unique, 'frequency' : frequency})
            
    return df_unique_counts

#Call the defined function
df_cat_freq = get_chemical_entry_count(y, len(y))

# %%
#Sorting the data frame based on frequency available
sort = df_cat_freq.sort_values("frequency", axis = 0, ascending = False).reset_index(drop = True)
#print(Number of unique chemicals)
print('Number of unique chemicals:', sort.shape[0])
#Shows the first 5 rows
sort.head()
# Out:
# Number of unique chemicals: 133
#    section name  frequency
# 0         waste         53
# 1   polystyrene         33
# 2  polyethylene         32
# 3       plastic         21
# 4          high         13

# %%
#year 2020
df_list_catalyst = sort

#A zipf line plot is shown
counts = df_list_catalyst.frequency
tokens = df_list_catalyst['section name']

ranks = np.arange(1, len(counts)+1)
indices = argsort(-counts)
frequencies = counts[indices]

# %%
#year 2021
df_list_catalyst1 = sort

# %%
#2022
df_list_catalyst2 = sort

# %%
#2023
df_list_catalyst3 = sort

# %%
#A zipf line plot is shown
counts = df_list_catalyst.frequency
tokens = df_list_catalyst['section name']

ranks = np.arange(1, len(counts)+1)
indices = argsort(-counts)
frequencies = counts[indices]


#A zipf line plot is shown
counts1 = df_list_catalyst1.frequency
tokens1 = df_list_catalyst1['section name']

ranks1 = np.arange(1, len(counts1)+1)
indices1 = argsort(-counts1)
frequencies1 = counts1[indices1]

#A zipf line plot is shown
counts2 = df_list_catalyst2.frequency
tokens2 = df_list_catalyst2['section name']

ranks2 = np.arange(1, len(counts2)+1)
indices2 = argsort(-counts2)
frequencies2 = counts2[indices2]

#A zipf line plot is shown
counts3 = df_list_catalyst3.frequency
tokens3 = df_list_catalyst3['section name']

ranks3 = np.arange(1, len(counts3)+1)
indices3 = argsort(-counts3)
frequencies3 = counts3[indices3]

# %%
plt.figure(figsize=(10,8))

plt.ylim(1,10**3)
plt.xlim(1,0.5*10**4)

loglog(ranks3, frequencies3, marker=".", label = '2023')
loglog(ranks2, frequencies2, marker=".", label = '2022')
loglog(ranks1, frequencies1, marker=".", label = '2021')
loglog(ranks, frequencies, marker=".", label = '2020')



xlabel("Rank of reactant entity",fontweight='bold', fontsize=16)
ylabel("Absolute frequency of reactant entity",fontweight='bold', fontsize=16)

plt.rcParams['axes.linewidth'] = 2
rc('font', weight='bold')

plt.tick_params(axis="x", direction="in",width=2)
plt.tick_params(axis="y", direction="in", width=2)

grid(True)
for n in list(logspace(-0.5, log10(len(counts)-2), 25).astype(int)):
    dummy = text(ranks[n], frequencies[n], " " + tokens[indices[n]], 
                 verticalalignment="bottom",
                 horizontalalignment="left", fontweight='bold',
                 fontsize=12)
    
for n in list(logspace(-0.5, log10(len(counts1)-2), 25).astype(int)):
    dummy1 = text(ranks1[n], frequencies1[n], " " + tokens1[indices1[n]], 
                 verticalalignment="bottom",
                 horizontalalignment="left", fontweight='bold',
                 fontsize=12)
    
for n in list(logspace(-0.5, log10(len(counts2)-2), 25).astype(int)):
    dummy2 = text(ranks2[n], frequencies2[n], " " + tokens2[indices2[n]], 
                 verticalalignment="bottom",
                 horizontalalignment="left", fontweight='bold',
                 fontsize=12)
    
for n in list(logspace(-0.5, log10(len(counts3)-2), 25).astype(int)):
    dummy3 = text(ranks3[n], frequencies3[n], " " + tokens3[indices3[n]], 
                 verticalalignment="bottom",
                 horizontalalignment="left", fontweight='bold',
                 fontsize=12)
#Save the plot
plt.legend()
plt.savefig(r'/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/result/reactant/zipf_reactant_text.pdf', dpi=5000)

plt.show()

# %%
plt.figure(figsize=(10,8))

plt.ylim(1,0.2*10**3)
plt.xlim(0.9,0.2*10**3)

# loglog(ranks3, frequencies3, marker=".", label = '2023')
# loglog(ranks2, frequencies2, marker=".", label = '2022')
# loglog(ranks1, frequencies1, marker=".", label = '2021')
loglog(ranks, frequencies, marker=".", label = '2017')



xlabel("Rank of reactant entity",fontweight='bold', fontsize=21)
ylabel("Absolute frequency of reactant entity",fontweight='bold', fontsize=21)

plt.rcParams['axes.linewidth'] = 2
rc('font', weight='bold')

plt.tick_params(axis="x", direction="in",width=2)
plt.tick_params(axis="y", direction="in", width=2)

grid(True)
for n in list(logspace(-0.5, log10(len(counts)-2), 25).astype(int)):
    dummy = text(ranks[n], frequencies[n], " " + tokens[indices[n]], 
                 verticalalignment="bottom",
                 horizontalalignment="left", fontweight='bold',
                 fontsize=18, rotation= 'vertical')
    

#Save the plot
plt.legend()
plt.savefig(r'/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/result/reactant/zipf_reactant_text_2017.pdf', dpi=5000)

plt.show()

# %%
dff_react.head()
# Out:
#                                  DOI  \
# 0        10.1533/9781845697662.2.102
# 1         10.1016/j.fuel.2021.120505
# 2  10.1016/j.conbuildmat.2022.127949
# 3       10.1016/j.arabjc.2022.104262
# 4  10.1016/j.conbuildmat.2019.117253
#
#                                                Title  \
# 0        5 Pyrolysis for recycling waste composites
# 1  Low-pressure hydrothermal processing of mixed ...
# 2  Cement mortars with ceramic molds shells and p...
# 3  Degradation-fragmentation of marine plastic wa...
# 4  Performance of AC mixtures containing flakes o...
#
#                                             Abstract            process  \
# 0                 Pyrolysis is a suitable process...                 []
# 1  The amount of polyolefin waste, which is 63% o...  [≥23 MPa, ~2 MPa]
# 2  Foundry industry produces millions of tons of ...                 []
# 3  This review critically evaluates the plastic a...                 []
# 4  This paper evaluates the performance of asphal...                 []
#
#   catalyst                                           reactant  \
# 0       []  [polymer composites, frequently thermoplastics...
# 1       []  [polyolefin waste, total plastic waste, 50% po...
# 2       []                                           [wastes]
# 3       []  [plastic accumulation challenges, plastic prod...
# 4       []  [low density polyethylene, plastic film, optim...
#
#                                               Method  \
# 0  [thermal, thermal decomposition products, pyro...
# 1  [Its degradation products, degradation, A new ...
# 2                                                 []
# 3  [degradation, degradation fragmentation phenom...
# 4                                                 []
#
#                                              Product
# 0  [thermal decomposition products, monomers, The...
# 1  [Its degradation products, high capital energy...
# 2  [cement mortars, mortars physical mechanical p...
# 3                           [plastic products, soil]
# 4                                 [asphalt concrete]

# %%
train = []

j =1
for inde,abst in enumerate(dff_react['Abstract']):
    data1 = {} #This list for a context 
    
    data1["context"] =  abst
    
    dictt_cat = {}   #Dict for catalyst question
    dictt_react = {} #Dict for reactants question
    dictt_metho= {} #Dict for method question
    dictt_prod = {} #Dict for product question
    
    #The data making for the catalyst entries
    react =  dff_react['reactant'][inde]
    if len(react) != 0:
        listt = []
        #This dict for QnA task
        dictt_react["id"] = str(j)   # j tells the question number

        boolen_list = [True, False]    # tells the is it possible to answer or not
        dictt_react["is_impossible"] =  boolen_list[1]

        ques = ["What are the reactants used?"]   #Question write here
        dictt_react["question"] = ques[0]

        listttt_react = answers(inde, abst,react)
        j = j+1
    elif len(react) == 0:
        #THis dict for QnA task
        dictt_react["id"] = str(j)

        boolen_list = [True, False]
        dictt_react["is_impossible"] =  boolen_list[0]

        ques = ["What are the reactants used?"] 
        dictt_react["question"] = ques[0]

        listttt_react =  []
        #listss.append(answers(sent, s))
        j = j+1

    
    
#     dictt_cat["answers"] = listttt_cat
    dictt_react["answers"] = listttt_react
#     dictt_metho["answers"] = listttt_metho
#     dictt_prod["answers"]  = listttt_prod
    
    lisst= []    #QnA list where question and answer exist
    
#     lisst.append(dictt_cat)
    lisst.append(dictt_react)
#     lisst.append(dictt_metho)
#     lisst.append(dictt_prod)
    
    data1["qas"] = lisst
    
    train.append(data1)

# %%
len(train)
# Out:
# 18848

# %%
train_ = train[:int(0.80*(len(train)))]                       # 80% train
valid_ = train[int(0.80*(len(train))):int(0.90*(len(train)))] #10% valid 
test_  = train[int(0.90*(len(train))):]                       #10% test

# %%
len(train_), len(test_), len(valid_)
# Out:
# (16864, 2109, 2108)

# %%
import json
with open("/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/result/reactant/data/reat_train.json", 'w') as F:
    # Use the json dumps method to write the list to disk
    F.write(json.dumps(train_))

# %%
import json
with open("/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/result/reactant/data/reat_test.json", 'w') as F:
    # Use the json dumps method to write the list to disk
    F.write(json.dumps(test_))

# %%
import json
with open("/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/result/reactant/data/reat_valid.json", 'w') as F:
    # Use the json dumps method to write the list to disk
    F.write(json.dumps(valid_))

# %%
import json
with open("/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/result/reactant/data/reat_full.json", 'w') as F:
    # Use the json dumps method to write the list to disk
    F.write(json.dumps(train))

# %% [markdown]
# **3. QnA for method**

# %%
def answers(num, total_text, catalystss):
    listss =  []  #Above list for answer  

    for a in range(len(catalystss)):
    #if len(catalystss) != 0:
        dicttt = {} # One anwser list
        dicttt["text"] = catalystss[a]
        values = total_text.split(catalystss[a])
        b = 0
        for c in values[0]:
            b = b + 1
        dicttt["answer_start"] = b

        listss.append(dicttt)
        
    return listss

# %%
indd = []
for i,cata in enumerate(dff['Method']):
    if len(cata) != 0:
        indd.append(i)
        
len(indd)
# Out:
# 6126

# %%
import random

# %%
#ext_ind[3004:3100]+indd

# %%
dff_meth = dff.loc[indd].reset_index(drop = True)

# %%
data = dff_meth

# %%
indeeee = []
for i in range(len(data)):
    if int(data.Date[i][-4:]) == 2017:
        if len(data.catalyst[i]) != 0:
            indeeee.append(i)
            
len(indeeee)
# Out:
# 64

# %%
data = data.iloc[indeeee].reset_index(drop=True)
len(data)
# Out:
# 64

# %%
y = []
for i in range(len(data)):
    if len(data['Method'][i]) != 0:
        #print(data['catalyst'][i])
        for catt in data['Method'][i]:
            y.append(catt)

# %%
from wordcloud import WordCloud

# matplotlib library
import matplotlib.pyplot as plt

# Joining all the processed lines together. Whole PDF
long_string = ''.join([str(i) for i in y])

# WordCloud object
wordcloud = WordCloud(background_color="white", 
                      max_words=100000, 
                      contour_width=5, 
                      contour_color='steelblue',
                      repeat = False,
                      relative_scaling = 0.5,
                      min_font_size=3,
                      max_font_size = 40)
wordcloud.generate(long_string)

# Visualizing
wordcloud.to_image()

plt.imshow(wordcloud) # image show
plt.axis('off') # to off the axis of x and y
plt.savefig('/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/result/methods/method_2017.pdf',dpi=2000,bbox_inches='tight')
plt.show()

# %%
#visualization library
import matplotlib.pyplot as plt
from pylab import *
from matplotlib import rc

#Utilize the wordcloud library
from wordcloud import WordCloud

#Import the warning library
import warnings
warnings.filterwarnings("ignore")

# %%
#define the function for get the name of chemical entities and their frequency
def get_chemical_entry_count(column, size):
    catal = []
    #Remove the all punctution
    catalyst_column= pd.Series(column).str.replace('[^\w\s]','')
    for i in range(size):
        cat_list = catalyst_column[i].split(" ")
        for j in range(len(cat_list)):
            #Appending the catalyst
            catal.append(cat_list[j])
            #frequency of existence
            unique, frequency = np.unique(np.array(catal), return_counts = True)
            #Making data frame of uniqueness and frequency
            df_unique_counts = pd.DataFrame({'section name' : unique, 'frequency' : frequency})
            
    return df_unique_counts

#Call the defined function
df_cat_freq = get_chemical_entry_count(y, len(y))

# %%
#Sorting the data frame based on frequency available
sort = df_cat_freq.sort_values("frequency", axis = 0, ascending = False).reset_index(drop = True)
#print(Number of unique chemicals)
print('Number of unique chemicals:', sort.shape[0])
#Shows the first 5 rows
sort.head()
# Out:
# Number of unique chemicals: 69
#   section name  frequency
# 0   conversion         65
# 1    pyrolysis         54
# 2  degradation         48
# 3    reforming         26
# 4    catalytic         18

# %%
#year 2020
df_list_catalyst = sort

#A zipf line plot is shown
counts = df_list_catalyst.frequency
tokens = df_list_catalyst['section name']

ranks = np.arange(1, len(counts)+1)
indices = argsort(-counts)
frequencies = counts[indices]

# %%
#year 2021
df_list_catalyst1 = sort

# %%
#2022
df_list_catalyst2 = sort

# %%
#2023
df_list_catalyst3 = sort

# %%
#A zipf line plot is shown
counts = df_list_catalyst.frequency
tokens = df_list_catalyst['section name']

ranks = np.arange(1, len(counts)+1)
indices = argsort(-counts)
frequencies = counts[indices]


#A zipf line plot is shown
counts1 = df_list_catalyst1.frequency
tokens1 = df_list_catalyst1['section name']

ranks1 = np.arange(1, len(counts1)+1)
indices1 = argsort(-counts1)
frequencies1 = counts1[indices1]

#A zipf line plot is shown
counts2 = df_list_catalyst2.frequency
tokens2 = df_list_catalyst2['section name']

ranks2 = np.arange(1, len(counts2)+1)
indices2 = argsort(-counts2)
frequencies2 = counts2[indices2]

#A zipf line plot is shown
counts3 = df_list_catalyst3.frequency
tokens3 = df_list_catalyst3['section name']

ranks3 = np.arange(1, len(counts3)+1)
indices3 = argsort(-counts3)
frequencies3 = counts3[indices3]

# %%
plt.figure(figsize=(10,8))

plt.ylim(1,10**3)
plt.xlim(1,0.1*10**4)

loglog(ranks3, frequencies3, marker=".", label = '2023')
loglog(ranks2, frequencies2, marker=".", label = '2022')
loglog(ranks1, frequencies1, marker=".", label = '2021')
loglog(ranks, frequencies, marker=".", label = '2020')



xlabel("Rank of method entity",fontweight='bold', fontsize=16)
ylabel("Absolute frequency of method entity",fontweight='bold', fontsize=16)

plt.rcParams['axes.linewidth'] = 2
rc('font', weight='bold')

plt.tick_params(axis="x", direction="in",width=2)
plt.tick_params(axis="y", direction="in", width=2)

grid(True)
# for n in list(logspace(-0.5, log10(len(counts)-2), 25).astype(int)):
#     dummy = text(ranks[n], frequencies[n], " " + tokens[indices[n]], 
#                  verticalalignment="bottom",
#                  horizontalalignment="left", fontweight='bold',
#                  fontsize=12)
    
# for n in list(logspace(-0.5, log10(len(counts1)-2), 25).astype(int)):
#     dummy1 = text(ranks1[n], frequencies1[n], " " + tokens1[indices1[n]], 
#                  verticalalignment="bottom",
#                  horizontalalignment="left", fontweight='bold',
#                  fontsize=12)
    
# for n in list(logspace(-0.5, log10(len(counts2)-2), 25).astype(int)):
#     dummy2 = text(ranks2[n], frequencies2[n], " " + tokens2[indices2[n]], 
#                  verticalalignment="bottom",
#                  horizontalalignment="left", fontweight='bold',
#                  fontsize=12)
    
# for n in list(logspace(-0.5, log10(len(counts3)-2), 25).astype(int)):
#     dummy3 = text(ranks3[n], frequencies3[n], " " + tokens3[indices3[n]], 
#                  verticalalignment="bottom",
#                  horizontalalignment="left", fontweight='bold',
#                  fontsize=12)
#Save the plot
plt.legend()
plt.savefig(r'/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/result/methods/zipf_method.pdf', dpi=5000)

plt.show()

# %%
plt.figure(figsize=(10,8))

plt.ylim(1,0.5*10**3)
plt.xlim(0.9,0.9*10**2)

# loglog(ranks3, frequencies3, marker=".", label = '2023')
# loglog(ranks2, frequencies2, marker=".", label = '2022')
# loglog(ranks1, frequencies1, marker=".", label = '2021')
loglog(ranks, frequencies, marker=".", label = '2017')


xlabel("Rank of method entity",fontweight='bold', fontsize=21)
ylabel("Absolute frequency of method entity",fontweight='bold', fontsize=21)

plt.rcParams['axes.linewidth'] = 2
rc('font', weight='bold')

plt.tick_params(axis="x", direction="in",width=2)
plt.tick_params(axis="y", direction="in", width=2)

grid(True)
for n in list(logspace(-0.5, log10(len(counts)-2), 25).astype(int)):
    dummy = text(ranks[n], frequencies[n], " " + tokens[indices[n]], 
                 verticalalignment="bottom",
                 horizontalalignment="left", fontweight='bold',
                 fontsize=18, rotation= 'vertical')
    

#Save the plot
plt.legend()
plt.savefig(r'/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/result/methods/zipf_method_text_2017.pdf', dpi=5000)

plt.show()

# %%
dff_meth.head()
# Out:
#                              DOI  \
# 0    10.1533/9781845697662.2.102
# 1     10.1016/j.fuel.2021.120505
# 2   10.1016/j.arabjc.2022.104262
# 3      10.1016/j.cej.2021.133450
# 4  10.1016/j.jclepro.2021.128600
#
#                                                Title  \
# 0        5 Pyrolysis for recycling waste composites
# 1  Low-pressure hydrothermal processing of mixed ...
# 2  Degradation-fragmentation of marine plastic wa...
# 3  Synergetic effect of UiO-66 and plasmonic AgNP...
# 4  Exploring the feasibility of thermal digestion...
#
#                                             Abstract            process  \
# 0                 Pyrolysis is a suitable process...                 []
# 1  The amount of polyolefin waste, which is 63% o...  [≥23 MPa, ~2 MPa]
# 2  This review critically evaluates the plastic a...                 []
# 3  The combination of metal–organic frameworks (M...                 []
# 4  The study developed a holistic approach based ...                 []
#
#   catalyst                                           reactant  \
# 0       []  [polymer composites, frequently thermoplastics...
# 1       []  [polyolefin waste, total plastic waste, 50% po...
# 2       []  [plastic accumulation challenges, plastic prod...
# 3       []           [polyethylene terephthalate (PET) waste]
# 4       []            [solid organic waste, waste management]
#
#                                               Method  \
# 0  [thermal, thermal decomposition products, pyro...
# 1  [Its degradation products, degradation, A new ...
# 2  [degradation, degradation fragmentation phenom...
# 3  [degradation, photocatalytic degradation, The ...
# 4  [conversion, rapid conversion, thermal, therma...
#
#                                              Product
# 0  [thermal decomposition products, monomers, The...
# 1  [Its degradation products, high capital energy...
# 2                           [plastic products, soil]
# 3                                  [energy transfer]
# 4                   [high nutrient-rich end product]

# %%
train = []

j =1
for inde,abst in enumerate(dff_meth['Abstract']):
    data1 = {} #This list for a context 
    
    data1["context"] =  abst
    
    dictt_cat = {}   #Dict for catalyst question
    dictt_react = {} #Dict for reactants question
    dictt_metho= {} #Dict for method question
    dictt_prod = {} #Dict for product question
    
    ##Data making for methods 
    metho =  dff_meth['Method'][inde]
    if len(metho) != 0:
        listt = []
        #This dict for QnA task
        dictt_metho["id"] = str(j)   # j tells the question number

        boolen_list = [True, False]    # tells the is it possible to answer or not
        dictt_metho["is_impossible"] =  boolen_list[1]

        ques = ["What are the methods used?"]   #Question write here
        dictt_metho["question"] = ques[0]

        listttt_metho = answers(inde, abst,metho)
        j = j+1
    elif len(metho) == 0:
        #THis dict for QnA task
        dictt_metho["id"] = str(j)

        boolen_list = [True, False]
        dictt_metho["is_impossible"] =  boolen_list[0]

        ques = ["What are the methods used?"] 
        dictt_metho["question"] = ques[0]

        listttt_metho =  []
        #listss.append(answers(sent, s))
        j = j+1
        
    
    
#     dictt_cat["answers"] = listttt_cat
#     dictt_react["answers"] = listttt_react
    dictt_metho["answers"] = listttt_metho
#     dictt_prod["answers"]  = listttt_prod
    
    lisst= []    #QnA list where question and answer exist
    
#     lisst.append(dictt_cat)
#     lisst.append(dictt_react)
    lisst.append(dictt_metho)
#     lisst.append(dictt_prod)
    
    data1["qas"] = lisst
    
    train.append(data1)

# %%
len(train)
# Out:
# 7852

# %%
# train

# %%
train_ = train[:int(0.80*(len(train)))]                       # 80% train
valid_ = train[int(0.80*(len(train))):int(0.90*(len(train)))] #10% valid 
test_  = train[int(0.90*(len(train))):]                       #10% test

# %%
len(train_), len(test_), len(valid_)
# Out:
# (6281, 786, 785)

# %%
import json
with open("/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/result/methods/data/meth_train.json", 'w') as F:
    # Use the json dumps method to write the list to disk
    F.write(json.dumps(train_))

# %%
import json
with open('/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/result/methods/data/meth_test.json', 'w') as F:
    # Use the json dumps method to write the list to disk
    F.write(json.dumps(test_))

# %%
import json
with open('/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/result/methods/data/meth_valid.json', 'w') as F:
    # Use the json dumps method to write the list to disk
    F.write(json.dumps(valid_))

# %%
import json
with open('/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/result/methods/data/meth_full.json', 'w') as F:
    # Use the json dumps method to write the list to disk
    F.write(json.dumps(train))

# %% [markdown]
# **4. QnA for product**

# %%
def answers(num, total_text, catalystss):
    listss =  []  #Above list for answer  

    for a in range(len(catalystss)):
    #if len(catalystss) != 0:
        dicttt = {} # One anwser list
        dicttt["text"] = catalystss[a]
        values = total_text.split(catalystss[a])
        b = 0
        for c in values[0]:
            b = b + 1
        dicttt["answer_start"] = b

        listss.append(dicttt)
        
    return listss

# %%
indd = []
for i,cata in enumerate(dff['Product']):
    if len(cata) != 0:
        indd.append(i)
        
len(indd)
# Out:
# 12024

# %%
import random

# %%
#ext_ind[3004:3100]+indd

# %%
dff_prod = dff.loc[indd].reset_index(drop = True)

# %%
data = dff_prod

# %%
indeeee = []
for i in range(len(data)):
    if int(data.Date[i][-4:]) == 2017:
        if len(data.Product[i]) != 0:
            indeeee.append(i)
            
len(indeeee)
# Out:
# 791

# %%
data = data.iloc[indeeee].reset_index(drop=True)
len(data)
# Out:
# 791

# %%
y = []
for i in range(len(data)):
    if len(data['Product'][i]) != 0:
        #print(data['catalyst'][i])
        for catt in data['Product'][i]:
            y.append(catt)
print(len(y))            
y_new = []

for nn in y:
    if ('waste' not in nn) and ('poly' not in nn ) and  ('The' not in nn ):
        y_new.append(nn)
len(y_new)
# Out:
# 2468
# 2002

# %%
from wordcloud import WordCloud

# matplotlib library
import matplotlib.pyplot as plt

# Joining all the processed lines together. Whole PDF
long_string = ''.join([str(i) for i in y_new])

# WordCloud object
wordcloud = WordCloud(background_color="white", 
                      max_words=100000, 
                      contour_width=5, 
                      contour_color='steelblue',
                      repeat = False,
                      relative_scaling = 0.5,
                      min_font_size=3,
                      max_font_size = 40)
wordcloud.generate(long_string)

# Visualizing
wordcloud.to_image()

plt.imshow(wordcloud) # image show
plt.axis('off') # to off the axis of x and y
plt.savefig('/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/result/product/product_2017.pdf',dpi=2000,bbox_inches='tight')
plt.show()

# %%
#visualization library
import matplotlib.pyplot as plt
from pylab import *
from matplotlib import rc

#Utilize the wordcloud library
from wordcloud import WordCloud

#Import the warning library
import warnings
warnings.filterwarnings("ignore")

# %%
#define the function for get the name of chemical entities and their frequency
def get_chemical_entry_count(column, size):
    catal = []
    #Remove the all punctution
    catalyst_column= pd.Series(column).str.replace('[^\w\s]','')
    for i in range(size):
        cat_list = catalyst_column[i].split(" ")
        for j in range(len(cat_list)):
            #Appending the catalyst
            catal.append(cat_list[j])
            #frequency of existence
            unique, frequency = np.unique(np.array(catal), return_counts = True)
            #Making data frame of uniqueness and frequency
            df_unique_counts = pd.DataFrame({'section name' : unique, 'frequency' : frequency})
            
    return df_unique_counts

#Call the defined function
df_cat_freq = get_chemical_entry_count(y_new, len(y_new))

# %%
#Sorting the data frame based on frequency available
sort = df_cat_freq.sort_values("frequency", axis = 0, ascending = False).reset_index(drop = True)
#print(Number of unique chemicals)
print('Number of unique chemicals:', sort.shape[0])
#Shows the first 5 rows
sort.head()
# Out:
# Number of unique chemicals: 755
#   section name  frequency
# 0     products        356
# 1   production        293
# 2       energy        276
# 3          oil        228
# 4     concrete        162

# %%
#year 2020
df_list_catalyst = sort

#A zipf line plot is shown
counts = df_list_catalyst.frequency
tokens = df_list_catalyst['section name']

ranks = np.arange(1, len(counts)+1)
indices = argsort(-counts)
frequencies = counts[indices]

# %%
#year 2021
df_list_catalyst1 = sort

# %%
#2022
df_list_catalyst2 = sort

# %%
#2023
df_list_catalyst3 = sort

# %%
df_list_catalyst3 = df_list_catalyst3.drop_duplicates(subset='frequency', keep='first').reset_index(drop = True)

# %%
#A zipf line plot is shown
counts = df_list_catalyst.head(20).frequency
tokens = df_list_catalyst.head(20)['section name']

ranks = np.arange(1, len(counts)+1)
indices = argsort(-counts)
frequencies = counts[indices]


#A zipf line plot is shown
counts1 = df_list_catalyst1.head(20).frequency
tokens1 = df_list_catalyst1.head(20)['section name']

ranks1 = np.arange(1, len(counts1)+1)
indices1 = argsort(-counts1)
frequencies1 = counts1[indices1]

#A zipf line plot is shown
counts2 = df_list_catalyst2.head(20).frequency
tokens2 = df_list_catalyst2.head(20)['section name']

ranks2 = np.arange(1, len(counts2)+1)
indices2 = argsort(-counts2)
frequencies2 = counts2[indices2]

#A zipf line plot is shown
counts3 = df_list_catalyst3.frequency
tokens3 = df_list_catalyst3['section name']

ranks3 = np.arange(1, len(counts3)+1)
indices3 = argsort(-counts3)
frequencies3 = counts3[indices3]

# %%
min(frequencies)
# Out:
# 7

# %%
plt.figure(figsize=(10,8))

plt.ylim(min(frequencies),0.5*10**3)
plt.xlim(1,10**2)

loglog(ranks3, frequencies3, marker=".", label = '2023')
loglog(ranks2, frequencies2, marker=".", label = '2022')
loglog(ranks1, frequencies1, marker=".", label = '2021')
loglog(ranks, frequencies, marker=".", label = '2020')



xlabel("Rank of product entity",fontweight='bold', fontsize=16)
ylabel("Absolute frequency of product entity",fontweight='bold', fontsize=16)

plt.rcParams['axes.linewidth'] = 2
rc('font', weight='bold')

plt.tick_params(axis="x", direction="in",width=2)
plt.tick_params(axis="y", direction="in", width=2)

grid(True)
for n in list(logspace(-0.5, log10(len(counts)-2), 25).astype(int)):
    dummy = text(ranks[n], frequencies[n], " " + tokens[indices[n]], 
                 verticalalignment="bottom",
                 horizontalalignment="left", fontweight='bold',
                 fontsize=12)
    
for n in list(logspace(-0.5, log10(len(counts1)-2), 25).astype(int)):
    dummy1 = text(ranks1[n], frequencies1[n], " " + tokens1[indices1[n]], 
                 verticalalignment="bottom",
                 horizontalalignment="left", fontweight='bold',
                 fontsize=12)
    
for n in list(logspace(-0.5, log10(len(counts2)-2), 25).astype(int)):
    dummy2 = text(ranks2[n], frequencies2[n], " " + tokens2[indices2[n]], 
                 verticalalignment="bottom",
                 horizontalalignment="left", fontweight='bold',
                 fontsize=12)
    
for n in list(logspace(-0.5, log10(len(counts3)-2), 25).astype(int)):
    dummy3 = text(ranks3[n], frequencies3[n], " " + tokens3[indices3[n]], 
                 verticalalignment="bottom",
                 horizontalalignment="left", fontweight='bold',
                 fontsize=12)
#Save the plot
plt.legend()
#plt.savefig(r'/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/result/product/zipf_product_text.pdf', dpi=5000)

plt.show()

# %%
plt.figure(figsize=(10,8))

plt.ylim(1,0.4*10**4)
plt.xlim(0.9,1.20*10**3)

# loglog(ranks3, frequencies3, marker=".", label = '2023')
# loglog(ranks2, frequencies2, marker=".", label = '2022')
# loglog(ranks1, frequencies1, marker=".", label = '2021')
loglog(ranks, frequencies, marker=".", label = '2017')


xlabel("Rank of product entity",fontweight='bold', fontsize=21)
ylabel("Absolute frequency of product entity",fontweight='bold', fontsize=21)

plt.rcParams['axes.linewidth'] = 2
rc('font', weight='bold')

plt.tick_params(axis="x", direction="in",width=2)
plt.tick_params(axis="y", direction="in", width=2)

grid(True)
for n in list(logspace(-0.5, log10(len(counts)-2), 25).astype(int)):
    dummy = text(ranks[n], frequencies[n], " " + tokens[indices[n]], 
                 verticalalignment="bottom",
                 horizontalalignment="left", fontweight='bold',
                 fontsize=18,rotation='vertical')
    

#Save the plot
plt.legend()
plt.savefig(r'/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/result/product/zipf_product_text_2017.pdf', dpi=5000)

plt.show()

# %%
dff_prod.head()
# Out:
#                                  DOI  \
# 0        10.1533/9781845697662.2.102
# 1         10.1016/j.fuel.2021.120505
# 2  10.1016/j.conbuildmat.2022.127949
# 3       10.1016/j.arabjc.2022.104262
# 4  10.1016/j.conbuildmat.2019.117253
#
#                                                Title  \
# 0        5 Pyrolysis for recycling waste composites
# 1  Low-pressure hydrothermal processing of mixed ...
# 2  Cement mortars with ceramic molds shells and p...
# 3  Degradation-fragmentation of marine plastic wa...
# 4  Performance of AC mixtures containing flakes o...
#
#                                             Abstract            process  \
# 0                 Pyrolysis is a suitable process...                 []
# 1  The amount of polyolefin waste, which is 63% o...  [≥23 MPa, ~2 MPa]
# 2  Foundry industry produces millions of tons of ...                 []
# 3  This review critically evaluates the plastic a...                 []
# 4  This paper evaluates the performance of asphal...                 []
#
#   catalyst                                           reactant  \
# 0       []  [polymer composites, frequently thermoplastics...
# 1       []  [polyolefin waste, total plastic waste, 50% po...
# 2       []                                           [wastes]
# 3       []  [plastic accumulation challenges, plastic prod...
# 4       []  [low density polyethylene, plastic film, optim...
#
#                                               Method  \
# 0  [thermal, thermal decomposition products, pyro...
# 1  [Its degradation products, degradation, A new ...
# 2                                                 []
# 3  [degradation, degradation fragmentation phenom...
# 4                                                 []
#
#                                              Product
# 0  [thermal decomposition products, monomers, The...
# 1  [Its degradation products, high capital energy...
# 2  [cement mortars, mortars physical mechanical p...
# 3                           [plastic products, soil]
# 4                                 [asphalt concrete]

# %%
train = []

j =1
for inde,abst in enumerate(dff_prod['Abstract']):
    data1 = {} #This list for a context 
    
    data1["context"] =  abst
    
    dictt_cat =   {}   #Dict for catalyst question
    dictt_react = {} #Dict for reactants question
    dictt_metho=  {} #Dict for method question
    dictt_prod =  {} #Dict for product question
    
    #The data making for the product entries
    prod =  dff_prod['Product'][inde]
    if len(prod) != 0:
        listt = []
        #This dict for QnA task
        dictt_prod["id"] = str(j)   # j tells the question number

        boolen_list = [True, False]    # tells the is it possible to answer or not
        dictt_prod["is_impossible"] =  boolen_list[1]

        ques = ["What are the products formed?"]   #Question write here
        dictt_prod["question"] = ques[0]

        listttt_prod = answers(inde, abst,prod)
        j = j+1
        
    elif len(prod) == 0:
        #THis dict for QnA task
        dictt_prod["id"] = str(j)

        boolen_list = [True, False]
        dictt_prod["is_impossible"] =  boolen_list[0]

        ques = ["What are the products formed?"] 
        dictt_prod["question"] = ques[0]

        listttt_prod =  []
        #listss.append(answers(sent, s))
        j = j+1
        
    
    
#     dictt_cat["answers"] = listttt_cat
#     dictt_react["answers"] = listttt_react
#     dictt_metho["answers"] = listttt_metho
    dictt_prod["answers"]  = listttt_prod
    
    lisst= []    #QnA list where question and answer exist
    
#     lisst.append(dictt_cat)
#     lisst.append(dictt_react)
#     lisst.append(dictt_metho)
    lisst.append(dictt_prod)
    
    data1["qas"] = lisst
    
    train.append(data1)

# %%
len(train)
# Out:
# 15478

# %%
# train

# %%
train_ = train[:int(0.80*(len(train)))]                       # 80% train
valid_ = train[int(0.80*(len(train))):int(0.90*(len(train)))] #10% valid 
test_  = train[int(0.90*(len(train))):]                       #10% test

# %%
len(train_), len(test_), len(valid_)
# Out:
# (12382, 1548, 1548)

# %%
import json
with open('/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/result/product/data/prod_train.json', 'w') as F:
    # Use the json dumps method to write the list to disk
    F.write(json.dumps(train_))

# %%
import json
with open('/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/result/product/data/prod_test.json', 'w') as F:
    # Use the json dumps method to write the list to disk
    F.write(json.dumps(test_))

# %%
import json
with open('/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/result/product/data/prod_valid.json', 'w') as F:
    # Use the json dumps method to write the list to disk
    F.write(json.dumps(valid_))

# %%
import json
with open('/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/result/product/data/prod_full.json', 'w') as F:
    # Use the json dumps method to write the list to disk
    F.write(json.dumps(train))

# %% [markdown]
# **5. Question and answer process**

# %%
# dff=df_net

# %%
def answers(num, total_text, catalystss):
    listss =  []  #Above list for answer  

    for a in range(len(catalystss)):
    #if len(catalystss) != 0:
        dicttt = {} # One anwser list
        dicttt["text"] = catalystss[a]
        values = total_text.split(catalystss[a])
        b = 0
        for c in values[0]:
            b = b + 1
        dicttt["answer_start"] = b

        listss.append(dicttt)
        
    return listss

# %%
indd = []
for i,cata in enumerate(dff["process"]):
    if len(cata) != 0:
        indd.append(i)
        
len(indd)
# Out:
# 611

# %%
inde = []
for ii in range(len(dff)):
    inde.append(ii)

ext_ind = []
for iii in inde:
    if iii not in indd:
        ext_ind.append(iii)
        

len(ext_ind), len(dff)
# Out:
# (20470, 21081)

# %%
import random

# %%
#ext_ind[3004:3100]+indd

# %%
dff_proc = dff.loc[indd].reset_index(drop = True)

# %%
dff_proc.head(10)
# Out:
#                                  DOI  \
# 0         10.1016/j.fuel.2021.120505
# 1      10.1016/j.jhazmat.2022.128971
# 2      10.1016/j.jclepro.2014.07.061
# 3       10.1016/j.envres.2021.112266
# 4     10.1016/j.porgcoat.2022.106742
# 5     10.1016/j.ceramint.2022.08.171
# 6      10.1016/j.polymer.2021.123956
# 7  10.1016/j.compositesa.2020.106096
# 8    10.1016/j.resconrec.2020.105296
# 9      10.1016/j.jclepro.2021.128446
#
#                                                Title  \
# 0  Low-pressure hydrothermal processing of mixed ...
# 1  Immobilization and recycling of contaminated m...
# 2  Use of residual agricultural plastics and cell...
# 3  An eco-friendly wood adhesive based on waterbo...
# 4  Castor-oil-based UV-curable hybrid coatings wi...
# 5  The harnessing of the waste arising from Y-TZP...
# 6  Towards high-performance all-polyethylene mate...
# 7  The novel application of nonmetals from waste ...
# 8  Enhanced extraction of copper from electronic ...
# 9  Twisting in improving processing of waste-deri...
#
#                                             Abstract  \
# 0  The amount of polyolefin waste, which is 63% o...
# 1  Sustainable stabilization/solidification (S/S)...
# 2  Crop protection residual plastic films are a g...
# 3  An environmentally friendly wood adhesive deve...
# 4  Restrained by the irreversibility of the perma...
# 5  A large amount of yttria-stabilized zirconia (...
# 6  In this study, we proposed a unique continuous...
# 7  Nonmetals from the waste printed circuit board...
# 8  Electronic waste (e-waste) is one of the faste...
# 9  Waste cotton fibers was spun into yarns for po...
#
#                            process catalyst  \
# 0                [≥23 MPa, ~2 MPa]       []
# 1               [5.0 MPa, 4.5 MPa]       []
# 2  [180 MPa, 20.26 MPa, 23.96 MPa]       []
# 3            [32.91 MPa, 4.21 MPa]       []
# 4                       [16.6 MPa]       []
# 5    [66.7 MPa, 96.0 MPa, 200 MPa]       []
# 6                       [98.2 MPa]       []
# 7   [24.9 MPa, 36.2 MPa, 1403 MPa]       []
# 8                        [148 atm]       []
# 9                        [286 MPa]       []
#
#                                             reactant  \
# 0  [polyolefin waste, total plastic waste, 50% po...
# 1                                 [hazardous wastes]
# 2  [Crop protection residual plastic films, waste...
# 3  [waterborne polyurethane, chromium shavings wa...
# 4  [repairable, recyclable, removable, hydrophobi...
# 5  [yttria-stabilized zirconia (Y-TZP) waste, zir...
# 6  [high-performance self-reinforced polyethylene...
# 7  [waste printed circuit board, waste printed ci...
# 8  [Electronic waste, waste, fastest growing wast...
# 9  [ever-increasing waste textiles generation, wa...
#
#                                               Method  \
# 0  [Its degradation products, degradation, A new ...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4       [thermal, good thermal, mechanical, coating]
# 5                                                 []
# 6                                                 []
# 7  [thermal, fabrication value-added thermal mana...
# 8                                                 []
# 9                                       [conversion]
#
#                                              Product
# 0  [Its degradation products, high capital energy...
# 1                                     [S/S products]
# 2  [industrially-sourced residual natural fibers,...
# 3                                                 []
# 4                             [renewable castor oil]
# 5                                                 []
# 6  [high-performance self-reinforced polyethylene...
# 7  [byproduct, value-added product, fabrication v...
# 8                     [melt-pressed Cu foil, energy]
# 9  [Waste cotton fibers, waste cotton fibers, hig...

# %%
train = []

j =1
for inde,abst in enumerate(dff_proc['Abstract']):
    data1 = {} #This list for a context 
    
    data1["context"] =  abst
    
    dictt_cat = {}   #Dict for catalyst question
    dictt_react = {} #Dict for reactants question
    dictt_metho= {} #Dict for method question
    dictt_prod = {} #Dict for product question
    dictt_proc = {} #Dict for process question
    
    #The data making for the catalyst entries
    comp =  dff_proc['process'][inde]
    if len(comp) != 0:
        listt = []
        #This dict for QnA task
        dictt_proc["id"] = str(j)   # j tells the question number

        boolen_list = [True, False]    # tells the is it possible to answer or not
        dictt_proc["is_impossible"] =  boolen_list[1]

        ques = ["What are the process parameters values?"]   #Question write here
        dictt_proc["question"] = ques[0]

        listttt_proc = answers(inde, abst,comp)
        j = j+1
    elif len(comp) == 0:
        #THis dict for QnA task
        dictt_proc["id"] = str(j)

        boolen_list = [True, False]
        dictt_proc["is_impossible"] =  boolen_list[0]

        ques = ["What are the process parameters values?"]
        dictt_proc["question"] = ques[0]

        listttt_proc =  []
        #listss.append(answers(sent, s))
        j = j+1
    
    
#     dictt_cat["answers"] = listttt_cat
#     dictt_react["answers"] = listttt_react
#     dictt_metho["answers"] = listttt_metho
#     dictt_prod["answers"]  = listttt_prod
    dictt_proc['answers'] = listttt_proc
    
    lisst= []    #QnA list where question and answer exist
    
#     lisst.append(dictt_cat)
#     lisst.append(dictt_react)
#     lisst.append(dictt_metho)
#     lisst.append(dictt_prod)
    lisst.append(dictt_proc)
    
    data1["qas"] = lisst
    
    train.append(data1)

# %%
len(train)
# Out:
# 611

# %%
# train

# %%
train_ = train[:int(0.80*(len(train)))]                       # 80% train
valid_ = train[int(0.80*(len(train))):int(0.90*(len(train)))] #10% valid 
test_  = train[int(0.90*(len(train))):]                       #10% test

# %%
len(train_), len(test_), len(valid_)
# Out:
# (488, 62, 61)

# %%
import json
with open('/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/result/process/data/pro_train.json', 'w') as F:
    # Use the json dumps method to write the list to disk
    F.write(json.dumps(train_))

# %%
import json
with open('/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/result/process/data/pro_test.json', 'w') as F:
    # Use the json dumps method to write the list to disk
    F.write(json.dumps(test_))

# %%
import json
with open('/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/result/process/data/pro_valid.json', 'w') as F:
    # Use the json dumps method to write the list to disk
    F.write(json.dumps(valid_))

# %%
import json
with open('/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/result/process/data/pro_full.json', 'w') as F:
    # Use the json dumps method to write the list to disk
    F.write(json.dumps(train))

# %%
dff.to_parquet("/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/result/data_full.gzip" ,compression='gzip')
# df.to_parquet(FILE_PATH + '{}.gzip'.format(csv_file),compression='gzip')

# %%
len_answer_cat = []
for a in dff_cat.index:
    len_answer_cat.append(len(dff_cat["catalyst"][a]))

# %%
len_answer_meth = []
for a in dff_meth.index:
    len_answer_meth.append(len(dff_meth["Method"][a]))

# %%
len_answer_react = []
for a in dff_react.index:
    len_answer_react.append(len(dff_react["reactant"][a]))

# %%
len_answer_prod = []
for a in dff_prod.index:
    len_answer_prod.append(len(dff_prod["Product"][a]))

# %%
len_answer_pro = []
for a in dff_proc.index:
    len_answer_pro.append(len(dff_proc["process"][a]))

# %%
print("mean and std of lists:", np.mean(len_answer_cat), np.std(len_answer_cat))
# Out:
# mean and std of lists: 2.657293497363796 2.058960541059826

# %%
print("mean and std of lists:", np.mean(len_answer_meth), np.std(len_answer_meth))
# Out:
# mean and std of lists: 3.5149006622516556 2.1887865657661596

# %%
print("mean and std of lists:", np.mean(len_answer_pro), np.std(len_answer_pro))
# Out:
# mean and std of lists: 1.5057283142389526 0.8376668076793218

# %%
print("mean and std of lists:", np.mean(len_answer_prod), np.std(len_answer_prod))
# Out:
# mean and std of lists: 3.2252875048455873 2.4172494440375396

# %%
print("mean and std of lists:", np.mean(len_answer_react), np.std(len_answer_react))
# Out:
# mean and std of lists: 4.368102716468591 3.0991169479420235

# %% [markdown]
# **QnA data making**

# %%
def answers(num, total_text, catalystss):
    listss =  []  #Above list for answer  

    for a in range(len(catalystss)):
    #if len(catalystss) != 0:
        dicttt = {} # One anwser list
        dicttt["text"] = catalystss[a]
        values = total_text.split(catalystss[a])
        b = 0
        for c in values[0]:
            b = b + 1
        dicttt["answer_start"] = b

        listss.append(dicttt)
        
    return listss

# %%
df
# Out:
#                                       DOI  \
# 0             10.1533/9781845697662.2.102
# 1              10.1016/j.fuel.2021.120505
# 2       10.1016/j.conbuildmat.2022.127949
# 3            10.1016/j.arabjc.2022.104262
# 4       10.1016/j.conbuildmat.2019.117253
# ...                                   ...
# 21076       10.1016/j.jclepro.2016.08.032
# 21077  10.1016/B978-0-12-819726-4.00008-9
# 21078           10.1016/j.cep.2017.11.017
# 21079     10.1016/j.scitotenv.2022.159256
# 21080       10.1016/j.jclepro.2017.03.007
#
#                                                    Title  \
# 0            5 Pyrolysis for recycling waste composites
# 1      Low-pressure hydrothermal processing of mixed ...
# 2      Cement mortars with ceramic molds shells and p...
# 3      Degradation-fragmentation of marine plastic wa...
# 4      Performance of AC mixtures containing flakes o...
# ...                                                  ...
# 21076  Water and carbon footprint of selected dairy p...
# 21077  Lost Foam Casting of Metallic Parts and Struct...
# 21078  Membrane crystallization via membrane distilla...
# 21079  Vertical distribution, accumulation, and chara...
# 21080  An attributional Life Cycle Assessment applica...
#
#                                                 Abstract            process  \
# 0                     Pyrolysis is a suitable process...                 []
# 1      The amount of polyolefin waste, which is 63% o...  [≥23 MPa, ~2 MPa]
# 2      Foundry industry produces millions of tons of ...                 []
# 3      This review critically evaluates the plastic a...                 []
# 4      This paper evaluates the performance of asphal...                 []
# ...                                                  ...                ...
# 21076  This study assesses the LCA-based Water Footpr...                 []
# 21077                 The lost foam casting is a uniq...                 []
# 21078  Crystallization is a solid-liquid separation t...                 []
# 21079  Mangroves in tropical and subtropical regions ...                 []
# 21080  Food packaging systems mainly serve to contain...                 []
#
#       catalyst                                           reactant  \
# 0           []  [recycling polymer composites, polymer matrix,...
# 1           []  [polyolefin waste, total plastic waste, 50% po...
# 2           []                                   [wastes, wastes]
# 3           []  [plastic accumulation challenges, plastic prod...
# 4           []  [low density polyethylene, plastic film, optim...
# ...        ...                                                ...
# 21076       []                                                 []
# 21077       []                   [ceramic coated polymeric foams]
# 21078       []                                                 []
# 21079       []  [microplastics, polypropylene/polyethylene pol...
# 21080       []     [alternative biopolymers, wastes, wastewaters]
#
#                                                   Method  \
# 0      [thermal, thermal decomposition products, pyro...
# 1       [Its degradation products, degradation, thermal]
# 2                                                     []
# 3      [degradation, degradation, fragmentation degra...
# 4                                                     []
# ...                                                  ...
# 21076                                                 []
# 21077                                                 []
# 21078                                                 []
# 21079                                                 []
# 21080                                                 []
#
#                                                  Product
# 0      [thermal decomposition products, monomers, The...
# 1      [Its degradation products, high capital energy...
# 2      [cement mortars, mortars physical mechanical p...
# 3                               [plastic products, soil]
# 4                                     [asphalt concrete]
# ...                                                  ...
# 21076  [production, energy consumption, production pr...
# 21077                                 [gaseous products]
# 21078                           [low energy consumption]
# 21079                                                 []
# 21080                [eco-friendly products, production]
#
# [21081 rows x 8 columns]

# %%
indee = []
for d in df.index:
    if (len(df['process'][d]) != 0) and (len(df['catalyst'][d]) != 0) and (len(df['reactant'][d]) != 0) and (len(df['Method'][d]) != 0) and (len(dff['Product'][d]) != 0):
        indee.append(d)
        
len(indee)
# Out:
# 0

# %%
dff = df_cat

# %%
indd = []
for i,cata in enumerate(dff['catalyst']):
    if len(cata) != 0:
        indd.append(i)
        
len(indd)
# Out:
# 1136

# %%
inde = []
for ii in range(len(dff)):
    inde.append(ii)

ext_ind = []
for iii in inde:
    if iii not in indd:
        ext_ind.append(iii)
        

len(ext_ind), len(dff)
# Out:
# (20195, 20363)

# %%
dff = dff.loc[indd].reset_index(drop = True)
len(dff)
# Out:
# 168

# %%
dff["process"]
# Out:
# 0      []
# 1      []
# 2      []
# 3      []
# 4      []
#        ..
# 163    []
# 164    []
# 165    []
# 166    []
# 167    []
# Name: process, Length: 168, dtype: object

# %%
dff['process'] = dff['process'].apply(deleteduplicate)
dff['Product'] = dff['Product'].apply(deleteduplicate)
dff['reactant'] = dff['reactant'].apply(deleteduplicate)
dff["Method"] = dff['Method'].apply(deleteduplicate)
dff['catalyst'] = dff['catalyst'].apply(deleteduplicate)

# %%
train = []

j =1
for inde,abst in enumerate(dff['Abstract']):
    data1 = {} #This list for a context 
    
    data1["context"] =  abst
    
    dictt_cat   = {} #Dict for catalyst question
    dictt_react = {} #Dict for reactants question
    dictt_metho = {} #Dict for method question
    dictt_prod  = {} #Dict for product question
    dictt_proc  = {} #Dict for process question
    
    #The data making for the catalyst entries
    comp =  dff['catalyst'][inde]
    if len(comp) != 0:
        listt = []
        #This dict for QnA task
        dictt_cat["id"] = str(j)   # j tells the question number

        boolen_list = [True, False]    # tells the is it possible to answer or not
        dictt_cat["is_impossible"] =  boolen_list[1]

        ques = ["What are the materials used as catalyst?"]   #Question write here
        dictt_cat["question"] = ques[0]

        listttt_cat = answers(inde, abst,comp)
        j = j+1
    elif len(comp) == 0:
        #THis dict for QnA task
        dictt_cat["id"] = str(j)

        boolen_list = [True, False]
        dictt_cat["is_impossible"] =  boolen_list[0]

        ques = ["What are the materials used as catalyst?"] 
        dictt_cat["question"] = ques[0]

        listttt_cat =  []
        #listss.append(answers(sent, s))
        j = j+1
    
    #Data making for reactant(polymers) 
    react = dff['reactant'][inde] 
    if len(react) != 0:
        listt = []
        #This dict for QnA task
        dictt_react["id"] = str(j)   # j tells the question number

        boolen_list = [True, False]    # tells the is it possible to answer or not
        dictt_react["is_impossible"] =  boolen_list[1]

        ques = ["What are the reactants used?"]   #Question write here
        dictt_react["question"] = ques[0]

        listttt_react = answers(inde, abst,react)
        j = j+1
    elif len(react) == 0:
        #THis dict for QnA task
        dictt_react["id"] = str(j)

        boolen_list = [True, False]
        dictt_react["is_impossible"] =  boolen_list[0]

        ques = ["What are the reactants used?"] 
        dictt_react["question"] = ques[0]

        listttt_react =  []
        #listss.append(answers(sent, s))
        j = j+1

    #Data making for methods 
    metho = dff['Method'][inde] 
    if len(metho) != 0:
        listt = []
        #This dict for QnA task
        dictt_metho["id"] = str(j)   # j tells the question number

        boolen_list = [True, False]    # tells the is it possible to answer or not
        dictt_metho["is_impossible"] =  boolen_list[1]

        ques = ["What are the methods used?"]   #Question write here
        dictt_metho["question"] = ques[0]

        listttt_metho = answers(inde, abst,metho)
        j = j+1
    elif len(metho) == 0:
        #THis dict for QnA task
        dictt_metho["id"] = str(j)

        boolen_list = [True, False]
        dictt_metho["is_impossible"] =  boolen_list[0]

        ques = ["What are the methods used?"] 
        dictt_metho["question"] = ques[0]

        listttt_metho =  []
        #listss.append(answers(sent, s))
        j = j+1
        
    #The data making for the product entries
    prod =  dff['Product'][inde]
    if len(prod) != 0:
        listt = []
        #This dict for QnA task
        dictt_prod["id"] = str(j)   # j tells the question number

        boolen_list = [True, False]    # tells the is it possible to answer or not
        dictt_prod["is_impossible"] =  boolen_list[1]

        ques = ["What are the products formed?"]   #Question write here
        dictt_prod["question"] = ques[0]

        listttt_prod = answers(inde, abst,prod)
        j = j+1
        
    elif len(prod) == 0:
        #THis dict for QnA task
        dictt_prod["id"] = str(j)

        boolen_list = [True, False]
        dictt_prod["is_impossible"] =  boolen_list[0]

        ques = ["What are the products formed?"] 
        dictt_prod["question"] = ques[0]

        listttt_prod =  []
        #listss.append(answers(sent, s))
        j = j+1
        
        
    #The data making for the process entries
    proc =  dff['process'][inde]
    if len(proc) != 0:
        listt = []
        #This dict for QnA task
        dictt_proc["id"] = str(j)   # j tells the question number

        boolen_list = [True, False]    # tells the is it possible to answer or not
        dictt_proc["is_impossible"] =  boolen_list[1]

        ques = ["What are the process parameters values?"]   #Question write here
        dictt_proc["question"] = ques[0]

        listttt_proc = answers(inde, abst,proc)
        j = j+1
        
    elif len(proc) == 0:
        #THis dict for QnA task
        dictt_proc["id"] = str(j)

        boolen_list = [True, False]
        dictt_proc["is_impossible"] =  boolen_list[0]

        ques = ["What are the process parameters values?"] 
        dictt_proc["question"] = ques[0]

        listttt_proc =  []
        #listss.append(answers(sent, s))
        j = j+1
    

    dictt_cat["answers"] = listttt_cat
    dictt_react["answers"] = listttt_react
    dictt_metho["answers"] = listttt_metho
    dictt_prod["answers"]  = listttt_prod
    dictt_proc["answers"]  = listttt_proc
    
    lisst= []    #QnA list where question and answer exist
    
    lisst.append(dictt_cat)
    lisst.append(dictt_react)
    lisst.append(dictt_metho)
    lisst.append(dictt_prod)
    lisst.append(dictt_proc)
    
    data1["qas"] = lisst
    
    train.append(data1)

# %%
len(train)
# Out:
# 168

# %%
train
# Out:
# [{'context': 'A new reactor system was developed for recovery fuels from the waste plastic mixture in steam atmosphere. Firstly, the degradation mechanisms of eight kinds of plastics, two polyolefins (polyethylene and polypropylene), two polyamide resins (nylon-6 and nylon-6,6), polystyrene and three polyesters (polycarbonate, poly(butylene terephthalate) and poly(ethylene terephthalate), were investigated both in nitrogen and steam as the carrier gas. Plastics except for polyesters were degraded without any influences of the kinds of the carrier gas, leaving negligibly small amount of carbonaceous residue. Polyesters, which were degraded with producing large amount of the residue in nitrogen, were succeeded to be hydrolyzed at high reaction rates in steam with producing hardly the carbonaceous residue. Secondly, a mixture of the waste plastics was continuously degraded to produce heavy oil in steam atmosphere by using a new reactor system. This system was composed of three kinds of reactors connected in series. One was a reactor filled with stirred heat medium particles, which enabled the high heat transfer rate, the high holdup and the good contact of the melted plastics with steam. The second was a tank reactor. The last one was a fixed bed reactor with FeOOH catalyst particles, which showed the catalysis in steam for the decomposition both of a wax and sublimate materials generated by the degradation of plastics. Furthermore, the oil produced from the proposed reactor system was continuously upgraded to produce gasoline and kerosene over Ni-REY catalyst in steam atmosphere.',
#   'qas': [{'id': '1',
#     'is_impossible': False,
#     'question': 'What are the materials used as catalyst?',
#     'answers': [{'text': 'Ni-REY', 'answer_start': 1554}]},
#    {'id': '2',
#     'is_impossible': False,
#     'question': 'What are the reactants used?',
#     'answers': [{'text': 'waste plastic mixture', 'answer_start': 63},
#      {'text': 'plastics', 'answer_start': 160},
#      {'text': 'polyolefins', 'answer_start': 174},
#      {'text': 'polyethylene', 'answer_start': 187},
#      {'text': 'polypropylene', 'answer_start': 204},
#      {'text': 'polyamide resins', 'answer_start': 224},
#      {'text': 'polyesters', 'answer_start': 288},
#      {'text': 'polycarbonate, poly(butylene terephthalate',
#       'answer_start': 300},
#      {'text': 'poly(ethylene terephthalate', 'answer_start': 348},
#      {'text': 'waste plastics', 'answer_start': 828},
#      {'text': 'melted plastics', 'answer_start': 1162}]},
#    {'id': '3',
#     'is_impossible': False,
#     'question': 'What are the methods used?',
#     'answers': [{'text': 'degradation mechanisms', 'answer_start': 119},
#      {'text': 'degradation', 'answer_start': 119}]},
#    {'id': '4',
#     'is_impossible': False,
#     'question': 'What are the products formed?',
#     'answers': [{'text': 'heavy oil', 'answer_start': 880},
#      {'text': 'oil', 'answer_start': 886}]},
#    {'id': '5',
#     'is_impossible': True,
#     'question': 'What are the process parameters values?',
#     'answers': []}]},
#  {'context': 'In this study, municipal polymer wastes that were no longer recyclable and were previously buried underground according to the usual municipal waste management program were converted to liquid fuel by catalytic pyrolysis technique. In the first step, zeolite Y catalyst was used to improve the quality of liquid fuel. In the second step, MIL-53 (Cu) was incorporated onto zeolite and pyrolyzed in nitrogen in the atmosphere. The analysis shows that clusters of carbon nanopores with a copper core, and its oxides were deposited on the zeolite. For both types of catalysts, the crystallization time of zeolite was investigated, and it was found that this leads to the synthesis of samples with different percentages of crystallinity. For each test, the liquid fuel produced was divided into four cuts: gasoline, jet fuel, diesel, and wax. The test results in a fixed bed reactor for every twelve samples of catalyst and their effect on the efficiency of different sections of liquid fuel show a significant improvement in the desired product. The properties and morphology of the catalysts were investigated. It was found that at 400 °C and a crystallization time of 18 h for support with 76.62% crystallinity, gasoline production efficiency will be 37.00%. At 500 °C and low crystallinity, the tendency of reaction to produce jet fuel with a maximum efficiency of 48.64%. Furthermore, the physical properties of each cut of liquid fuel and their comparison with the reported values indicating the appropriate qualities of the produced fuel were evaluated. In the optimal state, the octane number of the produced gasoline is 93.5 and its pour point is 41 °C. Also, a jet fuel with an octane number of 43.2 and a flashpoint of 69 °C has been obtained. In the case of diesel, the octane number and its viscosity have reached 46 and 2.407 cp, respectively. Examining the results obtained from GC MS, it was found that the zeolite catalyst modified by Diels Alder mechanism and branching will improve the quality of liquid fuel and on the other hand, will cause the cracking of the wax compounds and reduce their percentage in product analysis.',
#   'qas': [{'id': '6',
#     'is_impossible': False,
#     'question': 'What are the materials used as catalyst?',
#     'answers': [{'text': 'zeolite', 'answer_start': 251}]},
#    {'id': '7',
#     'is_impossible': False,
#     'question': 'What are the reactants used?',
#     'answers': [{'text': 'usual municipal waste management program',
#       'answer_start': 127}]},
#    {'id': '8',
#     'is_impossible': False,
#     'question': 'What are the methods used?',
#     'answers': [{'text': 'pyrolysis', 'answer_start': 211},
#      {'text': 'catalytic pyrolysis technique', 'answer_start': 201}]},
#    {'id': '9',
#     'is_impossible': False,
#     'question': 'What are the products formed?',
#     'answers': [{'text': 'desired product', 'answer_start': 1025},
#      {'text': 'gasoline production efficiency', 'answer_start': 1210},
#      {'text': 'product analysis', 'answer_start': 2122}]},
#    {'id': '10',
#     'is_impossible': True,
#     'question': 'What are the process parameters values?',
#     'answers': []}]},
#  {'context': 'In this study, the effects of CO2 thermochemical agent and a metal oxide catalyst (Co3O4) on thermochemical banner waste conversion were explored. The results revealed that compared to the non-catalytic conversion of banner waste under N2 environment, the conversion under CO2 yielded more non-condensable gases owing to an enhanced thermal cracking of volatiles. In addition, the CO and CH4 yields at >700 °C in CO2 increased considerably owing to the reverse water–gas shift reaction and CO2 methanation. The CO2 agent reduced the yields of condensables (e.g., benzoic acids, phthalic acids, esters, biphenyls, fluorenes) and decomposition residue (e.g., char and wax), which could be attributed to the enhancement of the thermal cracking of volatiles evolved during the banner waste conversion by CO2 and the C–H and O–H bonds present in the feedstock. In addition, the Co3O4 catalyst promoted the decarboxylation reaction under N2 environment, whereas it promoted the methanation and reverse water–gas shift reaction under CO2. This indicates that compared to the non-catalytic CO2-assisted banner waste conversion, the use of CO2 for the conversion of banner waste in the presence of Co3O4 significantly increased the yields of CH4 and CO. Furthermore, Co3O4 promoted the thermal cracking of polyester bond, thus decreasing the yields of long-chain chemical compounds. In addition, the simultaneous use of Co3O4 catalyst and CO2 agent minimized the formation of char and wax. For all cases (N2 versus CO2, non-catalytic versus catalytic), an increase in temperature enhanced the total permanent gas yield and decreased the yields of condensables, char, and wax. The findings of this study revealed the importance of the synergistic use of Co3O4 catalyst and CO2 agent for the plastic waste upcycling, such as banner waste.',
#   'qas': [{'id': '11',
#     'is_impossible': False,
#     'question': 'What are the materials used as catalyst?',
#     'answers': [{'text': 'Co3O4', 'answer_start': 83}]},
#    {'id': '12',
#     'is_impossible': False,
#     'question': 'What are the reactants used?',
#     'answers': [{'text': 'thermochemical banner waste conversion',
#       'answer_start': 93},
#      {'text': 'banner waste', 'answer_start': 108},
#      {'text': 'banner waste conversion', 'answer_start': 108},
#      {'text': 'non-catalytic CO2-assisted banner waste conversion',
#       'answer_start': 1068},
#      {'text': 'polyester bond', 'answer_start': 1297},
#      {'text': 'plastic waste upcycling', 'answer_start': 1781}]},
#    {'id': '13',
#     'is_impossible': False,
#     'question': 'What are the methods used?',
#     'answers': [{'text': 'conversion', 'answer_start': 121},
#      {'text': 'thermochemical banner waste conversion', 'answer_start': 93},
#      {'text': 'non-catalytic conversion', 'answer_start': 189},
#      {'text': 'thermal', 'answer_start': 333},
#      {'text': 'enhanced thermal cracking', 'answer_start': 324},
#      {'text': 'banner waste conversion', 'answer_start': 108},
#      {'text': 'thermal cracking', 'answer_start': 333},
#      {'text': 'non-catalytic CO2-assisted banner waste conversion',
#       'answer_start': 1068}]},
#    {'id': '14',
#     'is_impossible': True,
#     'question': 'What are the products formed?',
#     'answers': []},
#    {'id': '15',
#     'is_impossible': True,
#     'question': 'What are the process parameters values?',
#     'answers': []}]},
#  {'context': 'The recycling of waste lubricant oil from automobile industry was found to be best alternative to incineration. Silica (SiO2), alumina (Al2O3), silica–alumina (SiO2–Al2O3) supported iron oxide (10wt% Fe) catalysts were prepared by wet impregnation method and used for the desulphurisation of waste lubricant oil into fuel oil. The extent of sulphur removal increases in the sequence of Fe/SiO2–Al2O3<Fe/Al2O3<Fe/SiO2 and this might be due to the presence of smaller crystalline size (7.4 nm) of Fe2O3 in Fe/SiO2 catalyst. X-ray diffraction results suggest the presence of iron sulphide in the used catalyst. Gas chromatography with thermal conductivity detector analysis confirms the presence of H2S in gaseous products. In addition, Fe/SiO2 catalyst facilitated the formation of lower hydrocarbons by cracking higher hydrocarbons (≈C40) present in waste lubricant oil.',
#   'qas': [{'id': '16',
#     'is_impossible': False,
#     'question': 'What are the materials used as catalyst?',
#     'answers': [{'text': 'Fe/SiO2', 'answer_start': 386}]},
#    {'id': '17',
#     'is_impossible': False,
#     'question': 'What are the reactants used?',
#     'answers': [{'text': 'waste lubricant oil', 'answer_start': 17}]},
#    {'id': '18',
#     'is_impossible': False,
#     'question': 'What are the methods used?',
#     'answers': [{'text': 'thermal', 'answer_start': 632},
#      {'text': 'thermal conductivity detector analysis', 'answer_start': 632}]},
#    {'id': '19',
#     'is_impossible': False,
#     'question': 'What are the products formed?',
#     'answers': [{'text': 'waste lubricant oil', 'answer_start': 17},
#      {'text': 'fuel oil', 'answer_start': 317},
#      {'text': 'gaseous products', 'answer_start': 703}]},
#    {'id': '20',
#     'is_impossible': True,
#     'question': 'What are the process parameters values?',
#     'answers': []}]},
#  {'context': 'A solvolysis process to depolymerize the resin fraction of carbon fibre reinforced plastic waste to recover carbon fibre, followed by hydrothermal gasification of the liquid residual product to produce fuel gas was investigated using batch reactors. The depolymerisation reactions were carried out in ethylene glycol and ethylene glycol/water mixtures at near-critical conditions of the two solvents. With ethylene glycol alone the highest resin removal of 92.1% was achieved at 400°C. The addition of water to ethylene glycol led to higher resin removals compared to ethylene glycol alone. With an ethylene glycol/water ratio of 5, at 400°C, resin removal was 97.6%, whereas it was 95.2% when this ratio was 3, at the same temperature. The mechanical properties of the recovered carbon fibre were tested and showed minimal difference in strength compared to the virgin carbon fibre. The product liquid, containing organic resin degradation products was then subjected to catalytic supercritical water gasification at 500°C and 24MPa in the presence of NaOH and Ru/Al2O3 as catalysts, respectively. Up to 60mol.% of H2 gas was produced with NaOH as catalyst, and 53.7mol.% CH4 gas was produced in the presence of Ru/Al2O3.',
#   'qas': [{'id': '21',
#     'is_impossible': False,
#     'question': 'What are the materials used as catalyst?',
#     'answers': [{'text': 'Ru/Al2O3', 'answer_start': 1062}]},
#    {'id': '22',
#     'is_impossible': False,
#     'question': 'What are the reactants used?',
#     'answers': [{'text': 'carbon fibre reinforced plastic waste',
#       'answer_start': 59},
#      {'text': 'The depolymerisation reactions', 'answer_start': 250}]},
#    {'id': '23',
#     'is_impossible': False,
#     'question': 'What are the methods used?',
#     'answers': [{'text': 'thermal', 'answer_start': 139},
#      {'text': 'hydrothermal gasification', 'answer_start': 134},
#      {'text': 'degradation', 'answer_start': 929},
#      {'text': 'organic resin degradation products', 'answer_start': 915}]},
#    {'id': '24',
#     'is_impossible': False,
#     'question': 'What are the products formed?',
#     'answers': [{'text': 'liquid residual product', 'answer_start': 167},
#      {'text': 'carbon fibre reinforced plastic waste', 'answer_start': 59},
#      {'text': 'carbon fibre', 'answer_start': 59},
#      {'text': 'ethylene glycol', 'answer_start': 301},
#      {'text': 'ethylene glycol/water mixtures', 'answer_start': 321},
#      {'text': 'ethylene glycol/water ratio', 'answer_start': 599},
#      {'text': 'recovered carbon fibre', 'answer_start': 770},
#      {'text': 'virgin carbon fibre', 'answer_start': 863},
#      {'text': 'The product liquid', 'answer_start': 884},
#      {'text': 'organic resin degradation products', 'answer_start': 915}]},
#    {'id': '25',
#     'is_impossible': True,
#     'question': 'What are the process parameters values?',
#     'answers': []}]},
#  {'context': 'In fuel production from waste plastics, highly flammable hydrocarbon oils and by-product gasses are produced. These products are not suitable for developing countries, because high-precision plants and experienced operators are required for safe operation. Production of heavy oil rather than light oil is one solution to this problem. In the present study, catalytic pyrolysis of packing sheets commonly used in Vietnam was carried out in a batch reactor in order to produce heavier oil. The liquid product components were quantified by flame ionization detector-gas chromatography. Six kinds of catalysts were used for catalytic pyrolysis, including commercial SiO2-Al2O3, Pd on alumina, Cu, Ni, Fe2O3 and Fe3O4. Pd on alumina, Cu, Ni and Fe3O4 had no catalytic activity. The product components were almost the same as those produced by thermal pyrolysis with no catalyst. Al2O3-SiO2 products had a large amount of low-carbon-number components. Fe2O3 produced a small amount of light components and a large amount of heavy components. Fe2O3 produced heavier oil than the other catalysts.',
#   'qas': [{'id': '26',
#     'is_impossible': False,
#     'question': 'What are the materials used as catalyst?',
#     'answers': [{'text': 'Fe2O3', 'answer_start': 698}]},
#    {'id': '27',
#     'is_impossible': False,
#     'question': 'What are the reactants used?',
#     'answers': [{'text': 'waste plastics', 'answer_start': 24}]},
#    {'id': '28',
#     'is_impossible': False,
#     'question': 'What are the methods used?',
#     'answers': [{'text': 'pyrolysis', 'answer_start': 368},
#      {'text': 'catalytic pyrolysis', 'answer_start': 358},
#      {'text': 'thermal pyrolysis', 'answer_start': 839},
#      {'text': 'thermal', 'answer_start': 839}]},
#    {'id': '29',
#     'is_impossible': False,
#     'question': 'What are the products formed?',
#     'answers': [{'text': 'fuel production', 'answer_start': 3},
#      {'text': 'product', 'answer_start': 8},
#      {'text': 'highly flammable hydrocarbon oils', 'answer_start': 40},
#      {'text': 'These products', 'answer_start': 110},
#      {'text': 'heavy oil', 'answer_start': 271},
#      {'text': 'light oil', 'answer_start': 293},
#      {'text': 'heavier oil', 'answer_start': 476},
#      {'text': 'The liquid product components', 'answer_start': 489},
#      {'text': 'The product components', 'answer_start': 774},
#      {'text': 'Al2O3-SiO2 products', 'answer_start': 875}]},
#    {'id': '30',
#     'is_impossible': True,
#     'question': 'What are the process parameters values?',
#     'answers': []}]},
#  {'context': 'Efficient catalysis that simultaneously cleaves thermodynamically inert C–C bonds and generates functional moieties to stimulate chemical recycling of polyolefins is lacking. In this issue of Chem, Kanbur et al. design an organozirconium catalyst combined with aluminum reagents to enable a clever tandem C–C cleavage and carboalumination process that yields value-added alkylaluminum products.',
#   'qas': [{'id': '31',
#     'is_impossible': False,
#     'question': 'What are the materials used as catalyst?',
#     'answers': [{'text': 'aluminum', 'answer_start': 261},
#      {'text': 'alkylaluminum', 'answer_start': 371}]},
#    {'id': '32',
#     'is_impossible': False,
#     'question': 'What are the reactants used?',
#     'answers': [{'text': 'polyolefins', 'answer_start': 151}]},
#    {'id': '33',
#     'is_impossible': True,
#     'question': 'What are the methods used?',
#     'answers': []},
#    {'id': '34',
#     'is_impossible': False,
#     'question': 'What are the products formed?',
#     'answers': [{'text': 'value-added alkylaluminum products',
#       'answer_start': 359}]},
#    {'id': '35',
#     'is_impossible': True,
#     'question': 'What are the process parameters values?',
#     'answers': []}]},
#  {'context': 'Urgent need for waste disposal and renewable energy have opened up promising pathways for renewable and sustainable fuel production to substitute traditional fossil fuels. In this study, catalytic co-pyrolysis of waste paper (WP) and polyvinyl chloride (PVC) as typical municipal solid wastes was experimentally investigated towards hydrogen-rich syngas production. Results indicated the maximum H2 yield (429 μmol·gcat −1·min−1) was obtained with 60% PVC weight ratio under 900 °C which was higher than single component pyrolysis. Higher hydrogen yield (681.76 μmol·gcat −1·min−1) appeared over Fe/CeO2–CaO under the optimal conditions compared to that of Ru/ZSM-5-CaO (445.54 μmol·gcat −1·min−1). From the calculated non-isothermal kinetic parameters, both catalysts could reduce activation energies. Proper porous structure and CaO content in the catalyst could enhance hydrogen production via carbon species fixation.',
#   'qas': [{'id': '36',
#     'is_impossible': False,
#     'question': 'What are the materials used as catalyst?',
#     'answers': [{'text': 'CaO', 'answer_start': 604}]},
#    {'id': '37',
#     'is_impossible': False,
#     'question': 'What are the reactants used?',
#     'answers': [{'text': 'waste disposal', 'answer_start': 16},
#      {'text': 'waste paper', 'answer_start': 213},
#      {'text': 'polyvinyl chloride', 'answer_start': 234},
#      {'text': 'typical municipal solid wastes', 'answer_start': 262}]},
#    {'id': '38',
#     'is_impossible': False,
#     'question': 'What are the methods used?',
#     'answers': [{'text': 'pyrolysis', 'answer_start': 200},
#      {'text': 'single component pyrolysis', 'answer_start': 504},
#      {'text': 'calculated non-isothermal kinetic parameters',
#       'answer_start': 708},
#      {'text': 'thermal', 'answer_start': 726}]},
#    {'id': '39',
#     'is_impossible': False,
#     'question': 'What are the products formed?',
#     'answers': [{'text': 'renewable sustainable fuel production',
#       'answer_start': 921},
#      {'text': 'renewable energy', 'answer_start': 35},
#      {'text': 'hydrogen-rich syngas production', 'answer_start': 333},
#      {'text': 'hydrogen production', 'answer_start': 873}]},
#    {'id': '40',
#     'is_impossible': True,
#     'question': 'What are the process parameters values?',
#     'answers': []}]},
#  {'context': 'Syngas is a valuable intermediate for sustainable management of waste plastics, which can be converted to new monomers and chemicals. In this work, Ni catalysts were studied for syngas recovery via steam reforming of low-density polyethylene (LDPE) pyrolysis volatiles on various supports, such as Al2O3, MgO, CeO2, Y2O3, TiO2, SiO2 and ZSM-5. Two commercial catalysts (NiAl and NiCaAl) were used for comparison. The supports exhibited distinct effects on the catalytic activity, selectivity and coke formation. Ni/CeO2, Ni/Y2O3, Ni/Al2O3, NiAl and NiCaAl showed high syngas yield but these catalysts were prone to coke formation. Ni/MgO, Ni/TiO2, Ni/SiO2 and Ni/ZSM-5 were the least active. The obtained H2/CO ratios were correlated with CO selectivity, revealing the unique impacts of supports on syngas composition via water-gas shift reaction. Compared with commercial NiAl, our work demonstrated that the prepared Ni catalysts on Al2O3 and MgO were suitable candidates for steam reforming of plastic pyrolysis volatiles.',
#   'qas': [{'id': '41',
#     'is_impossible': False,
#     'question': 'What are the materials used as catalyst?',
#     'answers': [{'text': 'NiAl', 'answer_start': 370},
#      {'text': 'Al2O3', 'answer_start': 298},
#      {'text': 'MgO', 'answer_start': 305}]},
#    {'id': '42',
#     'is_impossible': False,
#     'question': 'What are the reactants used?',
#     'answers': [{'text': 'waste plastics', 'answer_start': 64},
#      {'text': 'low-density polyethylene', 'answer_start': 217},
#      {'text': 'plastic pyrolysis volatiles', 'answer_start': 997}]},
#    {'id': '43',
#     'is_impossible': False,
#     'question': 'What are the methods used?',
#     'answers': [{'text': 'pyrolysis', 'answer_start': 249},
#      {'text': 'pyrolysis volatiles', 'answer_start': 249},
#      {'text': 'reforming', 'answer_start': 204},
#      {'text': 'plastic pyrolysis volatiles', 'answer_start': 997},
#      {'text': 'steam reforming', 'answer_start': 198}]},
#    {'id': '44',
#     'is_impossible': False,
#     'question': 'What are the products formed?',
#     'answers': [{'text': 'new monomers', 'answer_start': 106}]},
#    {'id': '45',
#     'is_impossible': True,
#     'question': 'What are the process parameters values?',
#     'answers': []}]},
#  {'context': 'In the pyrolysis of lignin, lignin tends to agglomerate during the feeding stage, and the char produced can expand easily to form foam that prevents continuous operation. To solve this problem, a new bench-scale rotary kiln reactor with alumina balls was used for the pyrolysis of organosolv lignin. Also, a bench-scale fixed-bed reactor was used as a reference reactor to gain an insight on the pyrolysis phenomena from rotary kiln reactor. Compared to the fixed bed reactor, the rotary kiln reactor resulted in a higher yield of organic phase oil with high selectivity to monomeric phenolic compounds. Moreover, a larger amount of CO2 was obtained from the rotary kiln reactor, which strongly suggests that decarboxylation is main deoxygenation path. Furthermore, a char without agglomeration and foaming inside the reactor was generated from the rotary kiln reactor. The catalytic properties of the chars produced from both reactors with nickel impregnation were tested for the gasification of high-density polyethylene to produce H2. Among the four different catalysts (Ni/Rotary Kiln char, Ni/Fixed Bed char, Ni/Al2O3, Ni/Activated carbon) tested, the Ni/Fixed Bed char exhibited the highest yield of H2 (~two times higher H2 generation) from the gasification process of high-density polyethylene. X-ray photoelectron spectroscopy and scanning electron microscopy offers that the high dispersion/distribution of Ni occurred when the fixed bed char was used as a support. All experimental findings from this study significantly suggest that Ni supported on char could be an economically viable catalyst for producing H2 from gasification of high-density polyethylene.',
#   'qas': [{'id': '46',
#     'is_impossible': False,
#     'question': 'What are the materials used as catalyst?',
#     'answers': [{'text': 'Ni', 'answer_start': 1074}]},
#    {'id': '47',
#     'is_impossible': False,
#     'question': 'What are the reactants used?',
#     'answers': [{'text': 'high-density polyethylene', 'answer_start': 997}]},
#    {'id': '48',
#     'is_impossible': False,
#     'question': 'What are the methods used?',
#     'answers': [{'text': 'pyrolysis', 'answer_start': 7},
#      {'text': 'pyrolysis phenomena', 'answer_start': 396}]},
#    {'id': '49',
#     'is_impossible': False,
#     'question': 'What are the products formed?',
#     'answers': [{'text': 'organic phase oil', 'answer_start': 531}]},
#    {'id': '50',
#     'is_impossible': True,
#     'question': 'What are the process parameters values?',
#     'answers': []}]},
#  {'context': 'Cellulose/polyethylene (CPE) mixture 3:1, w/w with and without three clay catalysts (K10 – montmorillonite K10, KSF – montmorillonite KSF, B – Bentonite) addition were subjected to pyrolysis at temperatures 400, 450 and 500°C with heating rate of 100°C/s to produce bio-oil with high yield. The pyrolytic oil yield was in the range of 41.3–79.5wt% depending on the temperature, the type and the amount of catalyst. The non-catalytic fast pyrolysis at 500°C gives the highest yield of bio-oil (79.5wt%). The higher temperature of catalytic pyrolysis of cellulose/polyethylene mixture the higher yield of bio-oil is. Contrarily, increasing amount of montmorillonite results in significant, almost linear decrease in bio-oil yield followed by a significant increase of gas yield. The addition of clay catalysts to CPE mixture has a various influence on the distribution of bio-oil components. The addition of montmorillonite K10 to cellulose/polyethylene mixture promotes the deepest conversion of polyethylene and cellulose. Additionally, more saturated than unsaturated hydrocarbons are present in resultant bio-oils. The proportion of liquid hydrocarbons is the highest when a montmorillonite K10 is acting as a catalyst.',
#   'qas': [{'id': '51',
#     'is_impossible': False,
#     'question': 'What are the materials used as catalyst?',
#     'answers': [{'text': 'montmorillonite', 'answer_start': 91}]},
#    {'id': '52',
#     'is_impossible': False,
#     'question': 'What are the reactants used?',
#     'answers': [{'text': 'Cellulose/polyethylene', 'answer_start': 0},
#      {'text': 'cellulose/polyethylene mixture', 'answer_start': 552},
#      {'text': '/polyethylene mixture', 'answer_start': 561},
#      {'text': 'polyethylene', 'answer_start': 10}]},
#    {'id': '53',
#     'is_impossible': False,
#     'question': 'What are the methods used?',
#     'answers': [{'text': 'pyrolysis', 'answer_start': 181},
#      {'text': 'The non-catalytic fast pyrolysis', 'answer_start': 415},
#      {'text': 'catalytic pyrolysis', 'answer_start': 529},
#      {'text': 'conversion', 'answer_start': 981},
#      {'text': 'deepest conversion', 'answer_start': 973}]},
#    {'id': '54',
#     'is_impossible': False,
#     'question': 'What are the products formed?',
#     'answers': [{'text': 'oil', 'answer_start': 270},
#      {'text': 'The pyrolytic oil yield', 'answer_start': 291},
#      {'text': 'bio-oil yield', 'answer_start': 714},
#      {'text': 'bio-oil components', 'answer_start': 870},
#      {'text': 'oils', 'answer_start': 1111}]},
#    {'id': '55',
#     'is_impossible': True,
#     'question': 'What are the process parameters values?',
#     'answers': []}]},
#  {'context': 'Catalytic co-pyrolysis of biomass and plastics (HDPE (high density polyethylene), PP (polypropylene) and PET (polyethylene terephthalate)) has been performed in a fixed-bed reactor in presence of cobalt based alumina, ceria and ceria-alumina catalysts to analyze the product distribution and selectivity. Catalysts are synthesized using co-precipitation method and characterized by BET (Brunauer–Emmett–Teller) surface area and XRD analysis. The effect of catalytic co-pyrolysis at different temperature with product distribution has been evaluated. The results have clearly shown the synergistic effect between biomass and plastics, the liquid products gradually increases forming with rise in the plastic content in the blend. Gaseous products have yielded most during pyrolysis of blend having biomass/plastics ratio of 5:1 with the presence of 40% Co/30% CeO2/30% Al2O3 catalyst with hydrogen gas production touched its peak of 47 vol%. Catalytic performance enhanced with increase with the cobalt loading, with best performance attributing to 40% Co/30% CeO2/30% Al2O3 catalyst.',
#   'qas': [{'id': '56',
#     'is_impossible': False,
#     'question': 'What are the materials used as catalyst?',
#     'answers': [{'text': 'cobalt', 'answer_start': 196},
#      {'text': 'Co/30', 'answer_start': 852},
#      {'text': 'CeO2/30', 'answer_start': 859},
#      {'text': 'Al2O3', 'answer_start': 868}]},
#    {'id': '57',
#     'is_impossible': False,
#     'question': 'What are the reactants used?',
#     'answers': [{'text': 'biomass plastics (HDPE', 'answer_start': 1083},
#      {'text': 'high density polyethylene', 'answer_start': 54},
#      {'text': '(polypropylene', 'answer_start': 85},
#      {'text': 'polyethylene terephthalate', 'answer_start': 110},
#      {'text': 'plastics', 'answer_start': 38},
#      {'text': 'plastic content', 'answer_start': 699},
#      {'text': 'biomass/plastics ratio', 'answer_start': 797}]},
#    {'id': '58',
#     'is_impossible': False,
#     'question': 'What are the methods used?',
#     'answers': [{'text': 'pyrolysis', 'answer_start': 13}]},
#    {'id': '59',
#     'is_impossible': False,
#     'question': 'What are the products formed?',
#     'answers': [{'text': 'product distribution', 'answer_start': 267},
#      {'text': 'liquid products', 'answer_start': 638},
#      {'text': 'Gaseous products', 'answer_start': 729},
#      {'text': 'hydrogen gas production', 'answer_start': 888}]},
#    {'id': '60',
#     'is_impossible': True,
#     'question': 'What are the process parameters values?',
#     'answers': []}]},
#  {'context': 'In accordance with global economic prosperity, the frequencies of food delivery and takeout orders have been increasing. The pandemic life, specifically arising from COVID-19, rapidly expanded the food delivery service. Thus, the massive generation of disposable plastic food containers has become significant environmental problems. Establishing a sustainable disposal platform for plastic packaging waste (PPW) of food delivery containers has intrigued particular interest. To comprise this grand challenge, a reliable thermal disposable platform has been suggested in this study. From the pyrolysis process, a heterogeneous plastic mixture of PPW was converted into syngas and value-added hydrocarbons (HCs). PPW collected from five different restaurants consisted of polypropylene (36.9 wt%), polyethylene (10.5 wt%), polyethylene terephthalate (18.1 wt%), polystyrene (13.5 wt%), polyvinyl chloride (4.2 wt%), and other composites (16.8 wt%). Due to these compositional complexities, pyrolysis of PPW led to formations of a variety of benzene derivatives and aliphatic HCs. Adapting multi-stage pyrolysis, the different chemicals were converted into industrial chemicals (benzene, toluene, styrene, etc.). To selectively convert HCs into syngas (H2 and CO), catalytic pyrolysis was adapted using supported Ni catalyst (5 wt% Ni/SiO2). Over Ni catalyst, H2 was produced as a main product due to CH bond scission of HCs. When CO2 was used as a co-reactant, HCs were further transformed to H2 and CO through the chemical reactions of CO2 with gas phase HCs. CO2-assisted catalytic pyrolysis also retarded catalyst deactivation inhibiting coke deposition on Ni catalyst.',
#   'qas': [{'id': '61',
#     'is_impossible': False,
#     'question': 'What are the materials used as catalyst?',
#     'answers': [{'text': 'Ni', 'answer_start': 1311}]},
#    {'id': '62',
#     'is_impossible': False,
#     'question': 'What are the reactants used?',
#     'answers': [{'text': 'disposable plastic food containers',
#       'answer_start': 252},
#      {'text': 'plastic packaging waste', 'answer_start': 383},
#      {'text': 'heterogeneous plastic mixture', 'answer_start': 613},
#      {'text': 'polypropylene', 'answer_start': 771},
#      {'text': 'polyethylene', 'answer_start': 797},
#      {'text': 'polyethylene terephthalate', 'answer_start': 822},
#      {'text': 'polystyrene', 'answer_start': 861}]},
#    {'id': '63',
#     'is_impossible': False,
#     'question': 'What are the methods used?',
#     'answers': [{'text': 'thermal', 'answer_start': 521},
#      {'text': 'reliable thermal disposable platform', 'answer_start': 512},
#      {'text': 'pyrolysis process', 'answer_start': 592},
#      {'text': 'pyrolysis', 'answer_start': 592},
#      {'text': 'multi-stage pyrolysis', 'answer_start': 1088},
#      {'text': 'catalytic pyrolysis', 'answer_start': 1263},
#      {'text': 'CO2-assisted catalytic pyrolysis', 'answer_start': 1560}]},
#    {'id': '64',
#     'is_impossible': False,
#     'question': 'What are the products formed?',
#     'answers': [{'text': 'disposable plastic food containers',
#       'answer_start': 252},
#      {'text': 'value-added hydrocarbons', 'answer_start': 680},
#      {'text': 'polystyrene', 'answer_start': 861},
#      {'text': 'main product', 'answer_start': 1379}]},
#    {'id': '65',
#     'is_impossible': True,
#     'question': 'What are the process parameters values?',
#     'answers': []}]},
#  {'context': 'The joint valorization of high-density polyethylene (HDPE) and light cycle oil (LCO) has been studied via hydroprocessing with the aim of valorizing the HDPE and reducing the sulfur and polyaromatic contents in the LCO. Experiments have been carried out in a batch type reactor under the following conditions: 320–400°C; 80bar; feed:catalyst mass ratio, 20:1; LCO:HDPE mass ratio, 10:1. CoMo/Al catalyst showed higher LCO hydrodesulfurization activity than the other tested catalysts (NiMo/SiAl and NiW/HY), reaching a hydrodesulfurization conversion of 99.3wt% (72ppm of sulfur in the liquid product) at 400°C. Furthermore, a moderate dearomatization was obtained, reaching a polyaromatic conversion of 76wt%. In the hydroprocessing of LCO and HDPE mixture, the joint feeding lightly increases hydrodesulfurization conversion and has no significant impact on product distribution, with HDPE conversion being 31wt%. These results are promising for valorizing waste plastics by incorporating into a first LCO hydroprocessing stage. The hydrodesulfurizated liquid product should be treated in a second hydrocracking stage using a noble metal catalyst supported on strong acid functions.',
#   'qas': [{'id': '66',
#     'is_impossible': False,
#     'question': 'What are the materials used as catalyst?',
#     'answers': [{'text': 'hydrodesulfurizated', 'answer_start': 1035}]},
#    {'id': '67',
#     'is_impossible': False,
#     'question': 'What are the reactants used?',
#     'answers': [{'text': 'high-density polyethylene', 'answer_start': 26},
#      {'text': 'polyaromatic contents', 'answer_start': 186},
#      {'text': 'polyaromatic conversion', 'answer_start': 677},
#      {'text': 'waste plastics', 'answer_start': 959}]},
#    {'id': '68',
#     'is_impossible': False,
#     'question': 'What are the methods used?',
#     'answers': [{'text': 'conversion', 'answer_start': 540},
#      {'text': 'hydrodesulfurization conversion', 'answer_start': 519},
#      {'text': 'polyaromatic conversion', 'answer_start': 677},
#      {'text': 'HDPE conversion', 'answer_start': 887}]},
#    {'id': '69',
#     'is_impossible': False,
#     'question': 'What are the products formed?',
#     'answers': [{'text': 'light cycle oil', 'answer_start': 63},
#      {'text': 'liquid product', 'answer_start': 586},
#      {'text': 'product distribution', 'answer_start': 860},
#      {'text': 'The hydrodesulfurizated liquid product',
#       'answer_start': 1031}]},
#    {'id': '70',
#     'is_impossible': True,
#     'question': 'What are the process parameters values?',
#     'answers': []}]},
#  {'context': 'ZnCl2-activated biochar produced by one-step (impregnated by a 40% ZnCl2 solution, defined as Zn/C-I) and two-step (impregnated by a 40% ZnCl2 solution and microemulsion, defined as Zn/C-II and Zn/C-III, respectively) methods was used to catalyze the pyrolysis of mixed waste plastics (polyethylene, polyethylene, and polystyrene) to comparatively study their catalytic effect on aromatic-enriched oil production. The catalytic mechanism was discussed. The results show that ZnCl2-activated biochar showed high catalytic selectivity to aromatics during the pyrolysis of plastics at 500\u202f°C, and the content of aromatics was increased to 47.5, 46.8, and 42.4% when respectively catalyzed by Zn/C-I, Zn/C-II, and Zn/C-III. Two-ring aromatics were significantly enriched, which accounted for 90.7, 73.1, and 87.7% of the aromatics in Zn/C-I, Zn/C-II, and Zn/C-III catalytic pyrolysis oils. 1,3-Diphenylpropane was the major component of the oils, and its proportion was 19.4, 11.5, and 15.9% in Zn/C-I, Zn/C-II, and Zn/C-III catalytic pyrolysis oils, respectively. The introduced Zn species could increase the surface acidity by forming Lewis acid sites (Zn-L), which increased aromatic yields by promoting the Diels–Alder reaction, hydrogen transfer, and dehydrogenation processes. Zn-L also promoted the condensation reaction of aromatics. Compared with Zn/C-I, Zn/C-III treated by ZnCl2 microemulsion could reduce 41.8% of coke on the catalysts owing to its larger pore size, while maintaining a relatively high oil quality.',
#   'qas': [{'id': '71',
#     'is_impossible': False,
#     'question': 'What are the materials used as catalyst?',
#     'answers': [{'text': 'Zn/C', 'answer_start': 94},
#      {'text': 'Zn/C-III', 'answer_start': 194},
#      {'text': 'ZnCl2', 'answer_start': 0}]},
#    {'id': '72',
#     'is_impossible': False,
#     'question': 'What are the reactants used?',
#     'answers': [{'text': 'mixed waste plastics', 'answer_start': 264},
#      {'text': 'polyethylene', 'answer_start': 286},
#      {'text': 'plastics', 'answer_start': 276}]},
#    {'id': '73',
#     'is_impossible': False,
#     'question': 'What are the methods used?',
#     'answers': [{'text': 'pyrolysis', 'answer_start': 251},
#      {'text': 'Zn/C-III catalytic pyrolysis oils', 'answer_start': 851}]},
#    {'id': '74',
#     'is_impossible': False,
#     'question': 'What are the products formed?',
#     'answers': [{'text': 'aromatic-enriched oil production',
#       'answer_start': 380},
#      {'text': 'Zn/C-III catalytic pyrolysis oils', 'answer_start': 851},
#      {'text': 'oils', 'answer_start': 880},
#      {'text': 'relatively high oil quality', 'answer_start': 1495}]},
#    {'id': '75',
#     'is_impossible': True,
#     'question': 'What are the process parameters values?',
#     'answers': []}]},
#  {'context': 'In this paper the combination of catalytic and stepwise pyrolysis is explored. A mixture of polyethylene (PE), polypropylene (PP), polystyrene (PS), poly(ethylene terephthalate) (PET) and poly(vinyl chloride) (PVC), which resembles real municipal plastic waste, has been pyrolysed in a 3.5dm3 semi-batch reactor at 440°C for 30min using a ZSM-5 zeolite as catalyst. A low temperature (300°C) dechlorination step has been carried out both with and without catalyst. It has been proved that the application of such dechlorination step gives rise to a 75wt% reduction of chlorine in the liquid fraction. However, such step has a negative influence on the catalyst, which loses some catalytic activity. The optimum procedure in terms of quality and chlorine content of the products is the combination of first a low temperature step without catalyst, and second the catalytic pyrolysis step.',
#   'qas': [{'id': '76',
#     'is_impossible': False,
#     'question': 'What are the materials used as catalyst?',
#     'answers': [{'text': 'chlorine', 'answer_start': 568}]},
#    {'id': '77',
#     'is_impossible': False,
#     'question': 'What are the reactants used?',
#     'answers': [{'text': 'polyethylene', 'answer_start': 92},
#      {'text': 'polypropylene', 'answer_start': 111},
#      {'text': 'polystyrene', 'answer_start': 131},
#      {'text': 'poly(ethylene terephthalate', 'answer_start': 149},
#      {'text': 'poly(vinyl chloride', 'answer_start': 188},
#      {'text': 'real municipal plastic waste', 'answer_start': 232}]},
#    {'id': '78',
#     'is_impossible': False,
#     'question': 'What are the methods used?',
#     'answers': [{'text': 'pyrolysis', 'answer_start': 56},
#      {'text': 'catalytic stepwise pyrolysis', 'answer_start': 887},
#      {'text': 'second catalytic pyrolysis step', 'answer_start': 887}]},
#    {'id': '79',
#     'is_impossible': False,
#     'question': 'What are the products formed?',
#     'answers': [{'text': 'polystyrene', 'answer_start': 131},
#      {'text': 'products', 'answer_start': 769}]},
#    {'id': '80',
#     'is_impossible': True,
#     'question': 'What are the process parameters values?',
#     'answers': []}]},
#  {'context': 'In this study, co-pyrolysis of oil shale (Kütahya-Seyitömer, Turkey) and low density polyethylene (LDPE) is performed in a fixed bed reactor under different temperature and mixture ratios. The product yields and characters of co-pyrolysis and individual pyrolysis are compared. The aim of the study is also aimed to find out possible synergistic effects on the yields of tar. Pyrolysis experiments are carried out at various mixture ratios of oil shale/LDPE at the weight ratio of 33%, 50%, 67% and in the temperature range of 600–800 °C. The effects of temperature, LDPE amount in the mixture and catalysts on the thermal degradation of oil shale are investigated in terms of both yield and properties of tar. Tar obtained during the experiments have been characterized with GC–MS and FTIR. The synergistic effect on the formation of valuable products is also discussed. As expected the co-pyrolysis of oil shale and LDPE gave high percentage of tar yields. In addition a remarkable synergetic effect was observed in the co-pyrolysis of oil shale and LDPE and this effect was improved by adding zeolite as a catalyst to the oil shale/LDPE mixture.',
#   'qas': [{'id': '81',
#     'is_impossible': False,
#     'question': 'What are the materials used as catalyst?',
#     'answers': [{'text': 'zeolite', 'answer_start': 1096}]},
#    {'id': '82',
#     'is_impossible': False,
#     'question': 'What are the reactants used?',
#     'answers': [{'text': 'low density polyethylene', 'answer_start': 73}]},
#    {'id': '83',
#     'is_impossible': False,
#     'question': 'What are the methods used?',
#     'answers': [{'text': 'pyrolysis', 'answer_start': 18},
#      {'text': 'individual pyrolysis', 'answer_start': 243},
#      {'text': 'degradation', 'answer_start': 623},
#      {'text': 'thermal degradation', 'answer_start': 615},
#      {'text': 'thermal', 'answer_start': 615}]},
#    {'id': '84',
#     'is_impossible': False,
#     'question': 'What are the products formed?',
#     'answers': [{'text': 'oil shale', 'answer_start': 31},
#      {'text': 'The product yields', 'answer_start': 189},
#      {'text': 'oil shale/LDPE', 'answer_start': 443},
#      {'text': 'valuable products', 'answer_start': 835},
#      {'text': 'oil shale/LDPE mixture', 'answer_start': 1125}]},
#    {'id': '85',
#     'is_impossible': True,
#     'question': 'What are the process parameters values?',
#     'answers': []}]},
#  {'context': 'A novel chemical looping cracking–gasification process was investigated to produce separate H2 and syngas from plastic-derived pyrolysis gas over synthetic Ni–Fe–Al redox catalysts. The non-condensable pyrolysis gas was catalytically cracked at 800 °C, followed by catalyst regeneration with steam. The highest activity was obtained over NiFeAl (molar Ni:Fe:Al = 1:1:1), producing concentrated H2 (83.1 vol%, 0.46 mol g(Ni+Fe) −1) and coke intermediate (232.1 wt%) from cracking. During the steam gasification stage, coke removal efficiency of 96% was obtained with a high syngas yield of 0.89 mol g(Ni+Fe) −1. With equimolar Ni/Fe, increasing Al/(Ni+Fe) ratio led to decreased catalyst activity due to enhanced metal–support interaction. Plausible reaction mechanisms were proposed to interpret the catalytic effects on tuning the morphologies, chemical structure and activity of the coke deposits. This work demonstrates the important role of Ni–Fe–Al catalysts on the production of H2 and syngas via chemical looping cracking–gasification process.',
#   'qas': [{'id': '86',
#     'is_impossible': False,
#     'question': 'What are the materials used as catalyst?',
#     'answers': [{'text': 'Ni', 'answer_start': 156}]},
#    {'id': '87',
#     'is_impossible': False,
#     'question': 'What are the reactants used?',
#     'answers': [{'text': 'plastic-derived pyrolysis gas',
#       'answer_start': 111}]},
#    {'id': '88',
#     'is_impossible': False,
#     'question': 'What are the methods used?',
#     'answers': [{'text': 'pyrolysis', 'answer_start': 127},
#      {'text': 'plastic-derived pyrolysis gas', 'answer_start': 111},
#      {'text': 'The non-condensable pyrolysis gas', 'answer_start': 182}]},
#    {'id': '89',
#     'is_impossible': False,
#     'question': 'What are the products formed?',
#     'answers': [{'text': 'production', 'answer_start': 971}]},
#    {'id': '90',
#     'is_impossible': True,
#     'question': 'What are the process parameters values?',
#     'answers': []}]},
#  {'context': 'This article presents experimental results on the pyrolysis of different mixtures of polymer waste. ABS copolymer, PET, PP, tire waste styrene-butadiene rubber (SBR) and pure non-vulcanised SBR were used in the experiments under different catalyst conditions: (i) without a catalyst, (ii) with an unmodified ZSM-5 catalyst, (iii) with a ZSM-5 catalyst possessing ammonium groups, and (iv) with a ZSM-5 catalyst containing 10 % Ni. The primary objective of this study was to select suitable conditions to pyrolyse polymeric materials depending on the polymer type and properties of the desired final products, e.g., aromatic and heteroaromatic hydrocarbons and valuable chemical subproducts. Suitable conditions can be determined for the thermal conversion of polymeric materials, and using non-catalytic pyrolysis can yield chemical compounds such as alpha-methyl styrene from acrylonitrile-butadiene-styrene (ABS) and limonene from tire waste, which can be used in both fine chemicals and industrial production. The pyrolysis conditions can be modified in terms of the catalyst based on the tested waste polymer and result in products rich in BTEX fractions. Among all tested catalysts, the ZSM-5 catalyst based on aluminosilicate impregnated with nickel ions yielded the highest total fraction of aromatic and heteroaromatic hydrocarbons, especially from the pyrolysis of PP and PET. With this catalyst, more than 75 area% of the product stream (of the total identified product peaks by MS) consisted of aromatic and heteroaromatic fractions (e.g., terephthalonitrile from polyethylene terephthalate), which were composed of 5.6 and 19.9 area% benzene, 7.0 and 10.8 area% toluene, 5.7 and 10.6 area% ethylbenzene and 1.2 and 1.4 area% xylene for PP and PET, respectively. High proportions of the aromatic and heteroaromatic fractions were observed in the product stream during the ABS pyrolysis with two types of catalysts: aluminosilicate with ammonium groups (73 area% of the aromatic and heteroaromatic hydrocarbons) and aluminosilicate impregnated with nickel ions (85 area% of the aromatic and heteroaromatic hydrocarbons).',
#   'qas': [{'id': '91',
#     'is_impossible': False,
#     'question': 'What are the materials used as catalyst?',
#     'answers': [{'text': 'nickel', 'answer_start': 1249}]},
#    {'id': '92',
#     'is_impossible': False,
#     'question': 'What are the reactants used?',
# ...
#   'qas': [{'id': '801',
#     'is_impossible': False,
#     'question': 'What are the materials used as catalyst?',
#     'answers': [{'text': 'TiO2-based', 'answer_start': 858}]},
#    {'id': '802',
#     'is_impossible': False,
#     'question': 'What are the reactants used?',
#     'answers': [{'text': 'wastewater treatment', 'answer_start': 56},
#      {'text': 'wastewater treatment applications', 'answer_start': 1533}]},
#    {'id': '803',
#     'is_impossible': False,
#     'question': 'What are the methods used?',
#     'answers': [{'text': 'degradation', 'answer_start': 1204},
#      {'text': 'photodegradation', 'answer_start': 1199}]},
#    {'id': '804',
#     'is_impossible': True,
#     'question': 'What are the products formed?',
#     'answers': []},
#    {'id': '805',
#     'is_impossible': True,
#     'question': 'What are the process parameters values?',
#     'answers': []}]},
#  {'context': 'The recovery of Polyol from PolyUretane (PU) and Bis(2-HydroxyEthyl) Terephthalate (BHET) from Poly(Ethylene) Terephthalate (PET) from plastic waste by transesterification reactions was achieved, by using a wide scope of simple air-stable metal salts, Lewis acids, mixtures of commercially available phosphine/phosphite ligands with metal salts and low-valent [Ni(COD)2] as catalytic precursors, in the presence of ethyleneglycol as a transesterification agent. A kinetic study with cobalt chloride led to the conclusion that the PET degradation with metal salts behaves as a consecutive reaction with an induction period. The use of σ-donor or σ-donor/π-acceptor bidentate phosphine ligands, such as dcype and dppe, along with CoCl2 or [Ni(COD)2] improved the PET degradation process. For both rigid and flexible PU, FeCl3 was the most active catalyst precursor.',
#   'qas': [{'id': '806',
#     'is_impossible': False,
#     'question': 'What are the materials used as catalyst?',
#     'answers': [{'text': 'FeCl3', 'answer_start': 818}]},
#    {'id': '807',
#     'is_impossible': False,
#     'question': 'What are the reactants used?',
#     'answers': [{'text': 'plastic waste', 'answer_start': 135}]},
#    {'id': '808',
#     'is_impossible': False,
#     'question': 'What are the methods used?',
#     'answers': [{'text': 'degradation', 'answer_start': 534},
#      {'text': 'PET degradation', 'answer_start': 530},
#      {'text': 'PET degradation process', 'answer_start': 761}]},
#    {'id': '809',
#     'is_impossible': False,
#     'question': 'What are the products formed?',
#     'answers': [{'text': '(BHET', 'answer_start': 83}]},
#    {'id': '810',
#     'is_impossible': True,
#     'question': 'What are the process parameters values?',
#     'answers': []}]},
#  {'context': 'The cation-exchange resin loaded with ferrous ion (CERF) catalyzes the photochemical oxidation of 2,4-D. The co-existence of UV light and oxalate is the key to initiating the attack by hydroxyl radicals of 2,4-D in the presence of CERF and H2O2. In addition to oxalate, citrate and EDTA may also drive the CERF-induced photooxidation that is more favorable in an acidic environment. The solid catalyst can easily be separated from the solution by filtration after the reaction, and then reused. The removal rate of 2,4-D with the reused CERF was found to be faster than that with the fresh CERF. This can be explained by the presence of a higher amount of ferrous ions in the recycled resin, thus speeding up the production of hydroxyl radicals. The effect of oxalate concentration on the recycling efficiency of the catalyst was studied. For the first cycle, the rate constants increased as the oxalate concentration increased. The removal rate was strongly dependent on the concentration of the oxalate. For practical purposes, a model was derived to evaluate the capacity of the catalyst and to predict the cumulative mass of 2,4-D removed at any reaction time of any cycle. In a series of four runs conducted with the same catalyst, the optimal concentration of oxalate was found to be 2.4mM, and 74.7% of 2,4-D (total 0.099468mg) was transformed.',
#   'qas': [{'id': '811',
#     'is_impossible': False,
#     'question': 'What are the materials used as catalyst?',
#     'answers': [{'text': 'oxalate', 'answer_start': 138}]},
#    {'id': '812',
#     'is_impossible': True,
#     'question': 'What are the reactants used?',
#     'answers': []},
#    {'id': '813',
#     'is_impossible': True,
#     'question': 'What are the methods used?',
#     'answers': []},
#    {'id': '814',
#     'is_impossible': False,
#     'question': 'What are the products formed?',
#     'answers': [{'text': 'production', 'answer_start': 713}]},
#    {'id': '815',
#     'is_impossible': True,
#     'question': 'What are the process parameters values?',
#     'answers': []}]},
#  {'context': 'A thermo and pH-responsive hydrogel (PNIPAM-co-PPAP) was synthesized via free radical polymerization of N-isopropylacrylamide (NIPAM) and potassium 4-(acryloyloxy) pyridine-2, 6-dicarboxylate (PAP) in mixed solvents of water and tetrahydrofuran. SEM micrographs revealed that the hydrogel was macroporous and the pores within the matrixes were interconnected. The chelidamic acid functionalized PNIPAM-co-PPAP hydrogel exhibited excellent capacity to anchor palladium (II) and the resulting material showed well catalytic activity for copper-free Sonogashira reaction of aryl halides with phenylacetylene in aqueous media. The reactions proceeded well with 0.1mol% of Pd (II) catalyst, due to the good dispersion of Pd2+ in the macroporous structure as well as the enrichment of reactants within hydrogel under reaction conditions. Through the reversibly swelling/deswelling, the PNIPAM-co-PPAP hydrogel-immobilized Pd (II) catalyst could be easily recovered by simple method. Furthermore, the PNIPAM-co-PPAP /Pd catalyst exhibited good recyclability and could be recycled six times without remarkable loss in catalytic activity.',
#   'qas': [{'id': '816',
#     'is_impossible': False,
#     'question': 'What are the materials used as catalyst?',
#     'answers': [{'text': '/Pd', 'answer_start': 1009}]},
#    {'id': '817',
#     'is_impossible': False,
#     'question': 'What are the reactants used?',
#     'answers': [{'text': 'free radical polymerization', 'answer_start': 73}]},
#    {'id': '818',
#     'is_impossible': True,
#     'question': 'What are the methods used?',
#     'answers': []},
#    {'id': '819',
#     'is_impossible': True,
#     'question': 'What are the products formed?',
#     'answers': []},
#    {'id': '820',
#     'is_impossible': True,
#     'question': 'What are the process parameters values?',
#     'answers': []}]},
#  {'context': 'A alumina–magnesium composite oxide catalyst (Al–Mg) was synthesized for catalytic degradation of poly vinyl chloride (PVC) containing polymer mixtures, i.e. polypropylene (PP)/PVC, low-density polyethylene (LDPE)/PVC, polystyrene (PS)/PVC, and LDPE/PP/PS/PVC. In the catalytic degradations the Al–Mg composite oxide catalyst accelerated the rate of polymer degradation and lowered the carbon distribution of liquid products. In addition, it showed good effect on the fixation of evolved HCl and greatly decreased the chlorine content in the oil. These results suggested that the Al–Mg composite oxide catalyst can be effectively used for catalytic degradation and dechlorination of PVC-containing mixed plastics.',
#   'qas': [{'id': '821',
#     'is_impossible': False,
#     'question': 'What are the materials used as catalyst?',
#     'answers': [{'text': 'Al–Mg', 'answer_start': 46},
#      {'text': 'oxide', 'answer_start': 30}]},
#    {'id': '822',
#     'is_impossible': False,
#     'question': 'What are the reactants used?',
#     'answers': [{'text': 'poly vinyl chloride', 'answer_start': 98},
#      {'text': 'polymer mixtures', 'answer_start': 135},
#      {'text': 'polypropylene', 'answer_start': 158},
#      {'text': 'PP)/PVC, low-density polyethylene', 'answer_start': 173},
#      {'text': ', polystyrene', 'answer_start': 217},
#      {'text': 'polymer degradation', 'answer_start': 350},
#      {'text': 'PVC-containing mixed plastics', 'answer_start': 683}]},
#    {'id': '823',
#     'is_impossible': False,
#     'question': 'What are the methods used?',
#     'answers': [{'text': 'degradation', 'answer_start': 83},
#      {'text': 'catalytic degradation', 'answer_start': 73},
#      {'text': 'catalytic degradations', 'answer_start': 268},
#      {'text': 'polymer degradation', 'answer_start': 350}]},
#    {'id': '824',
#     'is_impossible': False,
#     'question': 'What are the products formed?',
#     'answers': [{'text': ', polystyrene', 'answer_start': 217},
#      {'text': 'liquid products', 'answer_start': 409},
#      {'text': 'oil', 'answer_start': 542}]},
#    {'id': '825',
#     'is_impossible': True,
#     'question': 'What are the process parameters values?',
#     'answers': []}]},
#  {'context': 'Polymers are extensively used as supports for the fabrication of catalysts. They have many advantages such as high thermal stability, ease of modification, high mechanical strength and large surface area. In recent years, the methods for the preparation of metal nanoparticles and complex based catalysts have been developed to a great extent. The presence of supports in the construction of catalysts prevents the accumulation of metal nanoparticles. In this review, polymer-supported ruthenium (Ru) catalysts (in two complex and nano forms) have been covered as significant catalysts for the oxidation of compounds such as types of alcohols, D-glucose, 5-hydroxymethylfurfural, etc. Oxidation of alcohols is of outstanding importance both in industrial and academic research. The solvent, oxygen pressure and temperature are the significant reaction parameters in the process. The advantages and differences related to the reported polymer-supported Ru catalyst systems have been reviewed, while new progresses, for example, a catalyst system for optimal oxidations, have also been outlined.',
#   'qas': [{'id': '826',
#     'is_impossible': False,
#     'question': 'What are the materials used as catalyst?',
#     'answers': [{'text': 'Ru', 'answer_start': 497}]},
#    {'id': '827',
#     'is_impossible': False,
#     'question': 'What are the reactants used?',
#     'answers': [{'text': 'polymer-supported ruthenium (Ru) catalysts',
#       'answer_start': 468},
#      {'text': 'reported polymer-supported Ru catalyst systems',
#       'answer_start': 925}]},
#    {'id': '828',
#     'is_impossible': False,
#     'question': 'What are the methods used?',
#     'answers': [{'text': 'thermal', 'answer_start': 115},
#      {'text': 'high thermal stability', 'answer_start': 110}]},
#    {'id': '829',
#     'is_impossible': True,
#     'question': 'What are the products formed?',
#     'answers': []},
#    {'id': '830',
#     'is_impossible': True,
#     'question': 'What are the process parameters values?',
#     'answers': []}]},
#  {'context': 'This work reports immobilization of ZnO photocatalyst on very fine pineapple leaf fiber (PALFs) by a by polyelectrolyte coating method, for the removal of colored pollutants from water stream, allowing for simple recovery after use. It also emphasizes on the effect of defect structure containing in ZnO of hierarchical sphere-like and flake-like morphologies on the color removal performance. The photocatalytic activity of ZnO/PALFs for degradation of congo red (CR) dye was examined under static (dark) and UV/visible irradiation conditions, and effective color removal (>95 %) was achieved, as the results of adsorption and photo-oxidation processes. Results from photoluminescence and X-ray photoelectron spectroscopy suggested that the sphere-like ZnO, bearing zinc vacancies (VZn), zinc interstitials (Zni), singly ionized oxygen vacancies (Vo +), and oxygen vacancies (Vo), has superior photocatalytic activity up to 3.6 times compared to that of flake-like ZnO. With the recyclability up to 3 cycles (>84 % color removal efficiencies), the ZnO immobilized on PALFs have shown a great promise as an easy-to-recover photocatalyst for the removal of colored pollutants in wastewater treatment processes.',
#   'qas': [{'id': '831',
#     'is_impossible': False,
#     'question': 'What are the materials used as catalyst?',
#     'answers': [{'text': 'ZnO', 'answer_start': 36}]},
#    {'id': '832',
#     'is_impossible': False,
#     'question': 'What are the reactants used?',
#     'answers': [{'text': 'polyelectrolyte coating method',
#       'answer_start': 104},
#      {'text': 'wastewater treatment processes', 'answer_start': 1178}]},
#    {'id': '833',
#     'is_impossible': False,
#     'question': 'What are the methods used?',
#     'answers': [{'text': 'degradation', 'answer_start': 439}]},
#    {'id': '834',
#     'is_impossible': True,
#     'question': 'What are the products formed?',
#     'answers': []},
#    {'id': '835',
#     'is_impossible': True,
#     'question': 'What are the process parameters values?',
#     'answers': []}]},
#  {'context': 'The hydrolysis of cellulose catalysed by ionic liquid (IL) immobilized on chloromethyl vinyl benzene (CMVB) with different IL/CMVB ratio was carried out in water as a solvent. The influence of process variables like IL/CMVB ratio in catalyst, temperature and time were investigated in a batch reactor. It was found that 40% IL/CMVB catalyst afforded maximum%TRS and glucose yield 58.5 and 47.9% respectively at 160 °C in 6h reaction time. This can be attributed to the synergistic effect of chloro and sulfonic groups, to dissolve the cellulose by breaking the intra and inter molecular hydrogen bonds and cleave the β-1, 4 glycosidic bonds respectively. The catalysts synthesized in the laboratory were characterized by FTIR, CHNS and TGA. The catalyst can be recovered three times without any significant loss in activity and characterized by FTIR to show the peaks of chloro and sulfonic groups in the recovered catalyst.',
#   'qas': [{'id': '836',
#     'is_impossible': False,
#     'question': 'What are the materials used as catalyst?',
#     'answers': [{'text': 'sulfonic', 'answer_start': 502}]},
#    {'id': '837',
#     'is_impossible': True,
#     'question': 'What are the reactants used?',
#     'answers': []},
#    {'id': '838',
#     'is_impossible': False,
#     'question': 'What are the methods used?',
#     'answers': [{'text': 'The hydrolysis', 'answer_start': 0},
#      {'text': 'hydrolysis', 'answer_start': 4}]},
#    {'id': '839',
#     'is_impossible': True,
#     'question': 'What are the products formed?',
#     'answers': []},
#    {'id': '840',
#     'is_impossible': True,
#     'question': 'What are the process parameters values?',
#     'answers': []}]}]

# %%
len(train)
# Out:
# 168

# %%
train_ = train[:int(0.70*(len(train)))]                       #70% train
valid_ = train[int(0.70*(len(train))):int(0.85*(len(train)))] #15% valid 
test_  = train[int(0.85*(len(train))):]                       #15% test

# %%
len(train_), len(test_), len(valid_)
# Out:
# (14254, 3055, 3054)

# %%
import json
with open('/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/data/data qna/data_individual/with_dupli/bert/full_train_2.json', 'w') as F:
    # Use the json dumps method to write the list to disk
    F.write(json.dumps(train_))

# %%
import json
with open('/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/data/data qna/data_individual/with_dupli/bert/full_test_2.json', 'w') as F:
    # Use the json dumps method to write the list to disk
    F.write(json.dumps(test_))

# %%
import json
with open('/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/data/data qna/data_individual/with_dupli/bert/full_valid_2.json', 'w') as F:
    # Use the json dumps method to write the list to disk
    F.write(json.dumps(valid_))

# %%
import json
with open('/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/data/data qna/data_individual/with_dupli/full_train_full_2.json', 'w') as F:
    # Use the json dumps method to write the list to disk
    F.write(json.dumps(train))

# %%
dff.to_csv(r"/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/data/data qna/data_with_all.csv")

# %%
df.to_csv(r'/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/data/data qna/data_individual/with_dupli/data.txt', header=None, index=None, sep=' ', mode='a')

# %%
dff.shape
# Out:
# (19333, 7)

# %%
dff.to_csv(r"/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/data/data qna/data_with_all.csv")

# %%
def answers(num, total_text, catalystss):
    listss =  []  #Above list for answer  

    for a in range(len(catalystss)):
    #if len(catalystss) != 0:
        dicttt = {} # One anwser list
        dicttt["text"] = catalystss[a]
        values = total_text.split(catalystss[a])
        b = 0
        for c in values[0]:
            b = b + 1
        dicttt["answer_start"] = b

        listss.append(dicttt)
        
    return listss

# %%
ddf_react = dff_react['Abstract']
len(ddf_react)
# Out:
# 4670

# %%
train = []

j =1
for inde,abst in enumerate(dff_prod['Abstract']):
    data1 = {} #This list for a context 
    
    data1["context"] =  abst
    
    dictt_cat = {}   #Dict for catalyst question
    dictt_react = {} #Dict for reactants question
    dictt_metho= {} #Dict for method question
    dictt_prod = {} #Dict for product question
    
#     The data making for the catalyst entries
#     comp =  dff_cat['catalyst'][inde]
#     if len(comp) != 0:
#         listt = []
#         #This dict for QnA task
#         dictt_cat["id"] = str(j)   # j tells the question number

#         boolen_list = [True, False]    # tells the is it possible to answer or not
#         dictt_cat["is_impossible"] =  boolen_list[1]

#         ques = ["What is the name of catalyst?"]   #Question write here
#         dictt_cat["question"] = ques[0]

#         listttt_cat = answers(inde, abst,comp)
#         j = j+1
#     elif len(comp) == 0:
#         #THis dict for QnA task
#         dictt_cat["id"] = str(j)

#         boolen_list = [True, False]
#         dictt_cat["is_impossible"] =  boolen_list[0]

#         ques = ["What is the name of catalyst?"] 
#         dictt_cat["question"] = ques[0]

#         listttt_cat =  []
#         #listss.append(answers(sent, s))
#         j = j+1
    
    #data1 = {} #This list for a context 
    
#     data1["context"] =  abst
    
    #Data making for reactant(polymers) 
#     react = dff_react['reactant'][inde] 
#     if len(react) != 0:
#         listttt = []
#         #This dict for QnA task
#         dictt_react["id"] = str(j)   # j tells the question number

#         boolen_list = [True, False]    # tells the is it possible to answer or not
#         dictt_react["is_impossible"] =  boolen_list[1]

#         ques = ["What is the name of reactant?"]   #Question write here
#         dictt_react["question"] = ques[0]

#         listttt_react = answers(inde, abst,react)
#         j = j+1
#     elif len(react) == 0:
#         #THis dict for QnA task
#         dictt_react["id"] = str(j)

#         boolen_list = [True, False]
#         dictt_react["is_impossible"] =  boolen_list[0]

#         ques = ["What is the name of reactant?"] 
#         dictt_react["question"] = ques[0]

#         listttt_react =  []
#         #listss.append(answers(sent, s))
#         j = j+1

#     #Data making for methods 
#     metho = dff_meth['Method'][inde] 
#     if len(metho) != 0:
#         listt = []
#         #This dict for QnA task
#         dictt_metho["id"] = str(j)   # j tells the question number

#         boolen_list = [True, False]    # tells the is it possible to answer or not
#         dictt_metho["is_impossible"] =  boolen_list[1]

#         ques = ["What is the name of method?"]   #Question write here
#         dictt_metho["question"] = ques[0]

#         listttt_metho = answers(inde, abst,metho)
#         j = j+1
#     elif len(metho) == 0:
#         #THis dict for QnA task
#         dictt_metho["id"] = str(j)

#         boolen_list = [True, False]
#         dictt_metho["is_impossible"] =  boolen_list[0]

#         ques = ["What is the name of method?"] 
#         dictt_metho["question"] = ques[0]

#         listttt_metho =  []
#         #listss.append(answers(sent, s))
#         j = j+1
        
#     #The data making for the product entries
    prod =  dff_prod['Product'][inde]
    if len(prod) != 0:
        listt = []
        #This dict for QnA task
        dictt_prod["id"] = str(j)   # j tells the question number

        boolen_list = [True, False]    # tells the is it possible to answer or not
        dictt_prod["is_impossible"] =  boolen_list[1]

        ques = ["What are the name of products?"]   #Question write here
        dictt_prod["question"] = ques[0]

        listttt_prod = answers(inde, abst,prod)
        j = j+1
        
    elif len(prod) == 0:
        #THis dict for QnA task
        dictt_prod["id"] = str(j)

        boolen_list = [True, False]
        dictt_prod["is_impossible"] =  boolen_list[0]

        ques = ["What are the name of products?"] 
        dictt_prod["question"] = ques[0]

        listttt_prod =  []
        #listss.append(answers(sent, s))
        j = j+1
    

#     dictt_cat["answers"] = listttt_cat
#     dictt_react["answers"] = listttt_react
#     dictt_metho["answers"] = listttt_metho
    dictt_prod["answers"]  = listttt_prod
    
    lisst= []    #QnA list where question and answer exist
    
#     lisst.append(dictt_cat)
#     lisst.append(dictt_react)
#     lisst.append(dictt_metho)
    lisst.append(dictt_prod)
    
    data1["qas"] = lisst
    
    train.append(data1)

# %%
doc =  nlp(sent_tokenize(df_pe['Abstract'][2019])[5])

for a, chunk in enumerate(doc.noun_chunks):
    #print(chunk.text)
    if 'yield' in chunk.text: 
        print(chunk)
# Out:
# The gas yield

# %%
productextract(df_pe['Abstract'][2021])
# Out:
# ['low energy consumption building',
#  'concrete production',
#  'embodied energy',
#  'concrete production',
#  'lightweight concrete and thermal insulation products',
#  'lightweight concrete and thermal insulation products',
#  'EPS concrete',
#  'EPS aggregate concrete',
#  'concrete',
#  'the production',
#  'concrete']

# %%
for sen in sent_tokenize(df_pe['Abstract'][2021]):
    print(sen,"\n")
# Out:
# With the limited supply of energies that we can extract or mine from the earth, low energy consumption building is indeed a demand for the present situation with the use of sustainable building materials.
#
# Owing to the frequent use of EPS in the packaging industry, the versatile use of non-biodegradable EPS contributes to increasing global waste generation.
#
# In this regard, the utilization of recycled EPS in concrete production can be a sustainable approach to manage embodied energy.
#
# EPS is a very lightweight thermal insulating material and is primarily used to prepare lightweight concrete and thermal insulation products in the construction sector.
#
# Currently, EPS-based cementitious composites are used in many building structures due to their excellent durability, thermal performance, and sustainability benefits.
#
# Several extensive studies have been carried out over a few years to maximize the hardened and durability properties of EPS concrete.
#
# With a number of building materials emerging, there is a lack of in-depth review studies on the performance of EPS aggregate concrete.
#
# The study underlines the influence of the addition of EPS to lightweight concrete in terms of mechanical, durability, and thermal insulation properties.
#
# The main contribution of this article lies in the exploration of subsequent additives, for the production of modified EPS to improve the performance of concrete.
#
# Further, the review is expected to provide substantial knowledge on the potential use of EPS, to promote sustainability in the construction sector.

# %%
reactantextract(df_pe['Abstract'][2017]), methodextract(df_pe['Abstract'][2017]), productextract(df_pe['Abstract'][2018])
# Out:
# (['photovoltaic silicon (Si) waste', 'Si waste'],
#  ['thermal',
#   'an electrothermal shock method',
#   'thermal',
#   'thermal',
#   'High-gradient thermal fields',
#   'thermal',
#   'thermal',
#   'thermal',
#   'thermal',
#   'thermal',
#   'thermal'],
#  ['energy',
#   'energy',
#   'energy',
#   'energy',
#   'energy',
#   'energy',
#   'clean energy',
#   'energy',
#   'energy',
#   'energy',
#   'energy'])

# %%
#["polyethylene","waste","plastic", 'PET', 'wastes' ]   #We will try this words

def reactantextract(text):
    reactants =  ['poly', 'waste', "wastes", "plastic", "plastics"]
    reactant = []
    for sen in sent_tokenize(text):
#         if "poly" in sen:
        doc = nlp(sen)
        for a, chunk in enumerate(doc.noun_chunks):
            #print(chunk)
            for react in reactants:
                if react in chunk.text:
                    reactant.append(chunk.text)
    return reactant

reactantextract(df_pe['Abstract'][2017])
# Out:
# ['photovoltaic silicon (Si) waste', 'Si waste']

# %%
for sen in sent_tokenize(df['Abstract'][0]):
    if "pyrolysis" in sen:
        doc = nlp(sen)
        print(sen, "\n")
        for text in doc:
            print(text,">>>>>>>>>" ,text.pos_, ">>>>>>>>", text.dep_)
# Out:
# The products of pyrolysis carried out at an appropriate temperature are monomers and other valuable chemicals.
#
# The >>>>>>>>> DET >>>>>>>> det
# products >>>>>>>>> NOUN >>>>>>>> nsubj
# of >>>>>>>>> ADP >>>>>>>> prep
# pyrolysis >>>>>>>>> NOUN >>>>>>>> pobj
# carried >>>>>>>>> VERB >>>>>>>> acl
# out >>>>>>>>> ADP >>>>>>>> prt
# at >>>>>>>>> ADP >>>>>>>> prep
# an >>>>>>>>> DET >>>>>>>> det
# appropriate >>>>>>>>> ADJ >>>>>>>> amod
# temperature >>>>>>>>> NOUN >>>>>>>> pobj
# are >>>>>>>>> AUX >>>>>>>> ROOT
# monomers >>>>>>>>> NOUN >>>>>>>> attr
# and >>>>>>>>> CCONJ >>>>>>>> cc
# other >>>>>>>>> ADJ >>>>>>>> amod
# valuable >>>>>>>>> ADJ >>>>>>>> amod
# chemicals >>>>>>>>> NOUN >>>>>>>> conj
# . >>>>>>>>> PUNCT >>>>>>>> punct
# This chapter describes the pyrolysis reactions and products of frequently used thermoplastics and thermosets in polymer composites.
#
# This >>>>>>>>> DET >>>>>>>> det
# chapter >>>>>>>>> NOUN >>>>>>>> nsubj
# describes >>>>>>>>> VERB >>>>>>>> ROOT
# the >>>>>>>>> DET >>>>>>>> det
# pyrolysis >>>>>>>>> NOUN >>>>>>>> compound
# reactions >>>>>>>>> NOUN >>>>>>>> dobj
# and >>>>>>>>> CCONJ >>>>>>>> cc
# products >>>>>>>>> NOUN >>>>>>>> conj
# of >>>>>>>>> ADP >>>>>>>> prep
# frequently >>>>>>>>> ADV >>>>>>>> advmod
# used >>>>>>>>> VERB >>>>>>>> amod
# thermoplastics >>>>>>>>> NOUN >>>>>>>> pobj
# and >>>>>>>>> CCONJ >>>>>>>> cc
# thermosets >>>>>>>>> NOUN >>>>>>>> conj
# in >>>>>>>>> ADP >>>>>>>> prep
# polymer >>>>>>>>> NOUN >>>>>>>> compound
# composites >>>>>>>>> NOUN >>>>>>>> pobj
# . >>>>>>>>> PUNCT >>>>>>>> punct
# Published results on pyrolysis of various polymer composites are discussed in order to understand the requirements of successful plastic composite recycling by pyrolysis.
#
# Published >>>>>>>>> VERB >>>>>>>> amod
# results >>>>>>>>> NOUN >>>>>>>> nsubjpass
# on >>>>>>>>> ADP >>>>>>>> prep
# pyrolysis >>>>>>>>> NOUN >>>>>>>> pobj
# of >>>>>>>>> ADP >>>>>>>> prep
# various >>>>>>>>> ADJ >>>>>>>> amod
# polymer >>>>>>>>> NOUN >>>>>>>> compound
# composites >>>>>>>>> NOUN >>>>>>>> pobj
# are >>>>>>>>> AUX >>>>>>>> auxpass
# discussed >>>>>>>>> VERB >>>>>>>> ROOT
# in >>>>>>>>> ADP >>>>>>>> prep
# order >>>>>>>>> NOUN >>>>>>>> pobj
# to >>>>>>>>> PART >>>>>>>> aux
# understand >>>>>>>>> VERB >>>>>>>> acl
# the >>>>>>>>> DET >>>>>>>> det
# requirements >>>>>>>>> NOUN >>>>>>>> dobj
# of >>>>>>>>> ADP >>>>>>>> prep
# successful >>>>>>>>> ADJ >>>>>>>> amod
# plastic >>>>>>>>> NOUN >>>>>>>> amod
# composite >>>>>>>>> ADJ >>>>>>>> amod
# recycling >>>>>>>>> NOUN >>>>>>>> pobj
# by >>>>>>>>> ADP >>>>>>>> prep
# pyrolysis >>>>>>>>> NOUN >>>>>>>> pobj
# . >>>>>>>>> PUNCT >>>>>>>> punct
# The environmental concern related to pyrolysis of flame retardants containing polymer composites is also touched upon and some methods are referred to for decreasing or eliminating toxic and harmful compounds from the pyrolysis products of halogenated flame retardants.
#
# The >>>>>>>>> DET >>>>>>>> det
# environmental >>>>>>>>> ADJ >>>>>>>> amod
# concern >>>>>>>>> NOUN >>>>>>>> nsubjpass
# related >>>>>>>>> VERB >>>>>>>> acl
# to >>>>>>>>> ADP >>>>>>>> prep
# pyrolysis >>>>>>>>> NOUN >>>>>>>> pobj
# of >>>>>>>>> ADP >>>>>>>> prep
# flame >>>>>>>>> ADJ >>>>>>>> amod
# retardants >>>>>>>>> NOUN >>>>>>>> pobj
# containing >>>>>>>>> VERB >>>>>>>> acl
# polymer >>>>>>>>> NOUN >>>>>>>> compound
# composites >>>>>>>>> NOUN >>>>>>>> dobj
# is >>>>>>>>> AUX >>>>>>>> auxpass
# also >>>>>>>>> ADV >>>>>>>> advmod
# touched >>>>>>>>> VERB >>>>>>>> ROOT
# upon >>>>>>>>> SCONJ >>>>>>>> prep
# and >>>>>>>>> CCONJ >>>>>>>> cc
# some >>>>>>>>> DET >>>>>>>> det
# methods >>>>>>>>> NOUN >>>>>>>> nsubjpass
# are >>>>>>>>> AUX >>>>>>>> auxpass
# referred >>>>>>>>> VERB >>>>>>>> conj
# to >>>>>>>>> ADP >>>>>>>> prep
# for >>>>>>>>> ADP >>>>>>>> prep
# decreasing >>>>>>>>> VERB >>>>>>>> pcomp
# or >>>>>>>>> CCONJ >>>>>>>> cc
# eliminating >>>>>>>>> VERB >>>>>>>> conj
# toxic >>>>>>>>> ADJ >>>>>>>> amod
# and >>>>>>>>> CCONJ >>>>>>>> cc
# harmful >>>>>>>>> ADJ >>>>>>>> conj
# compounds >>>>>>>>> NOUN >>>>>>>> dobj
# from >>>>>>>>> ADP >>>>>>>> prep
# the >>>>>>>>> DET >>>>>>>> det
# pyrolysis >>>>>>>>> NOUN >>>>>>>> compound
# products >>>>>>>>> NOUN >>>>>>>> pobj
# of >>>>>>>>> ADP >>>>>>>> prep
# halogenated >>>>>>>>> ADJ >>>>>>>> amod
# flame >>>>>>>>> NOUN >>>>>>>> compound
# retardants >>>>>>>>> NOUN >>>>>>>> pobj
# . >>>>>>>>> PUNCT >>>>>>>> punct

# %%
doc = nlp(sent_tokenize(df.Abstract[30])[0])
for text in doc:
    print(text,">>>>>>>>>" ,text.pos_, ">>>>>>>>", text.dep_)
# Out:
# The >>>>>>>>> DET >>>>>>>> det
# aim >>>>>>>>> NOUN >>>>>>>> nsubj
# of >>>>>>>>> ADP >>>>>>>> prep
# this >>>>>>>>> DET >>>>>>>> det
# work >>>>>>>>> NOUN >>>>>>>> pobj
# was >>>>>>>>> AUX >>>>>>>> ROOT
# to >>>>>>>>> PART >>>>>>>> aux
# study >>>>>>>>> VERB >>>>>>>> xcomp
# the >>>>>>>>> DET >>>>>>>> det
# effects >>>>>>>>> NOUN >>>>>>>> dobj
# of >>>>>>>>> ADP >>>>>>>> prep
# plastics >>>>>>>>> NOUN >>>>>>>> pobj
# ( >>>>>>>>> PUNCT >>>>>>>> punct
# high >>>>>>>>> ADJ >>>>>>>> amod
# - >>>>>>>>> PUNCT >>>>>>>> punct
# density >>>>>>>>> NOUN >>>>>>>> compound
# polyethylene >>>>>>>>> NOUN >>>>>>>> appos
# ( >>>>>>>>> PUNCT >>>>>>>> punct
# HDPE >>>>>>>>> PROPN >>>>>>>> appos
# ) >>>>>>>>> PUNCT >>>>>>>> punct
# , >>>>>>>>> PUNCT >>>>>>>> punct
# polystyrene >>>>>>>>> PROPN >>>>>>>> conj
# ( >>>>>>>>> PUNCT >>>>>>>> punct
# PS >>>>>>>>> PROPN >>>>>>>> appos
# ) >>>>>>>>> PUNCT >>>>>>>> punct
# , >>>>>>>>> PUNCT >>>>>>>> punct
# polypropylene >>>>>>>>> NOUN >>>>>>>> conj
# ( >>>>>>>>> PUNCT >>>>>>>> punct
# PP >>>>>>>>> PROPN >>>>>>>> appos
# ) >>>>>>>>> PUNCT >>>>>>>> punct
# , >>>>>>>>> PUNCT >>>>>>>> punct
# and >>>>>>>>> CCONJ >>>>>>>> cc
# polyethylene >>>>>>>>> NOUN >>>>>>>> compound
# terephthalate >>>>>>>>> NOUN >>>>>>>> conj
# ( >>>>>>>>> PUNCT >>>>>>>> punct
# PET >>>>>>>>> NOUN >>>>>>>> appos
# ) >>>>>>>>> PUNCT >>>>>>>> punct
# ) >>>>>>>>> PUNCT >>>>>>>> punct
# on >>>>>>>>> ADP >>>>>>>> prep
# reactor >>>>>>>>> NOUN >>>>>>>> compound
# performance >>>>>>>>> NOUN >>>>>>>> pobj
# and >>>>>>>>> CCONJ >>>>>>>> cc
# microbial >>>>>>>>> ADJ >>>>>>>> amod
# communities >>>>>>>>> NOUN >>>>>>>> conj
# during >>>>>>>>> ADP >>>>>>>> prep
# acidogenic >>>>>>>>> ADJ >>>>>>>> amod
# fermentation >>>>>>>>> NOUN >>>>>>>> pobj
# of >>>>>>>>> ADP >>>>>>>> prep
# food >>>>>>>>> NOUN >>>>>>>> compound
# waste >>>>>>>>> NOUN >>>>>>>> pobj
# for >>>>>>>>> ADP >>>>>>>> prep
# the >>>>>>>>> DET >>>>>>>> det
# production >>>>>>>>> NOUN >>>>>>>> pobj
# of >>>>>>>>> ADP >>>>>>>> prep
# volatile >>>>>>>>> ADJ >>>>>>>> amod
# fatty >>>>>>>>> ADJ >>>>>>>> compound
# acids >>>>>>>>> NOUN >>>>>>>> pobj
# ( >>>>>>>>> PUNCT >>>>>>>> punct
# VFA >>>>>>>>> PROPN >>>>>>>> appos
# ) >>>>>>>>> PUNCT >>>>>>>> punct
# . >>>>>>>>> PUNCT >>>>>>>> punct

# %%
sent_tokenize(df['Abstract'][440])
# Out:
# ['Silica nanoparticles (SiNPs), have recently emerged as important nanomaterials with immense applications in various fields.',
#  'Owing to their variable pore size, high surface area, surface reactivity, structural flexibility, stability, and low toxicity SiNPs are appealing to be employed in numerous fields including biomedicine and environment remediation.',
#  'Though several methods are being applied for the synthesis of SiNPs from various sources; the key inclination in this regard is the concept of environment safety and "green" technologies.',
#  'Numerous low-cost and renewable materials are being investigated as a source of precursor materials for the synthesis of SiNPs and agricultural waste holds great potential in this regard.',
#  'Due to the abundance of silica in diverse agricultural residues, synthesis of nano-silica from them, leads to new possibilities for agro-waste management and valorization.',
#  'For extraction of bonded silica from agrowastes different conventional methods are in place, however extraction, mediated by microbes can make the process further eco-friendly and hence holds great research potential.',
#  'The biological extraction of these nanoparticles from agricultural waste and the mechanism behind it is not much explored and reviewed.',
#  'This review highlights several agricultural wastes which can be applied as precursor for generation of SiNPs and elaborates the mechanism behind biological extraction of SiNPs from agro-waste in detail.',
#  'We have also discussed various applications of SiNPs, emphasizing their role in environment monitoring, detection and bioremediation.',
#  'Finally, we have discussed the challenges in producing nano-sized silica from agro-waste, along with research priorities in this field that will help researchers for further investigations in this field.']

# %%
#13503 out of 21000
len(dff)
# Out:
# 4758

# %%
inddd =  []
for i in dff.index:
    if len(dff['Product'][i]) != 0:
        inddd.append(i)
        
dff_prod = dff.loc[inddd].reset_index(drop = True)
len(dff_prod)
# Out:
# 2020

# %%
dff_react
# Out:
#                                     DOI  \
# 0           10.1533/9781845697662.2.102
# 1            10.1016/j.fuel.2021.120505
# 2     10.1016/j.conbuildmat.2022.127949
# 3          10.1016/j.arabjc.2022.104262
# 4     10.1016/j.conbuildmat.2019.117253
# ...                                 ...
# 4665      10.1016/j.jnucmat.2011.09.029
# 4666       10.1016/j.seppur.2021.118767
# 4667       10.1016/j.envpol.2021.117621
# 4668        10.1016/j.matpr.2022.05.519
# 4669         10.1016/j.jaap.2009.03.003
#
#                                                   Title  \
# 0           5 Pyrolysis for recycling waste composites
# 1     Low-pressure hydrothermal processing of mixed ...
# 2     Cement mortars with ceramic molds shells and p...
# 3     Degradation-fragmentation of marine plastic wa...
# 4     Performance of AC mixtures containing flakes o...
# ...                                                 ...
# 4665  Performance of aged cement–polymer composite i...
# 4666  Flotation separation of acrylonitrile-butadien...
# 4667  Achievements in pyrolysis process in E-waste m...
# 4668  Advances in plastic waste-derived carbon nanom...
# 4669  A comparative study on thermal and catalytic d...
#
#                                                Abstract catalyst  \
# 0                    Pyrolysis is a suitable process...       []
# 1     The amount of polyolefin waste, which is 63% o...       []
# 2     Foundry industry produces millions of tons of ...       []
# 3     This review critically evaluates the plastic a...       []
# 4     This paper evaluates the performance of asphal...       []
# ...                                                 ...      ...
# 4665  An advanced composite of cement and water exte...       []
# 4666  The wasted acrylonitrile–butadienestyrene (ABS...       []
# 4667  Many aspects of modern life of our civilizatio...       []
# 4668  Plastic is one of the most serious environment...       []
# 4669  A comparative study on the thermal and catalyt...       []
#
#                                                reactant  \
# 0     [recycling polymer composites, polymer matrix,...
# 1     [polyolefin waste, total plastic waste, 50% po...
# 2                                      [wastes, wastes]
# 3     [plastic accumulation challenges, plastic prod...
# 4     [low density polyethylene, plastic film, optim...
# ...                                                 ...
# 4665  [extended polyester, recycled Poly(ethylene te...
# 4666  [high impact polystyrene, polymer surface modi...
# 4667  [electronic waste, E-waste, waste, waste mater...
# 4668  [waste plastic, plastic waste, current plastic...
# 4669                       [polybutylene terephthalate]
#
#                                                  Method  \
# 0     [thermal, thermal decomposition products, pyro...
# 1      [Its degradation products, degradation, thermal]
# 2                                                    []
# 3     [degradation, degradation, fragmentation degra...
# 4                                                    []
# ...                                                 ...
# 4665                        [thermal, thermal analyses]
# 4666                                                 []
# 4667  [pyrolysis, pyrolysis process, pyrolysis proce...
# 4668                                                 []
# 4669  [degradation, thermal catalytic degradation, t...
#
#                                                 Product
# 0     [thermal, thermal decomposition products, pyro...
# 1      [Its degradation products, degradation, thermal]
# 2                                                    []
# 3     [degradation, degradation, fragmentation degra...
# 4                                                    []
# ...                                                 ...
# 4665                        [thermal, thermal analyses]
# 4666                                                 []
# 4667  [pyrolysis, pyrolysis process, pyrolysis proce...
# 4668                                                 []
# 4669  [degradation, thermal catalytic degradation, t...
#
# [4670 rows x 7 columns]

# %%
len(dff)
# Out:
# 4758
