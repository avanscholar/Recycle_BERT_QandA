# %%
#Import basic libraries
import pandas as pd
import numpy as np

# %%
#Access the avaiable full text DOIs
df0 = pd.read_csv(r"/home/user3/Documents/avan_phd/Objective_3/Recycle_bert/Data/Relevant_abstracts/ps_recycle_methods.csv")
print('Shape of data:',df0.shape)
#Shows the five rows of data frame
df0.head(2)
# Out:
# Shape of data: (5900, 5)
#                             DOI  \
# 0    10.1016/j.jobe.2022.105697
# 1  10.1016/j.wasman.2022.07.001
#
#                                                Title  \
# 0  Dissolved recycled expanded polystyrene as par...
# 1  Recycling of polystyrene-based external therma...
#
#                                             Abstract           Date  \
# 0  The recovery of Construction and Demolition Wa...  15 April 2023
# 1  The material recycling of complex waste stream...  1 August 2022
#
#                            Journal
# 0  Journal of Building Engineering
# 1                 Waste Management

# %%
#Access the avaiable full text DOIs
df1 = pd.read_csv(r"/home/user3/Documents/avan_phd/Objective_3/Recycle_bert/Data/Relevant_abstracts/pet_recycle_methods.csv")
print('Shape of data:',df1.shape)
#Shows the five rows of data frame
df1.head(2)
# Out:
# Shape of data: (5900, 6)
#    Unnamed: 0                                DOI  \
# 0           0    10.1016/j.resconrec.2022.106639
# 1           1  10.1016/j.conbuildmat.2022.127084
#
#                                                Title  \
# 0  Efficient chemical recycling of waste polyethy...
# 1  Recycled Non-Biodegradable polyethylene tereph...
#
#                                             Abstract           Date  \
# 0  We present an efficient chemical recycling/dep...  December 2022
# 1  In this study, the use of recycled non-biodegr...  18 April 2022
#
#                                  Journal
# 0  Resources, Conservation and Recycling
# 1    Construction and Building Materials

# %%
#Access the avaiable full text DOIs
df2 = pd.read_csv(r"/home/user3/Documents/avan_phd/Objective_3/Recycle_bert/Data/Relevant_abstracts/pp_recycle_methods.csv")
print('Shape of data:',df2.shape)
#Shows the five rows of data frame
df2.head(2)
# Out:
# Shape of data: (5900, 5)
#                             DOI  \
# 0    10.1016/j.jobe.2022.105697
# 1  10.1016/j.wasman.2022.07.001
#
#                                                Title  \
# 0  Dissolved recycled expanded polystyrene as par...
# 1  Recycling of polystyrene-based external therma...
#
#                                             Abstract           Date  \
# 0  The recovery of Construction and Demolition Wa...  15 April 2023
# 1  The material recycling of complex waste stream...  1 August 2022
#
#                            Journal
# 0  Journal of Building Engineering
# 1                 Waste Management

# %%
#Access the avaiable full text DOIs
df3 = pd.read_csv(r"/home/user3/Documents/avan_phd/Objective_3/Recycle_bert/Data/Relevant_abstracts/pe_recycle_methods.csv")
print('Shape of data:',df3.shape)
#Shows the five rows of data frame
df3.head(2)
# Out:
# Shape of data: (6000, 6)
#    Unnamed: 0                           DOI  \
# 0           0  10.1016/j.susmat.2022.e00562
# 1           1    10.1016/j.jobe.2022.105541
#
#                                                Title  \
# 0  Environmental assessment of the recycling proc...
# 1  Sustainable utilization of hybrid recycled pow...
#
#                                             Abstract            Date  \
# 0  The plastic packaging, and in particular the m...      April 2023
# 1  The effects of hybrid recycled powder (HRP) fr...  1 January 2023
#
#                                   Journal
# 0  Sustainable Materials and Technologies
# 1         Journal of Building Engineering

# %%
# concatenating df1 and df2 along rows
df_net = pd.concat([df0, df1,df2, df3], axis=0).reset_index(drop = True)
print('Net shape of data frame:', df_net.shape)
# Out:
# Net shape of data frame: (23700, 6)

# %%
df_net.Date[0][-4:]
# Out:
# '2023'

# %%
date = []
for i in range(len(df_net)):
    date.append(int(df_net.Date[i][-4:]))
    
PUSHILSER = []
for i in range(len(df_net)):
    PUSHILSER.append(df_net.Journal[i])

# %%
# pd.Series(date).value_counts()
from collections import defaultdict

def frequencies(lst):
    freq = defaultdict(int)
    for val in lst:
        freq[val] += 1
    return dict(freq)

date_dict = frequencies(date)
pubshi_dict =frequencies(PUSHILSER)

# %%
import operator
# sorted_date = dict( sorted(date_dict.items(), key=operator.itemgetter(1),reverse=True))

sorted_pub = dict( sorted(pubshi_dict.items(), key=operator.itemgetter(1),reverse=True))

# %%
myKeys = list(date_dict.keys())
myKeys.sort(reverse=True)
sorted_date = {i: date_dict[i] for i in myKeys}

# %%
years = []
numbers = []

for key, value in sorted_date.items():
    years.append(key)
    numbers.append(value)

# %%
# years

# %%
print(years[1:24])
yearss = years[1:24]

numberss = numbers[1:24] 
# numberss, yearss
# Out:
# [2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000]

# %%
name_pub =[]
countss =[]
for key, value in sorted_pub.items():
    name_pub.append(key)
    countss.append(value)

# %%
import numpy as np
import matplotlib.pyplot as plt
#plt.bar(r1, bars1, color='red', width=barWidth,  label='Once-through reactor')
plt.bar(yearss, numberss, color='blue', label='Recycle reactor')
#labels = numberss
#plt.bar(r3, bars3, color='#2d7f5e', width=barWidth, edgecolor='white', label='var3')
 
# Add xticks on the middle of the group bars
plt.xlabel('Year', fontsize=16, fontweight='bold')
plt.ylabel('Number of Publications', fontsize=16, fontweight='bold')
#plt.xticks([r + barWidth for r in range(len(bars3))], bars3, rotation=90,fontsize=16,fontweight='bold')
plt.yticks(fontsize=10,fontweight='bold') 
#plt.xticks(fontsize=10,fontweight='bold', rotation =90) 

plt.xticks(yearss, fontsize=10,fontweight='bold', rotation =90)
# Create legend & Show graphic
#plt.legend(framealpha=0.8, frameon=False,prop={"size":16,'weight':'bold'},bbox_to_anchor =(1.06, 1.1), ncol = 2)
#plt.legend(loc=0,bbox_to_anchor =(0.5, 1.20), frameon=False)
plt.savefig(r'number_paper_new.pdf', dpi=5000,bbox_inches='tight')
plt.show()

# %%
# name_pub, countss
df = pd.DataFrame(
   dict(
      names=name_pub[:30],
      marks=countss[:30]
   )
)
df_sorted = df.sort_values('marks')

# %%
import numpy as np
import matplotlib.pyplot as plt
#plt.bar(r1, bars1, color='red', width=barWidth,  label='Once-through reactor')
plt.bar('names', 'marks', data=df_sorted, color='blue', label='Recycle reactor')
#labels = numberss
#plt.bar(r3, bars3, color='#2d7f5e', width=barWidth, edgecolor='white', label='var3')
 
# Add xticks on the middle of the group bars
plt.xlabel('Name of Journal', fontsize=16, fontweight='bold')
plt.ylabel('Number of Publications', fontsize=16, fontweight='bold')
#plt.xticks([r + barWidth for r in range(len(bars3))], bars3, rotation=90,fontsize=16,fontweight='bold')
plt.yticks(fontsize=10,fontweight='bold') 
#plt.xticks(fontsize=10,fontweight='bold', rotation =90) 

plt.xticks(fontsize=10,fontweight='bold', rotation =90)
# Create legend & Show graphic
#plt.legend(framealpha=0.8, frameon=False,prop={"size":16,'weight':'bold'},bbox_to_anchor =(1.06, 1.1), ncol = 2)
#plt.legend(loc=0,bbox_to_anchor =(0.5, 1.20), frameon=False)
plt.savefig(r'publication_new.pdf', dpi=5000,bbox_inches='tight')
plt.show()

# %% [markdown]
# # Random data testing

# %%
import pandas as pd

#data load of pet
df_pet = pd.read_csv(r'random_files.csv')
df_pet =  df_pet.drop(['Unnamed: 0'], axis=1)
print('Shape of data frame:', df_pet.shape)
df_pet.head()

# %%
indd = []

for i in range(len(df_pet)):
    if df_pet.Date[i] != '3':
        indd.append(i)

# %%
df_net =  df_pet.iloc[indd].reset_index(drop=True)

# %%
date = []
for i in range(len(df_net)):
    date.append(int(df_net.Date[i][-4:]))
    
PUSHILSER = []
for i in range(len(df_net)):
    PUSHILSER.append(df_net.Journal[i])

# %%
# pd.Series(date).value_counts()
from collections import defaultdict

def frequencies(lst):
    freq = defaultdict(int)
    for val in lst:
        freq[val] += 1
    return dict(freq)

date_dict = frequencies(date)
pubshi_dict =frequencies(PUSHILSER)

# %%
import operator
# sorted_date = dict( sorted(date_dict.items(), key=operator.itemgetter(1),reverse=True))

sorted_pub = dict( sorted(pubshi_dict.items(), key=operator.itemgetter(1),reverse=True))

# %%
myKeys = list(date_dict.keys())
myKeys.sort(reverse=True)
sorted_date = {i: date_dict[i] for i in myKeys}

# %%
years = []
numbers = []

for key, value in sorted_date.items():
    years.append(key)
    numbers.append(value)

# %%
# years, numbers

# %%
print(years[:24])
yearss = years[:24]

numberss = numbers[:24] 
# numberss, yearss

# %%
name_pub =[]
countss =[]
for key, value in sorted_pub.items():
    name_pub.append(key)
    countss.append(value)

# %%
import numpy as np
import matplotlib.pyplot as plt
#plt.bar(r1, bars1, color='red', width=barWidth,  label='Once-through reactor')
plt.bar(yearss, numberss, color='blue', label='Recycle reactor')
#labels = numberss
#plt.bar(r3, bars3, color='#2d7f5e', width=barWidth, edgecolor='white', label='var3')
 
# Add xticks on the middle of the group bars
plt.xlabel('Year', fontsize=16, fontweight='bold')
plt.ylabel('Number of Publication', fontsize=16, fontweight='bold')
#plt.xticks([r + barWidth for r in range(len(bars3))], bars3, rotation=90,fontsize=16,fontweight='bold')
plt.yticks(fontsize=10,fontweight='bold') 
#plt.xticks(fontsize=10,fontweight='bold', rotation =90) 

plt.xticks(yearss, fontsize=10,fontweight='bold', rotation =90)
# Create legend & Show graphic
#plt.legend(framealpha=0.8, frameon=False,prop={"size":16,'weight':'bold'},bbox_to_anchor =(1.06, 1.1), ncol = 2)
#plt.legend(loc=0,bbox_to_anchor =(0.5, 1.20), frameon=False)
plt.savefig(r'number_paper_random.pdf', dpi=5000,bbox_inches='tight')
plt.show()

# %%
# name_pub, countss
df = pd.DataFrame(
   dict(
      names=name_pub[:30],
      marks=countss[:30]
   )
)
df_sorted = df.sort_values('marks')

# %%
import numpy as np
import matplotlib.pyplot as plt
#plt.bar(r1, bars1, color='red', width=barWidth,  label='Once-through reactor')
plt.bar('names', 'marks', data=df_sorted, color='blue', label='Recycle reactor')
#labels = numberss
#plt.bar(r3, bars3, color='#2d7f5e', width=barWidth, edgecolor='white', label='var3')
 
# Add xticks on the middle of the group bars
plt.xlabel('Name of Journal', fontsize=16, fontweight='bold')
plt.ylabel('Number of Publication', fontsize=16, fontweight='bold')
#plt.xticks([r + barWidth for r in range(len(bars3))], bars3, rotation=90,fontsize=16,fontweight='bold')
plt.yticks(fontsize=10,fontweight='bold') 
#plt.xticks(fontsize=10,fontweight='bold', rotation =90) 

plt.xticks(fontsize=10,fontweight='bold', rotation =90)
# Create legend & Show graphic
#plt.legend(framealpha=0.8, frameon=False,prop={"size":16,'weight':'bold'},bbox_to_anchor =(1.06, 1.1), ncol = 2)
#plt.legend(loc=0,bbox_to_anchor =(0.5, 1.20), frameon=False)
plt.savefig(r'publication_random.pdf', dpi=5000,bbox_inches='tight')
plt.show()

# %% [markdown]
# **End of Code**
