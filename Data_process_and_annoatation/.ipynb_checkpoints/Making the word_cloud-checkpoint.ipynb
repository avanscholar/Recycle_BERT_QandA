# %%
import pandas as pd
import numpy as np
from pandas import ExcelFile

# %%
my_path='/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/data/harshita/data_full.csv'
    
data = pd.read_csv(my_path)
data.head()
# Out:
#    Unnamed: 0                                DOI  \
# 0           0        10.1533/9781845697662.2.102
# 1           1         10.1016/j.fuel.2021.120505
# 2           2  10.1016/j.conbuildmat.2022.127949
# 3           3       10.1016/j.arabjc.2022.104262
# 4           4  10.1016/j.conbuildmat.2019.117253
#
#                                                Title  \
# 0        5 Pyrolysis for recycling waste composites
# 1  Low-pressure hydrothermal processing of mixed ...
# 2  Cement mortars with ceramic molds shells and p...
# 3  Degradation-fragmentation of marine plastic wa...
# 4  Performance of AC mixtures containing flakes o...
#
#                                             Abstract                process  \
# 0                 Pyrolysis is a suitable process...                     []
# 1  The amount of polyolefin waste, which is 63% o...  ['≥23 MPa', '~2 MPa']
# 2  Foundry industry produces millions of tons of ...                     []
# 3  This review critically evaluates the plastic a...                     []
# 4  This paper evaluates the performance of asphal...                     []
#
#   catalyst                                           reactant  \
# 0       []  ['recycling polymer composites', 'polymer matr...
# 1       []  ['polyolefin waste', 'total plastic waste', '5...
# 2       []                               ['wastes', 'wastes']
# 3       []  ['plastic accumulation challenges', 'plastic p...
# 4       []  ['low density polyethylene', 'plastic film', '...
#
#                                               Method  \
# 0  ['thermal', 'thermal decomposition products', ...
# 1  ['Its degradation products', 'degradation', 't...
# 2                                                 []
# 3  ['degradation', 'degradation', 'fragmentation ...
# 4                                                 []
#
#                                              Product
# 0  ['thermal decomposition products', 'monomers',...
# 1  ['Its degradation products', 'high capital ene...
# 2  ['cement mortars', 'mortars physical mechanica...
# 3                       ['plastic products', 'soil']
# 4                               ['asphalt concrete']

# %%
#The reactant columns
x=data.iloc[:,5].values
x
# Out:
# array(['[]', '[]', '[]', ..., '[]', '[]', '[]'], dtype=object)

# %%
y=[]
List=[]
for i in range(len(data)):
    lis = x[i].split('[')
    gis = lis[1].split(']')
    his = gis[0].split("'")
    J=[]
    for k in range(1, len(his)-1):
        if(his[k]!=' '):
            J.append(his[k])
    List.append(J)
    #print(J)

# %%
for i in range(0, len(List)):
    for j in range(0, len(List[i])):
        v=List[i][j]
        if(y.count(v)==0):
            y.append(v)

# %%
len(y)
# print(y)
# Out:
# 468

# %%
from wordcloud import WordCloud

# matplotlib library
import matplotlib.pyplot as plt

# Joining all the processed lines together. Whole PDF
long_string = ''.join([str(i) for i in y])

# WordCloud object
wordcloud = WordCloud(background_color="white", 
                      max_words=100000, 
                      contour_width=5, 
                      contour_color='steelblue',
                      repeat = False,
                      relative_scaling = 0.5,
                      min_font_size=3,
                      max_font_size = 40)
wordcloud.generate(long_string)

# Visualizing
wordcloud.to_image()

plt.imshow(wordcloud) # image show
plt.axis('off') # to off the axis of x and y
plt.savefig('/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/result/word_cloud/process_word_cloud.pdf',dpi=2000,bbox_inches='tight')
plt.show()

# %% [markdown]
# **The catalyst**

# %%
import pandas as pd
import numpy as np

# %%
#The reactant columns
x=data['catalyst'].values

# %%
y=[]
List=[]
for i in range(len(data)):
    lis = x[i].split('[')
    gis = lis[1].split(']')
    his = gis[0].split("'")
    J=[]
    for k in range(1, len(his)-1):
        if(his[k]!=' '):
            J.append(his[k])
    List.append(J)
    #print(J)

# %%
for i in range(0, len(List)):
    for j in range(0, len(List[i])):
        v=List[i][j]
        if(y.count(v)==0):
            y.append(v)

# %%
print(len(y))
print(y)
# Out:
# 94
# ['Ni-REY', 'zeolite', 'Co3O4', 'Fe/SiO2', 'Ru/Al2O3', 'Fe2O3', 'aluminum', ', ', 'alkylaluminum', 'CaO', 'NiAl', 'Al2O3', 'MgO', 'Ni', 'montmorillonite', 'cobalt', 'Co/30', 'CeO2/30', 'hydrodesulfurizated', 'Zn/C', 'Zn/C-III', 'ZnCl2', 'chlorine', 'nickel', 'Cl', 'Ni-based', 'TiO2', 'CuNiIn', 'glucose', 'Y-zeolite', 'copper', 'Si/Al', 'Y-Zeolite/ZnO', 'Ni/SiO2-S', 'Li/NaY', 'CNF-PEI', 'Pt', 'Ni–Pd/Al2O3', 'MnO2/HGO', 'titania', 'FeCl3', 'Co/Mo', 'Fe', 'Mo', 'CoFe2O4', 'Zn', 'Co', 'KOH', 'sulfonic', 'Ni/Al2O3', 'ZnO-based', 'Ru', 'Mn-Ce', 'oxide', 'Mn', 'Fe-based', 'NiFe2O4', 'zeolites', 'chlorine-containing', 'Ru-based', 'Ni–Mg–Al–CaO', 'Fe-SBA-15', 'Fe/Si', 'nickel-based', 'Ni/ZSM-5', 'Ni/sphere', 'Cl-containing', 'Ni/ZSM5-30', 'Ni/CeO2/Al2O3', 'Ag', 'Ni-Fe/γ-Al2O3', 'Titanium', 'Cu', 'Mg', 'Al', 'Mgx-Aly-O', 'platinum', 'Cu-Al2O3', 'Fe3O4', 'copper-', 'palladium', 'organoiodine', 'iodine-functionalized', 'iodine', 'ruthenium/catalyst', 'iron', 'AgNPs', 'Nickel', 'H2SO4', 'TiO2-based', 'oxalate', '/Pd', 'Al–Mg', 'ZnO']

# %%
from wordcloud import WordCloud

# matplotlib library
import matplotlib.pyplot as plt

# Joining all the processed lines together. Whole PDF
long_string = ''.join([str(i) for i in y])

# WordCloud object
wordcloud = WordCloud(background_color="white", 
                      max_words=100000, 
                      contour_width=5, 
                      contour_color='steelblue',
                      repeat = False,
                      relative_scaling = 0.5,
                      min_font_size=3,
                      max_font_size = 40)
wordcloud.generate(long_string)

# Visualizing
wordcloud.to_image()

plt.imshow(wordcloud) # image show
plt.axis('off') # to off the axis of x and y
plt.savefig('/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/result/word_cloud/cata_word_cloud.pdf',dpi=2000,bbox_inches='tight')
plt.show()

# %% [markdown]
# **Method**

# %%
import pandas as pd
import numpy as np

# %%
#The reactant columns
x=data['Method'].values

# %%
y=[]
List=[]
for i in range(len(data)):
    lis = x[i].split('[')
    gis = lis[1].split(']')
    his = gis[0].split("'")
    J=[]
    for k in range(1, len(his)-1):
        if(his[k]!=' '):
            J.append(his[k])
    List.append(J)
    #print(J)

# %%
for i in range(0, len(List)):
    for j in range(0, len(List[i])):
        v=List[i][j]
        if(y.count(v)==0):
            y.append(v)

# %%
print(len(y))
print(y)
# Out:
# 5078
# ['thermal', ', ', 'thermal decomposition products', 'pyrolysis', 'pyrolysis reactions', 'pyrolysis products', 'Its degradation products', 'degradation', 'fragmentation degradation rates', 'plastic degradation', 'photocatalytic degradation', 'The synergetic degradation mechanism', 'conversion', 'rapid conversion', 'thermal digestion (TD) technique', 'Thermogravimetric-Differential thermal analysis', 'thermal decomposition behavior', 'maximum degradation percentage', 'maximum degradation percentages', 'degradation percentages', 'non-isothermal CO2 gasification tests', 'degradation mechanisms', 'overall conversion', 'total conversion', '60 % conversion', 'maximum conversion', '>85% conversion', 'Thermal catalytic pyrolysis technologies', 'glycolysis', 'glycolysis process', 'better thermal insulation behaviour', 'thermal insulation material', 'thermal insulation behavior', 'thermal insulation', 'depolymerization', 'enzymatic depolymerization', 'pyrolysis-gas chromatography-mass spectrometer', 'pyrolysis characteristics', '50 % conversion', 'PVC polymer degradation', 'catalytic degradation', 'waste bottles’ PET conversion', 'conversion protocol', 'PET pyrolysis', 'hydrothermal (HT) treatment', 'studied conversion routes', 'direct HT conversion', '25.3% conversion yield', 'degradation efficiency', 'enhanced pH thermal stability', 'The pyrolysis process', 'hydrolysis', 'excellent hydrolysis resistance', 'mechanical, thermal chemical methodologies', 'waste material conversion processes', 'Infrared-fast pyrolysis', 'co-pyrolysis behavior', 'electric-conventional slow pyrolysis', 'co-pyrolysis process', 'pyrolysis volatiles', 'clean efficient waste PVC plastics pyrolysis technology', 'cracking conversion', 'LDPE conversion', '40,000 t/y MPW pyrolysis process', 'produced pyrolysis oil', 'catalytic pyrolysis technique', 'feed consumption rate conversion rate', 'lignin biodegradation', 'lignocellulose degradation', 'pyrolysis oil fuel components', 'thermal aging', 'The pyrolysis', 'pyrolysis-gas chromatography/mass spectrometry', 'pyrolysis oil composition', 'thermal aging treatment', 'thermal aging process', '128-h thermal aging', 'thermal valorization', 'thermal treatment', 'thermal technology', 'nanocatalyzed pyrolysis', 'pyrolysis-gasification', 'plastics depolymerization mechanism', 'thermal stability', 'rheology, thermal mechanical properties', 'thermal stabilizer', 'fresh, mechanical thermal properties', 'conversion processes', 'catalytic pyrolysis', 'thermal recycling', 'oil plastic pyrolysis', 'thermal cracking', 'pyrolysis process', 'plastic pyrolysis LDPE', 'pyrolysis times', 'LDPE plastic pyrolysis', 'The thermal stability', 'bit lower thermal stability', 'catalyzed pyrolysis', 'erosion environmental degradation', 'thermochemical banner waste conversion', 'non-catalytic conversion', 'enhanced thermal cracking', 'banner waste conversion', 'non-catalytic CO2-assisted banner waste conversion', '-pyrolysis', 'varying pyrolysis temperatures', 'thermal physiochemical characteristics', 'pyrolysis reactor', 'thermal storage unit', 'plastic wastes pyrolysis', 'reforming', 'steam reforming unit', 'microwave pyrolysis', '(c) pyrolysis process intensification', 'pyrolysis temperature', 'High conversion', 'NS conversion', 'thermal conductivity detector analysis', 'degradation resistance energy absorption characteristics', 'novel conversion', 'biodegradation propensities', 'biodegradation technologies', 'efficient conversion route', 'catalytic hydrothermal liquefaction (HTL) process', 'thermal analyses', 'fast pyrolysis', 'thermal conversion', 'glycolytic depolymerization', 'PET conversion', 'conventional thermal process', 'mild temperature pyrolysis', 'pyrolysis plant', 'Catalytic pyrolysis', 'pyrolysis technique', 'A pyrolysis process', 'The highest percent feedstock conversion', 'lowest feedstock conversion', 'different catalytic pyrolysis temperatures', 'physical, chemical, thermal characteristics', 'thermal characteristics', 'The therma ...

# %%
from wordcloud import WordCloud

# matplotlib library
import matplotlib.pyplot as plt

# Joining all the processed lines together. Whole PDF
long_string = ''.join([str(i) for i in y])

# WordCloud object
wordcloud = WordCloud(background_color="white", 
                      max_words=100000, 
                      contour_width=5, 
                      contour_color='steelblue',
                      repeat = False,
                      relative_scaling = 0.5,
                      min_font_size=3,
                      max_font_size = 40)
wordcloud.generate(long_string)

# Visualizing
wordcloud.to_image()

plt.imshow(wordcloud) # image show
plt.axis('off') # to off the axis of x and y
plt.savefig('/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/result/word_cloud/method_word_cloud.pdf',dpi=2000,bbox_inches='tight')
plt.show()

# %% [markdown]
# **Product**

# %%
import pandas as pd
import numpy as np

# %%
#The reactant columns
x=data['Product'].values

# %%
y=[]
List=[]
for i in range(len(data)):
    lis = x[i].split('[')
    gis = lis[1].split(']')
    his = gis[0].split("'")
    J=[]
    for k in range(1, len(his)-1):
        if(his[k]!=' '):
            J.append(his[k])
    List.append(J)
    #print(J)

# %%
for i in range(0, len(List)):
    for j in range(0, len(List[i])):
        v=List[i][j]
        if(y.count(v)==0):
            y.append(v)

# %%
print(len(y))
print(y)
# Out:
# 15135
# ['thermal decomposition products', ', ', 'monomers', 'The products', 'products', 'pyrolysis products', 'Its degradation products', 'high capital energy costs', 'clean oils', 'oils', 'The oils', 'energy', 'cement mortars', 'mortars physical mechanical properties', 'mortars', 'plastic products', 'soil', 'asphalt concrete', 'plasmon excitation energy transfer', 'high nutrient-rich end product', 'polyethylene glycol', 'polystyrene', 'The production', 'production', 'recycled bags/polystyrene', '3 display/IT product samples', 'extruded polystyrene', 'concrete walls', 'concrete', 'different energy spectra', 'ground products', 'heavy oil', 'oil', '49 soil samples', 'soil organic matter (SOM) concentrations', 'Guiyu soil', 'recycled concrete aggregates', 'production management', 'bio-oil yield', 'hydrogen production', 'production cost', 'economically competitive production', 'The defluoridation product', 'solid product layer', 'average apparent activation energy', 'hydrocarbon liquid oil', 'produced hydrocarbon oil', 'material energy recovery', 'energy sources', 'quaternary energy recycling', 'energy feedstocks', 'direct energy resources', 'syngas incineration products', 'mortar', 'mortars polymers', 'Two mortar groups', 'polymer mortars', 'energy consumption', 'repolymerizable monomers', 'fibers', 'organic pollutant production', 'secondary pollutants production', 'similar materials/products', 'HT products', 'weakly fluorescent products', 'aminolysis products', 'product fluorescence', 'useful energy-yielding products', 'syngas hydrogen fuel production', 'These energy-yielding products', 'high efficient energy products', 'soil sample', 'contaminated soil', 'bare soil', 'waste motor oil', 'oily product', 'oily products', 'initial waste motor oil', 'high value-added products', 'polystyrene food pack', 'food production chain', 'renewable energy sources', 'potential renewable energy', 'product compositions', 'oil yield', 'The maximum oil yield', 'isomerized products', 'product distribution', 'aromatization products', 'produced pyrolysis oil', 'P-oil', '15-year low P-oil revenue price', 'P-oil price', 'desired product', 'gasoline production efficiency', 'product analysis', 'high-value-added products', 'pyrolysis oil fuel components', 'pyrolysis oil composition', 'heavy oil fraction', 'light oil diesel oil fractions', 'gas production', 'energy efficiency', 'fibres', 'fibre', 'The production process', 'production process', 'utilized energy', 'energy storage materials', 'waste aluminium foil', 'waste aluminium foils', 'increasing energy demand', 'water boiling test', 'energy production waste management', 'The product', 'Two production technologies case studies', 'lightweight aggregates product lines', 'The created products', 'heat energy', 'high-energy input', 'value-added chemicals', 'value-added products synthesis', 'common bitumen type', 'PET modified bitumen', 'concrete paving mixture', 'cement/concrete mortar', 'final products', 'value-added goods', 'valuable commercial products', 'S/S products', 'bitumens', 'industrially-sourced residual natural fibers', 'residual cellulose fibers', 'Eucalyptus Globulus residual fibers', 'numerous environmentally sustainable cost-effective end-products', 'weak subgrade expansive soils', 'Expansive soils', 'expansive soils', 'The studied soil', 'expansive clay soil', 'AASHTO soil classification', 'Multilayer foils', 'new products', 'technical products', 'gaseous products', 'The end-product', 'electrical electronic products', 'high-performance polymers', 'acrylonitrile butadiene styrene', 'oil plastic pyrolysis', 'produced oil', 'higher oil yield', 'Most oil yields', 'sisal fibers', 'plastic production', 'higher production', 'neat oil', 'Solid product char', 'high value-added electronic product', 'cement concrete', 'M20 M25 grade cement concrete', 'waste plastic aggregate based concrete', 'maximum hydrogen energy', 'total energy efficiencies', 'hydrogen energy efficiency', 'total energy efficiency', 'worldw ...

# %%
from wordcloud import WordCloud

# matplotlib library
import matplotlib.pyplot as plt

# Joining all the processed lines together. Whole PDF
long_string = ''.join([str(i) for i in y])

# WordCloud object
wordcloud = WordCloud(background_color="white", 
                      max_words=100000, 
                      contour_width=5, 
                      contour_color='steelblue',
                      repeat = False,
                      relative_scaling = 0.5,
                      min_font_size=3,
                      max_font_size = 40)
wordcloud.generate(long_string)

# Visualizing
wordcloud.to_image()

plt.imshow(wordcloud) # image show
plt.axis('off') # to off the axis of x and y
plt.savefig('/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/result/word_cloud/products_word_cloud.pdf',dpi=2000,bbox_inches='tight')
plt.show()

# %% [markdown]
# **Reactant**

# %%
import pandas as pd
import numpy as np

# %%
#The reactant columns
x=data['reactant'].values

# %%
y=[]
List=[]
for i in range(len(data)):
    lis = x[i].split('[')
    gis = lis[1].split(']')
    his = gis[0].split("'")
    J=[]
    for k in range(1, len(his)-1):
        if(his[k]!=' '):
            J.append(his[k])
    List.append(J)
    #print(J)

# %%
for i in range(0, len(List)):
    for j in range(0, len(List[i])):
        v=List[i][j]
        if(y.count(v)==0):
            y.append(v)

# %%
print(len(y))
print(y)
# Out:
# 20923
# ['recycling polymer composites', ', ', 'polymer matrix', 'frequently thermoplastics', 'polymer composites', 'successful plastic composite recycling', 'polyolefin waste', 'total plastic waste', '50% polypropylene', 'wastes', 'plastic accumulation challenges', 'plastic products', 'polymeric properties', 'polymeric function', 'plastics', 'plastic polymer types', 'plastic degradation', 'low density polyethylene', 'plastic film', 'optimum plastic content', 'unaged plastic-modified mixture', 'LDPE waste', 'polyethylene terephthalate (PET) waste', 'solid organic waste', 'waste management', 'polylactic acid melt-blown non-woven fabric', 'polyethylene glycol', 'polystyrene', 'recycled bags/polystyrene', 'plastic waste mismanagement', 'mismanaged plastic waste', 'plastic', 'plastic research', 'marine plastic studies', 'distribution plastic–organism interactions', 'plastic waste', 'plastic pollution', 'plastic waste recycling plastic waste separation', 'plastic flotation', '470 waste plastic articles', 'polybrominated diphenyl ethers', 'waste categories', 'waste', 'waste small domestic appliances', 'waste IT telecommunications articles', 'extruded polystyrene', 'waste stream', 'waste plastics', 'temperature plastics addition ratio', 'optimum plastic addition ratio', 'plastic addition', 'thermoplastic', 'ever-increasing polymer waste', 'existing polymer materials', 'crosslinked polymer', 'permanently crosslinked polymers', 'thermoplastics', 'waste plastic mixture', 'polyolefins', 'polyethylene', 'polypropylene', 'polyamide resins', 'polyesters', 'polycarbonate, poly(butylene terephthalate', 'poly(ethylene terephthalate', 'melted plastics', 'polycyclic aromatic hydrocarbons', 'electronic waste', 'E-waste) recycling center', 'E-waste open burning sites', 'primitive E-waste recycling activities', 'urban solid wastes', 'waste collection management', 'waste marketing management', 'waste collectors', 'high density polyethylene', 'plastic composition', 'waste acid', 'Plastic waste', 'polyolefinic plastic waste', 'polyolefinic waste', 'plastic solid wastes', 'waste tires', 'municipal solid wastes', 'polyethylene-terephthalate (PET', 'unsaturated-polyester-resin (UPER', 'mortars polymers', 'PET waste', 'polymer mortars', 'chemical (or tertiary) plastic recycling technology', 'plastic article', 'repolymerizable monomers', 'new polymers', 'polymers', 'slowly degrading polymers', 'enzymatic depolymerization', 'depolymerization', 'rigid plastic packaging', 'flexible plastic packaging', 'complex plastics', 'Municipal solid wastes', 'polyvinyl chloride', 'PVC polymer degradation', 'waste management systems', 'waste management case studies', 'waste management LCA studies', 'waste bottles’ PET conversion', 'PET bottle plastics', 'waste PET upcycling', 'high-density polyethylene', 'polyethylene terephthalate', 'food waste', 'widely plastics', 'These non-degradable COVID-19 plastic wastes', 'These plastic wastes', 'polyethylene mesh knitted fabrics', 'waste surgical masks', 'waste motor oil', 'increasing medical-derived plastic pollution', 'initial waste motor oil', 'everyday waste', 'Functional polyethylene', 'The dynamic crosslinking transformed thermoplastic PE', 'continuous-fiber-reinforced thermoplastic composites', 'all-polymer composites', 'thermoplastic polymers', 'municipal solid waste', 'proper solid waste management planning', 'possible integrated solid waste management strategies', 'The average daily solid waste generation', 'polythene', 'polystyrene food pack', 'metal wastes', 'capita solid waste generation rate', 'total waste', 'organic polythene components', 'effective solid waste management', 'integrated solid waste management strategies', 'solid waste generation reduction', 'bulk plastics', 'bulk plastic', 'plastic blends', 'degrading plastics', 'biological waste', 'sustainable waste management alternative', 'waste material conversion processes', 'sustainable waste management option', 'polyaromatic rings', 'chlorine-contained PVC plastics', ...

# %%
from wordcloud import WordCloud

# matplotlib library
import matplotlib.pyplot as plt

# Joining all the processed lines together. Whole PDF
long_string = ''.join([str(i) for i in y])

# WordCloud object
wordcloud = WordCloud(background_color="white", 
                      max_words=100000, 
                      contour_width=5, 
                      contour_color='steelblue',
                      repeat = False,
                      relative_scaling = 0.5,
                      min_font_size=3,
                      max_font_size = 40)
wordcloud.generate(long_string)

# Visualizing
wordcloud.to_image()

plt.imshow(wordcloud) # image show
plt.axis('off') # to off the axis of x and y
plt.savefig('/home/user3/Documents/avan_phd/Objective_3/Objective_3_QnA/result/word_cloud/react_word_cloud.pdf',dpi=2000,bbox_inches='tight')
plt.show()
